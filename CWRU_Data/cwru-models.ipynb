# %%
import numpy as np
import pandas as pd
import cv2

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import sys
from tqdm import tqdm
from time import time
import shutil

# %%
import matplotlib.pyplot as plt

def plot_progress(history):
    loss_tr = []
    loss_vl = []
    acc_tr = []
    acc_vl = []
    loss_tr.append(history.history['loss'])
    loss_vl.append(history.history['val_loss'])
    acc_tr.append(history.history['categorical_accuracy'])
    acc_vl.append(history.history['val_categorical_accuracy'])
    
    plt.plot(acc_tr[0])
    plt.plot(acc_vl[0])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

    plt.plot(loss_tr[0])
    plt.plot(loss_vl[0])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# %%
from sklearn.metrics import classification_report,multilabel_confusion_matrix

# %%
inception1 = 0
def report(model):
    prediction = model.predict(test_gen)
    if model == inception1:
        print('incept')
        prediction = prediction[0]
    predicted_labels = np.argmax(prediction, axis=1)
    confusion_mat = multilabel_confusion_matrix(test_gen.labels, predicted_labels)
    print(confusion_mat)
    print(classification_report(test_gen.labels, predicted_labels, digits=5))

# %%
train_path = 'training_path/Model_Image/train'
val_path = 'validation_path/cwry-2/Model_Image/val'
test_path = 'testing_path/cwry-2/Model_Image/test'

num_train_samples = 12909
num_test_samples = 2815
num_val_samples = 2741
train_batch_size = 64
val_batch_size = 64


train_steps = np.ceil(num_train_samples / train_batch_size)
val_steps = np.ceil(num_val_samples / val_batch_size)

# %%
train_steps,val_steps
# Out:
# (202.0, 43.0)

# %%
IMAGE_SIZE = 256
def preprocess(img):
    img = cv2.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
    return img

datagen = ImageDataGenerator(preprocessing_function=lambda img: preprocess(img),
                             rescale=1.0/255)

train_gen = datagen.flow_from_directory(train_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=train_batch_size,
                                        class_mode='categorical')

val_gen = datagen.flow_from_directory(val_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=val_batch_size,
                                        class_mode='categorical')

test_gen = datagen.flow_from_directory(test_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=1,
                                        class_mode='categorical',
                                        shuffle=False)
# Out:
# Found 12909 images belonging to 16 classes.
# Found 2741 images belonging to 16 classes.
# Found 2815 images belonging to 16 classes.

# %% [markdown]
# # DL Models

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, DepthwiseConv2D, BatchNormalization, Flatten, Dense, Dropout
from tensorflow.keras import Model

# %%
# Metrics
cat_acc = tf.keras.metrics.CategoricalAccuracy()
auc_roc = tf.keras.metrics.AUC(multi_label=True, num_labels=16)
prec = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
# Out:
# Name: /physical_device:GPU:0   Type: GPU

# %% [markdown]
# ## AlexNet

# %%
def AlexNet(input_shape):
    input = Input(shape=input_shape)
    
    x = Conv2D(96, (11, 11), strides=(4, 4), activation='relu')(input)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(3, 3), strides=(2, 2))(x)
    
    x = Conv2D(256, kernel_size=5, padding='same', activation='relu')(x)
    x = tf.keras.layers.SpatialDropout2D(0.2)(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(3, 3), strides=(2, 2))(x)
    
    x = Conv2D(384, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.SpatialDropout2D(0.5)(x)
    x = BatchNormalization()(x)
    x = Conv2D(384, kernel_size=3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Conv2D(256, kernel_size=3, padding='same', activation='relu')(x)
    x = tf.keras.layers.SpatialDropout2D(0.2)(x)
    x = BatchNormalization()(x)
    
    x = MaxPool2D(pool_size=(3, 3), strides=(2, 2))(x)
    
    x = Flatten()(x)
    x = Dense(4096, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(4096, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(16, activation='softmax')(x)
    
    model = Model(inputs=input, outputs=output, name='AlexNet')
    
    return model

# %%
alexnet = AlexNet(input_shape=(256,256,3))
alexnet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
alexnet.count_params()

# %%
start = time()
alexnet_hist = alexnet.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')

# %%
hist_df = pd.DataFrame(alexnet_hist.history)
hist_json_file = 'AlexNet_50ep_history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
alexnet.save_weights('AlexNet.hdf5')

# %%
alexnet.evaluate(test_gen)

# %%
report(alexnet)

# %% [markdown]
# ## VGG

# %%
def conv_2(x,filters,kernel_size,activation):
    x = Conv2D(filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    x = Conv2D(filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    x = MaxPool2D(pool_size=2, strides=2, padding='same')(x)
    return x

def conv_3(x,filters,kernel_size,activation):
    x = Conv2D(filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    x = Conv2D(filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    x = Conv2D(filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    x = MaxPool2D(pool_size=2, strides=2, padding='same')(x)
    return x

def conv_4(x,filters,kernel_size,activation):
    x = Conv2D(filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    x = Conv2D(filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    x = Conv2D(filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    x = Conv2D(filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    x = MaxPool2D(pool_size=2, strides=2, padding='same')(x)
    return x

def FC(x,units,activation):
    x = Flatten()(x) 
    x = Dense(units = units, activation =activation)(x)
    x = Dropout(0.5)(x)
    x = Dense(units = units, activation =activation)(x)
    x = Dropout(0.5)(x)
    x = Dense(units = 16, activation ='softmax')(x)
    return x

# %% [markdown]
# ### VGG16

# %%
def VGG16(input_shape):
    
    input = Input(shape=input_shape)
    
    filters = 64
    kernel_same = 3
    act = 'relu'
    
    x = conv_2(input,filters,kernel_same,act)
    x = conv_2(x,filters*2,kernel_same,act)
    x = tf.keras.layers.SpatialDropout2D(0.2)(x)
    x = conv_3(x,filters*4,kernel_same,act)
    x = conv_3(x,filters*8,kernel_same,act)
    x = tf.keras.layers.SpatialDropout2D(0.2)(x)
    x = conv_3(x,filters*8,kernel_same,act)
    
    units = 4096
    
    output = FC(x,units,act)
    
    model = Model(inputs=input, outputs=output, name='VGG16')
    
    return model

# %%
vgg16 = VGG16(input_shape=(256,256,3))
vgg16.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
vgg16.count_params()

# %%
start = time()
vgg16_hist = vgg16.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')

# %%
hist_df = pd.DataFrame(vgg16_hist.history)
hist_json_file = 'VGG16_50ep_history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
vgg16.evaluate(test_gen)

# %%
report(vgg16)

# %% [markdown]
# ### VGG19

# %%
def VGG19(input_shape):
    
    input = Input(shape=input_shape)
    
    filters = 64
    kernel_same = 3
    act = 'relu'
    
    x = conv_2(input,filters,kernel_same,act)
    x = conv_2(x,filters*2,kernel_same,act)
    x = tf.keras.layers.SpatialDropout2D(0.2)(x)
    x = conv_4(x,filters*4,kernel_same,act)
    x = tf.keras.layers.SpatialDropout2D(0.5)(x)
    x = conv_4(x,filters*8,kernel_same,act)
    x = tf.keras.layers.SpatialDropout2D(0.2)(x)
    x = conv_4(x,filters*8,kernel_same,act)
    
    units = 4096
    
    output = FC(x,units,act)
    
    model = Model(inputs=input, outputs=output)
    
    return model

# %%
vgg19 = VGG19(input_shape=(256,256,3))
vgg19.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
vgg19.count_params()

# %%
start = time()
vgg19_hist = vgg19.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')

# %%
hist_df = pd.DataFrame(vgg19_hist.history)
hist_json_file = 'VGG19_50ep_history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = vgg19.evaluate(test_gen)

# %%
report(vgg19)

# %% [markdown]
# ## MobileNet

# %%
def block(x, filters, strides, activation):
    
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    
    x = Conv2D(filters=filters, kernel_size=1, strides=1)(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    
    return x

def MobileNet(input_shape):
    
    activation = 'relu'
    filters = 32
    reps = 5
    input = Input(shape =input_shape)
    x = Conv2D(filters = 32, kernel_size = 3, strides = 2, padding = 'same')(input)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    
    x = block(x, filters = filters, strides = 1, activation=activation)
    x = block(x, filters = filters*2, strides = 2, activation=activation)
    x = block(x, filters = filters*2, strides = 1, activation=activation)
    x = block(x, filters = filters*4, strides = 2, activation=activation)
    x = Dropout(0.2)(x)
    x = block(x, filters = filters*4, strides = 1, activation=activation)
    x = block(x, filters = filters*8, strides = 2, activation=activation)
    for _ in range (reps):
         x = block(x, filters = filters*8, strides = 1, activation=activation)
    x = block(x, filters = filters*16, strides = 2, activation=activation)
    x = block(x, filters = filters*16, strides = 1, activation=activation)
    x = Dropout(0.2)(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = Flatten()(x)
    output = Dense(units = 16, activation = 'softmax')(x)
    model = Model(inputs=input, outputs=output)
    
    return model

# %%
mobilenet = MobileNet(input_shape=(256,256,3))
mobilenet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
mobilenet.count_params()

# %%
start = time()
mobilenet_hist = mobilenet.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')

# %%
hist_df = pd.DataFrame(mobilenet_hist.history)
hist_json_file = 'MobileNet_50ep_histori.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = mobilenet.evaluate(test_gen)

# %%
report(mobilenet)

# %% [markdown]
# ## MobileNet v2

# %%
def inverted_residual_block(x, factor, filters_in, filters_out, strides, activation):
    
    x_add = x
    x = Conv2D(filters=filters_in*factor, kernel_size=1, strides=1)(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    
    x = DepthwiseConv2D(kernel_size=3, strides=strides, padding='same')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation)(x)
    
    x = Conv2D(filters=filters_out, kernel_size=1, strides=1,use_bias=False)(x)
    x = BatchNormalization()(x)
    
    if x_add.shape[-1] == x.shape[-1]:
        x = tf.keras.layers.Add()([x_add,x])
    
    return x

# %%
def MobileNet_v2(input_shape=(256,256,3)):
    
    input = Input(shape=input_shape)
    
    x = Conv2D(filters=32, kernel_size=3, strides=2, padding='same', use_bias=False)(input)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu6')(x)
    
    x = inverted_residual_block(x, factor=1, filters_in=x.shape[-1], filters_out=16, strides=1, activation='relu6')
    x = Dropout(0.2)(x)
    for i in range(2):
        s = 1
        if i == 0:
            s = 2
        x = inverted_residual_block(x, factor=6, filters_in=x.shape[-1], filters_out=24, strides=s, activation='relu6')
    for i in range(3):
        s = 1
        if i == 0:
            s = 2
        x = inverted_residual_block(x, factor=6, filters_in=x.shape[-1], filters_out=32, strides=s, activation='relu6')
    for i in range(4):
        s = 1
        if i == 0:
            s = 2
        x = inverted_residual_block(x, factor=6, filters_in=x.shape[-1], filters_out=64, strides=s, activation='relu6')
    for i in range(3):
        x = inverted_residual_block(x, factor=6, filters_in=x.shape[-1], filters_out=96, strides=1, activation='relu6')
    for i in range(3):
        s = 1
        if i == 0:
            s = 2
        x = inverted_residual_block(x, factor=6, filters_in=x.shape[-1], filters_out=160, strides=s, activation='relu6')
    x = inverted_residual_block(x, factor=6, filters_in=x.shape[-1], filters_out=320, strides=1, activation='relu6')
    x = Dropout(0.2)(x)
    
    x = Conv2D(filters=1280, kernel_size=1, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu6')(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    
    x = Flatten()(x)
    output = Dense(units=16, activation='softmax')(x)
    
    model = Model(inputs=input, outputs=output)
    
    return model

# %%
mobilenet_v2 = MobileNet_v2(input_shape=(256,256,3))
mobilenet_v2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
mobilenet_v2.count_params()
# Out:
# 2293904

# %%
start = time()
mobilenet_v2_hist = mobilenet_v2.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/50
# 2023-08-28 20:50:31.877500: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_2/dropout_4/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 202/202 - 136s - loss: 1.7519 - categorical_accuracy: 0.4982 - auc: 0.9160 - precision: 0.9357 - recall: 0.3080 - val_loss: 3.8050 - val_categorical_accuracy: 0.0668 - val_auc: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 136s/epoch - 674ms/step
# Epoch 2/50
# 202/202 - 97s - loss: 0.5897 - categorical_accuracy: 0.8036 - auc: 0.9859 - precision: 0.8933 - recall: 0.6932 - val_loss: 4.4494 - val_categorical_accuracy: 0.0657 - val_auc: 0.4982 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 97s/epoch - 478ms/step
# Epoch 3/50
# 202/202 - 97s - loss: 0.2957 - categorical_accuracy: 0.8996 - auc: 0.9950 - precision: 0.9255 - recall: 0.8757 - val_loss: 5.5957 - val_categorical_accuracy: 0.0657 - val_auc: 0.5281 - val_precision: 0.0657 - val_recall: 0.0657 - 97s/epoch - 482ms/step
# Epoch 4/50
# 202/202 - 99s - loss: 0.1699 - categorical_accuracy: 0.9408 - auc: 0.9980 - precision: 0.9522 - recall: 0.9309 - val_loss: 0.6130 - val_categorical_accuracy: 0.7964 - val_auc: 0.9889 - val_precision: 0.8233 - val_recall: 0.7599 - 99s/epoch - 491ms/step
# Epoch 5/50
# 202/202 - 99s - loss: 0.1232 - categorical_accuracy: 0.9591 - auc: 0.9989 - precision: 0.9655 - recall: 0.9526 - val_loss: 0.2982 - val_categorical_accuracy: 0.9296 - val_auc: 0.9892 - val_precision: 0.9336 - val_recall: 0.9285 - 99s/epoch - 488ms/step
# Epoch 6/50
# 202/202 - 100s - loss: 0.0936 - categorical_accuracy: 0.9706 - auc: 0.9991 - precision: 0.9733 - recall: 0.9670 - val_loss: 0.1736 - val_categorical_accuracy: 0.9391 - val_auc: 0.9981 - val_precision: 0.9451 - val_recall: 0.9358 - 100s/epoch - 493ms/step
# Epoch 7/50
# 202/202 - 99s - loss: 0.0770 - categorical_accuracy: 0.9758 - auc: 0.9993 - precision: 0.9791 - recall: 0.9728 - val_loss: 0.1416 - val_categorical_accuracy: 0.9533 - val_auc: 0.9984 - val_precision: 0.9578 - val_recall: 0.9518 - 99s/epoch - 491ms/step
# Epoch 8/50
# 202/202 - 98s - loss: 0.0570 - categorical_accuracy: 0.9807 - auc: 0.9996 - precision: 0.9826 - recall: 0.9791 - val_loss: 0.1372 - val_categorical_accuracy: 0.9540 - val_auc: 0.9977 - val_precision: 0.9546 - val_recall: 0.9522 - 98s/epoch - 487ms/step
# Epoch 9/50
# 202/202 - 99s - loss: 0.0495 - categorical_accuracy: 0.9844 - auc: 0.9996 - precision: 0.9858 - recall: 0.9832 - val_loss: 0.1356 - val_categorical_accuracy: 0.9570 - val_auc: 0.9975 - val_precision: 0.9600 - val_recall: 0.9540 - 99s/epoch - 491ms/step
# Epoch 10/50
# 202/202 - 99s - loss: 0.0404 - categorical_accuracy: 0.9865 - auc: 0.9998 - precision: 0.9874 - recall: 0.9853 - val_loss: 0.1403 - val_categorical_accuracy: 0.9591 - val_auc: 0.9980 - val_precision: 0.9618 - val_recall: 0.9555 - 99s/epoch - 491ms/step
# Epoch 11/50
# 202/202 - 99s - loss: 0.0346 - categorical_accuracy: 0.9884 - auc: 0.9997 - precision: 0.9894 - recall: 0.9876 - val_loss: 0.1267 - val_categorical_accuracy: 0.9573 - val_auc: 0.9981 - val_precision: 0.9590 - val_recall: 0.9559 - 99s/epoch - 490ms/step
# Epoch 12/50
# 202/202 - 98s - loss: 0.0342 - categorical_accuracy: 0.9900 - auc: 0.9996 - precision: 0.9908 - recall: 0.9889 - val_loss: 0.2246 - val_categorical_accuracy: 0.9365 - val_auc: 0.9941 - val_precision: 0.9415 - val_recall: 0.9329 - 98s/epoch - 487ms/step
# Epoch 13/50
# 202/202 - 99s - loss: 0.0263 - categorical_accuracy: 0.9913 - auc: 0.9998 - precision: 0.9918 - recall: 0.9907 - val_loss: 0.0940 - val_categorical_accuracy: 0.9664 - val_auc: 0.9980 - val_precision: 0.9692 - val_recall: 0.9657 - 99s/epoch - 492ms/step
# Epoch 14/50
# 202/202 - 99s - loss: 0.0289 - categorical_accuracy: 0.9906 - auc: 0.9999 - precision: 0.9912 - recall: 0.9901 - val_loss: 0.1114 - val_categorical_accuracy: 0.9635 - val_auc: 0.9982 - val_precision: 0.9649 - val_recall: 0.9632 - 99s/epoch - 488ms/step
# Epoch 15/50
# 202/202 - 99s - loss: 0.0202 - categorical_accuracy: 0.9941 - auc: 0.9999 - precision: 0.9945 - recall: 0.9937 - val_loss: 0.0306 - val_categorical_accuracy: 0.9909 - val_auc: 1.0000 - val_precision: 0.9912 - val_recall: 0.9898 - 99s/epoch - 489ms/step
# Epoch 16/50
# 202/202 - 99s - loss: 0.0192 - categorical_accuracy: 0.9936 - auc: 0.9999 - precision: 0.9942 - recall: 0.9931 - val_loss: 0.0717 - val_categorical_accuracy: 0.9788 - val_auc: 0.9986 - val_precision: 0.9802 - val_recall: 0.9759 - 99s/epoch - 491ms/step
# Epoch 17/50
# 202/202 - 99s - loss: 0.0230 - categorical_accuracy: 0.9933 - auc: 0.9997 - precision: 0.9939 - recall: 0.9929 - val_loss: 0.0415 - val_categorical_accuracy: 0.9876 - val_auc: 0.9992 - val_precision: 0.9898 - val_recall: 0.9869 - 99s/epoch - 489ms/step
# Epoch 18/50
# 202/202 - 99s - loss: 0.0156 - categorical_accuracy: 0.9954 - auc: 0.9998 - precision: 0.9955 - recall: 0.9951 - val_loss: 0.0744 - val_categorical_accuracy: 0.9759 - val_auc: 0.9995 - val_precision: 0.9773 - val_recall: 0.9741 - 99s/epoch - 490ms/step
# Epoch 19/50
# 202/202 - 99s - loss: 0.0214 - categorical_accuracy: 0.9931 - auc: 0.9998 - precision: 0.9936 - recall: 0.9929 - val_loss: 0.0404 - val_categorical_accuracy: 0.9861 - val_auc: 0.9992 - val_precision: 0.9872 - val_recall: 0.9858 - 99s/epoch - 491ms/step
# Epoch 20/50
# 202/202 - 99s - loss: 0.0151 - categorical_accuracy: 0.9958 - auc: 0.9999 - precision: 0.9959 - recall: 0.9954 - val_loss: 0.0260 - val_categorical_accuracy: 0.9916 - val_auc: 1.0000 - val_precision: 0.9916 - val_recall: 0.9909 - 99s/epoch - 488ms/step
# Epoch 21/50
# 202/202 - 98s - loss: 0.0164 - categorical_accuracy: 0.9956 - auc: 0.9998 - precision: 0.9959 - recall: 0.9955 - val_loss: 0.0348 - val_categorical_accuracy: 0.9869 - val_auc: 0.9998 - val_precision: 0.9869 - val_recall: 0.9865 - 98s/epoch - 487ms/step
# Epoch 22/50
# 202/202 - 98s - loss: 0.0149 - categorical_accuracy: 0.9947 - auc: 0.9999 - precision: 0.9948 - recall: 0.9945 - val_loss: 0.0568 - val_categorical_accuracy: 0.9843 - val_auc: 0.9991 - val_precision: 0.9846 - val_recall: 0.9829 - 98s/epoch - 487ms/step
# Epoch 23/50
# 202/202 - 99s - loss: 0.0164 - categorical_accuracy: 0.9949 - auc: 0.9998 - precision: 0.9951 - recall: 0.9946 - val_loss: 0.0431 - val_categorical_accuracy: 0.9850 - val_auc: 0.9994 - val_precision: 0.9861 - val_recall: 0.9850 - 99s/epoch - 489ms/step
# Epoch 24/50
# 202/202 - 99s - loss: 0.0135 - categorical_accuracy: 0.9957 - auc: 0.9998 - precision: 0.9957 - recall: 0.9957 - val_loss: 0.1022 - val_categorical_accuracy: 0.9723 - val_auc: 0.9981 - val_precision: 0.9733 - val_recall: 0.9712 - 99s/epoch - 491ms/step
# Epoch 25/50
# 202/202 - 99s - loss: 0.0188 - categorical_accuracy: 0.9941 - auc: 0.9997 - precision: 0.9946 - recall: 0.9939 - val_loss: 0.0616 - val_categorical_accuracy: 0.9829 - val_auc: 0.9985 - val_precision: 0.9832 - val_recall: 0.9825 - 99s/epoch - 489ms/step
# Epoch 26/50
# 202/202 - 98s - loss: 0.0112 - categorical_accuracy: 0.9961 - auc: 1.0000 - precision: 0.9962 - recall: 0.9960 - val_loss: 0.0404 - val_categorical_accuracy: 0.9883 - val_auc: 0.9989 - val_precision: 0.9890 - val_recall: 0.9876 - 98s/epoch - 486ms/step
# Epoch 27/50
# 202/202 - 107s - loss: 0.0128 - categorical_accuracy: 0.9957 - auc: 0.9998 - precision: 0.9959 - recall: 0.9954 - val_loss: 0.1542 - val_categorical_accuracy: 0.9588 - val_auc: 0.9951 - val_precision: 0.9604 - val_recall: 0.9566 - 107s/epoch - 529ms/step
# Epoch 28/50
# 202/202 - 99s - loss: 0.0105 - categorical_accuracy: 0.9970 - auc: 0.9999 - precision: 0.9970 - recall: 0.9968 - val_loss: 0.0205 - val_categorical_accuracy: 0.9949 - val_auc: 0.9996 - val_precision: 0.9953 - val_recall: 0.9949 - 99s/epoch - 490ms/step
# Epoch 29/50
# 202/202 - 99s - loss: 0.0104 - categorical_accuracy: 0.9966 - auc: 1.0000 - precision: 0.9968 - recall: 0.9965 - val_loss: 0.0588 - val_categorical_accuracy: 0.9865 - val_auc: 0.9981 - val_precision: 0.9865 - val_recall: 0.9854 - 99s/epoch - 490ms/step
# Epoch 30/50
# 202/202 - 98s - loss: 0.0114 - categorical_accuracy: 0.9966 - auc: 0.9999 - precision: 0.9968 - recall: 0.9964 - val_loss: 0.0155 - val_categorical_accuracy: 0.9949 - val_auc: 0.9998 - val_precision: 0.9949 - val_recall: 0.9949 - 98s/epoch - 487ms/step
# Epoch 31/50
# 202/202 - 98s - loss: 0.0120 - categorical_accuracy: 0.9964 - auc: 0.9999 - precision: 0.9964 - recall: 0.9963 - val_loss: 0.0112 - val_categorical_accuracy: 0.9960 - val_auc: 1.0000 - val_precision: 0.9967 - val_recall: 0.9956 - 98s/epoch - 487ms/step
# Epoch 32/50
# 202/202 - 99s - loss: 0.0034 - categorical_accuracy: 0.9991 - auc: 1.0000 - precision: 0.9992 - recall: 0.9991 - val_loss: 0.0158 - val_categorical_accuracy: 0.9938 - val_auc: 1.0000 - val_precision: 0.9942 - val_recall: 0.9938 - 99s/epoch - 491ms/step
# Epoch 33/50
# 202/202 - 99s - loss: 0.0120 - categorical_accuracy: 0.9963 - auc: 0.9998 - precision: 0.9964 - recall: 0.9963 - val_loss: 0.0324 - val_categorical_accuracy: 0.9912 - val_auc: 0.9995 - val_precision: 0.9920 - val_recall: 0.9905 - 99s/epoch - 488ms/step
# Epoch 34/50
# 202/202 - 99s - loss: 0.0093 - categorical_accuracy: 0.9971 - auc: 1.0000 - precision: 0.9972 - recall: 0.9968 - val_loss: 0.0229 - val_categorical_accuracy: 0.9934 - val_auc: 0.9996 - val_precision: 0.9945 - val_recall: 0.9934 - 99s/epoch - 491ms/step
# Epoch 35/50
# 202/202 - 99s - loss: 0.0127 - categorical_accuracy: 0.9951 - auc: 0.9999 - precision: 0.9955 - recall: 0.9950 - val_loss: 0.1064 - val_categorical_accuracy: 0.9774 - val_auc: 0.9958 - val_precision: 0.9788 - val_recall: 0.9767 - 99s/epoch - 490ms/step
# Epoch 36/50
# 202/202 - 99s - loss: 0.0072 - categorical_accuracy: 0.9977 - auc: 0.9999 - precision: 0.9981 - recall: 0.9976 - val_loss: 0.0180 - val_categorical_accuracy: 0.9945 - val_auc: 0.9996 - val_precision: 0.9945 - val_recall: 0.9945 - 99s/epoch - 489ms/step
# Epoch 37/50
# 202/202 - 99s - loss: 0.0070 - categorical_accuracy: 0.9979 - auc: 0.9999 - precision: 0.9979 - recall: 0.9979 - val_loss: 0.0458 - val_categorical_accuracy: 0.9861 - val_auc: 0.9991 - val_precision: 0.9876 - val_recall: 0.9858 - 99s/epoch - 488ms/step
# Epoch 38/50
# 202/202 - 99s - loss: 0.0086 - categorical_accuracy: 0.9978 - auc: 0.9999 - precision: 0.9978 - recall: 0.9978 - val_loss: 0.0298 - val_categorical_accuracy: 0.9898 - val_auc: 0.9994 - val_precision: 0.9909 - val_recall: 0.9894 - 99s/epoch - 491ms/step
# Epoch 39/50
# 202/202 - 99s - loss: 0.0032 - categorical_accuracy: 0.9991 - auc: 1.0000 - precision: 0.9991 - recall: 0.9991 - val_loss: 0.0503 - val_categorical_accuracy: 0.9861 - val_auc: 0.9990 - val_precision: 0.9865 - val_recall: 0.9861 - 99s/epoch - 492ms/step
# Epoch 40/50
# 202/202 - 99s - loss: 0.0079 - categorical_accuracy: 0.9974 - auc: 0.9999 - precision: 0.9975 - recall: 0.9974 - val_loss: 0.0106 - val_categorical_accuracy: 0.9967 - val_auc: 0.9998 - val_precision: 0.9971 - val_recall: 0.9967 - 99s/epoch - 492ms/step
# Epoch 41/50
# 202/202 - 99s - loss: 0.0061 - categorical_accuracy: 0.9979 - auc: 1.0000 - precision: 0.9979 - recall: 0.9978 - val_loss: 0.0443 - val_categorical_accuracy: 0.9865 - val_auc: 0.9991 - val_precision: 0.9876 - val_recall: 0.9861 - 99s/epoch - 489ms/step
# Epoch 42/50
# 202/202 - 99s - loss: 0.0114 - categorical_accuracy: 0.9966 - auc: 0.9999 - precision: 0.9968 - recall: 0.9964 - val_loss: 0.0141 - val_categorical_accuracy: 0.9949 - val_auc: 1.0000 - val_precision: 0.9953 - val_recall: 0.9942 - 99s/epoch - 490ms/step
# Epoch 43/50
# 202/202 - 99s - loss: 0.0126 - categorical_accuracy: 0.9960 - auc: 0.9998 - precision: 0.9961 - recall: 0.9960 - val_loss: 0.0218 - val_categorical_accuracy: 0.9923 - val_auc: 0.9996 - val_precision: 0.9927 - val_recall: 0.9920 - 99s/epoch - 491ms/step
# Epoch 44/50
# 202/202 - 99s - loss: 0.0090 - categorical_accuracy: 0.9974 - auc: 0.9999 - precision: 0.9974 - recall: 0.9973 - val_loss: 0.0216 - val_categorical_accuracy: 0.9934 - val_auc: 0.9996 - val_precision: 0.9942 - val_recall: 0.9934 - 99s/epoch - 490ms/step
# Epoch 45/50
# 202/202 - 99s - loss: 0.0014 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0094 - val_categorical_accuracy: 0.9971 - val_auc: 1.0000 - val_precision: 0.9978 - val_recall: 0.9967 - 99s/epoch - 491ms/step
# Epoch 46/50
# 202/202 - 99s - loss: 0.0025 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0073 - val_categorical_accuracy: 0.9974 - val_auc: 1.0000 - val_precision: 0.9974 - val_recall: 0.9974 - 99s/epoch - 490ms/step
# Epoch 47/50
# 202/202 - 99s - loss: 0.0068 - categorical_accuracy: 0.9981 - auc: 0.9999 - precision: 0.9983 - recall: 0.9980 - val_loss: 0.0149 - val_categorical_accuracy: 0.9938 - val_auc: 1.0000 - val_precision: 0.9942 - val_recall: 0.9938 - 99s/epoch - 490ms/step
# Epoch 48/50
# 202/202 - 99s - loss: 0.0098 - categorical_accuracy: 0.9969 - auc: 0.9998 - precision: 0.9970 - recall: 0.9969 - val_loss: 0.0492 - val_categorical_accuracy: 0.9865 - val_auc: 0.9987 - val_precision: 0.9869 - val_recall: 0.9861 - 99s/epoch - 489ms/step
# Epoch 49/50
# 202/202 - 99s - loss: 0.0100 - categorical_accuracy: 0.9973 - auc: 0.9999 - precision: 0.9974 - recall: 0.9971 - val_loss: 0.0188 - val_categorical_accuracy: 0.9953 - val_auc: 0.9994 - val_precision: 0.9956 - val_recall: 0.9953 - 99s/epoch - 492ms/step
# Epoch 50/50
# 202/202 - 99s - loss: 0.0051 - categorical_accuracy: 0.9988 - auc: 0.9999 - precision: 0.9988 - recall: 0.9988 - val_loss: 0.0117 - val_categorical_accuracy: 0.9964 - val_auc: 0.9998 - val_precision: 0.9964 - val_recall: 0.9964 - 99s/epoch - 492ms/step
# ===================================
# 50 epochs in 99.19724799791972 min

# %%
hist_df = pd.DataFrame(mobilenet_v2_hist.history)
hist_json_file = 'MobileNe_v2_50ep_histori.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = mobilenet_v2.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 34s 12ms/step - loss: 0.0072 - categorical_accuracy: 0.9979 - auc: 1.0000 - precision: 0.9982 - recall: 0.9975

# %%
report(mobilenet_v2)
# Out:
# 2815/2815 [==============================] - 23s 8ms/step
# [[[2628    1]
#   [   0  186]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2629    0]
#   [   2  184]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2754    0]
#   [   0   61]]
#
#  [[2753    0]
#   [   1   61]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       186
#            1       0.99      1.00      1.00       186
#            2       0.99      1.00      1.00       186
#            3       1.00      1.00      1.00       186
#            4       1.00      1.00      1.00       186
#            5       0.99      1.00      1.00       186
#            6       1.00      1.00      1.00       186
#            7       1.00      0.99      1.00       186
#            8       1.00      0.99      0.99       186
#            9       0.99      1.00      1.00       186
#           10       1.00      0.99      1.00       186
#           11       0.99      1.00      1.00       186
#           12       1.00      0.99      1.00       186
#           13       1.00      1.00      1.00        61
#           14       1.00      0.98      0.99        62
#           15       1.00      1.00      1.00       274
#
#     accuracy                           1.00      2815
#    macro avg       1.00      1.00      1.00      2815
# weighted avg       1.00      1.00      1.00      2815

# %% [markdown]
# ## MobileNet v3

# %%
def bottleneck_block(x, kernel_size, stride, filters_out, exp_size, SE, NL):

    expanded_channels = exp_size
    reduction_ratio = 4
    x_add = x
    
    x = Conv2D(expanded_channels, kernel_size=1, padding='valid')(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation(NL)(x)
    
    x = DepthwiseConv2D(kernel_size=kernel_size, padding='same', strides=stride)(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation(NL)(x)
    
    if SE == True:
        # Squeeze and Excitation Layer
        squeeze = tf.keras.layers.GlobalAveragePooling2D()(x)
        excitation = Dense(expanded_channels // reduction_ratio, activation='relu')(squeeze)
        excitation = Dense(expanded_channels, activation='hard_sigmoid')(excitation)
        excitation = tf.keras.layers.Reshape((1, 1, expanded_channels))(excitation)
        x = tf.keras.layers.multiply([x, excitation])

    x = Conv2D(filters_out, kernel_size=1, padding='valid')(x)
    x = BatchNormalization()(x)
    
    if x_add.shape == x.shape:
        x = tf.keras.layers.add([x, x_add])
    
    return x

def efficient_final_layers(x,l=960):
    x = Conv2D(l, kernel_size=1, padding='valid', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('swish')(x)
    
    x = tf.keras.layers.AveragePooling2D(8)(x)
    
    x = Conv2D(1280, kernel_size=1, use_bias=False)(x)
    x = tf.keras.layers.Activation('swish')(x)
    x = Dropout(0.2)(x)
    x = Conv2D(16, kernel_size=1, activation='softmax')(x)
    
    x = tf.squeeze(x, 1)
    x = tf.squeeze(x, 1)
    
    return x

# %%
def MobileNet_v3(size='Large',input_shape=(256,256,3)):
    
    input = Input(shape=input_shape)
    
    if size == 'Large':
        x = Conv2D(16, kernel_size=3, padding='same', strides=2, use_bias=False)(input)
        x = BatchNormalization()(x)
        x = tf.keras.layers.Activation('swish')(x)

                           # x  k  s  out exp sq&ex   act
        x = bottleneck_block(x, 3, 1, 16, 16, False, 'relu')
        x = bottleneck_block(x, 3, 2, 24, 64, False, 'relu')
        x = bottleneck_block(x, 3, 1, 24, 72, False, 'relu')
        x = Dropout(0.2)(x)

        x = bottleneck_block(x, 5, 2, 40, 72, True, 'relu')
        x = bottleneck_block(x, 5, 1, 40, 120, True, 'relu')
        x = bottleneck_block(x, 5, 1, 40, 120, True, 'relu')

        x = bottleneck_block(x, 3, 2, 80, 240, False, 'swish')
        x = bottleneck_block(x, 3, 1, 80, 200, False, 'swish')
        x = bottleneck_block(x, 3, 1, 80, 184, False, 'swish')
        x = bottleneck_block(x, 3, 1, 80, 184, False, 'swish')
        x = bottleneck_block(x, 3, 1, 112, 480, True, 'swish')
        x = bottleneck_block(x, 3, 1, 112, 672, True, 'swish')
        x = Dropout(0.2)(x)

        x = bottleneck_block(x, 5, 2, 160, 672, True, 'swish')
        x = bottleneck_block(x, 5, 1, 160, 960, True, 'swish')
        x = bottleneck_block(x, 5, 1, 160, 960, True, 'swish')
        

        output = efficient_final_layers(x)

        model = Model(inputs=input, outputs=output, name='MobileNetv3_large')
    if size == 'Small':
        x = Conv2D(16, kernel_size=3, padding='same', strides=2, use_bias=False)(input)
        x = BatchNormalization()(x)
        x = tf.keras.layers.Activation('swish')(x)

                           # x  k  s  out exp sq&ex   act
        x = bottleneck_block(x, 3, 2, 16, 16, True, 'relu')
        x = bottleneck_block(x, 3, 2, 24, 72, False, 'relu')
        x = bottleneck_block(x, 3, 1, 24, 88, False, 'relu')
        x = Dropout(0.2)(x)
        
        x = bottleneck_block(x, 5, 2, 40, 96, True, 'swish')
        x = bottleneck_block(x, 5, 1, 40, 240, True, 'swish')
        x = bottleneck_block(x, 5, 1, 40, 240, True, 'swish')
        x = bottleneck_block(x, 5, 1, 48, 120, True, 'swish')
        x = bottleneck_block(x, 5, 1, 48, 144, True, 'swish')
        x = bottleneck_block(x, 5, 2, 96, 288, True, 'swish')
        x = Dropout(0.2)(x)
        x = bottleneck_block(x, 5, 1, 96, 576, True, 'swish')
        x = bottleneck_block(x, 5, 1, 96, 576, True, 'swish')

        output = efficient_final_layers(x,l=576)

        model = Model(inputs=input, outputs=output, name='MobileNetv3_Small')
    
    return model

# %%
Lmobilenet_v3 = MobileNet_v3(size='Large',input_shape=(256,256,3))
Lmobilenet_v3.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
Lmobilenet_v3.count_params()
# Out:
# 4255374

# %%
start = time()
Lmobilenet_v3_hist = Lmobilenet_v3.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/50
# 2023-08-28 22:41:17.146668: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inMobileNetv3_large/dropout_6/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 202/202 - 135s - loss: 1.1827 - categorical_accuracy: 0.6648 - auc: 0.9631 - precision: 0.8957 - recall: 0.5371 - val_loss: 2.9111 - val_categorical_accuracy: 0.0668 - val_auc: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 135s/epoch - 667ms/step
# Epoch 2/50
# 202/202 - 87s - loss: 0.2752 - categorical_accuracy: 0.9009 - auc: 0.9952 - precision: 0.9220 - recall: 0.8801 - val_loss: 3.6212 - val_categorical_accuracy: 0.0668 - val_auc: 0.5105 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 87s/epoch - 428ms/step
# Epoch 3/50
# 202/202 - 87s - loss: 0.1420 - categorical_accuracy: 0.9535 - auc: 0.9982 - precision: 0.9604 - recall: 0.9462 - val_loss: 4.8226 - val_categorical_accuracy: 0.1204 - val_auc: 0.6442 - val_precision: 0.1393 - val_recall: 0.1124 - 87s/epoch - 430ms/step
# Epoch 4/50
# 202/202 - 94s - loss: 0.0893 - categorical_accuracy: 0.9714 - auc: 0.9991 - precision: 0.9742 - recall: 0.9679 - val_loss: 0.0962 - val_categorical_accuracy: 0.9683 - val_auc: 0.9992 - val_precision: 0.9727 - val_recall: 0.9624 - 94s/epoch - 467ms/step
# Epoch 5/50
# 202/202 - 87s - loss: 0.0583 - categorical_accuracy: 0.9814 - auc: 0.9996 - precision: 0.9835 - recall: 0.9791 - val_loss: 0.0368 - val_categorical_accuracy: 0.9876 - val_auc: 0.9996 - val_precision: 0.9883 - val_recall: 0.9876 - 87s/epoch - 432ms/step
# Epoch 6/50
# 202/202 - 87s - loss: 0.0529 - categorical_accuracy: 0.9823 - auc: 0.9994 - precision: 0.9836 - recall: 0.9816 - val_loss: 0.0354 - val_categorical_accuracy: 0.9876 - val_auc: 0.9998 - val_precision: 0.9883 - val_recall: 0.9876 - 87s/epoch - 429ms/step
# Epoch 7/50
# 202/202 - 87s - loss: 0.0341 - categorical_accuracy: 0.9885 - auc: 0.9998 - precision: 0.9901 - recall: 0.9874 - val_loss: 0.0499 - val_categorical_accuracy: 0.9836 - val_auc: 0.9991 - val_precision: 0.9839 - val_recall: 0.9832 - 87s/epoch - 429ms/step
# Epoch 8/50
# 202/202 - 87s - loss: 0.0426 - categorical_accuracy: 0.9855 - auc: 0.9996 - precision: 0.9862 - recall: 0.9846 - val_loss: 0.0253 - val_categorical_accuracy: 0.9931 - val_auc: 0.9996 - val_precision: 0.9934 - val_recall: 0.9927 - 87s/epoch - 430ms/step
# Epoch 9/50
# 202/202 - 87s - loss: 0.0347 - categorical_accuracy: 0.9883 - auc: 0.9997 - precision: 0.9894 - recall: 0.9881 - val_loss: 0.0133 - val_categorical_accuracy: 0.9964 - val_auc: 1.0000 - val_precision: 0.9964 - val_recall: 0.9964 - 87s/epoch - 431ms/step
# Epoch 10/50
# 202/202 - 95s - loss: 0.0244 - categorical_accuracy: 0.9919 - auc: 0.9998 - precision: 0.9926 - recall: 0.9915 - val_loss: 0.0202 - val_categorical_accuracy: 0.9934 - val_auc: 0.9996 - val_precision: 0.9942 - val_recall: 0.9931 - 95s/epoch - 469ms/step
# Epoch 11/50
# 202/202 - 86s - loss: 0.0206 - categorical_accuracy: 0.9938 - auc: 0.9998 - precision: 0.9941 - recall: 0.9933 - val_loss: 0.0374 - val_categorical_accuracy: 0.9880 - val_auc: 0.9990 - val_precision: 0.9883 - val_recall: 0.9880 - 86s/epoch - 427ms/step
# Epoch 12/50
# 202/202 - 87s - loss: 0.0238 - categorical_accuracy: 0.9927 - auc: 0.9997 - precision: 0.9934 - recall: 0.9923 - val_loss: 0.0716 - val_categorical_accuracy: 0.9829 - val_auc: 0.9982 - val_precision: 0.9843 - val_recall: 0.9821 - 87s/epoch - 431ms/step
# Epoch 13/50
# 202/202 - 87s - loss: 0.0213 - categorical_accuracy: 0.9926 - auc: 0.9999 - precision: 0.9934 - recall: 0.9919 - val_loss: 0.0352 - val_categorical_accuracy: 0.9901 - val_auc: 0.9994 - val_precision: 0.9905 - val_recall: 0.9901 - 87s/epoch - 429ms/step
# Epoch 14/50
# 202/202 - 87s - loss: 0.0217 - categorical_accuracy: 0.9930 - auc: 0.9999 - precision: 0.9934 - recall: 0.9930 - val_loss: 0.0137 - val_categorical_accuracy: 0.9974 - val_auc: 0.9996 - val_precision: 0.9974 - val_recall: 0.9974 - 87s/epoch - 432ms/step
# Epoch 15/50
# 202/202 - 87s - loss: 0.0154 - categorical_accuracy: 0.9954 - auc: 0.9999 - precision: 0.9957 - recall: 0.9950 - val_loss: 0.0707 - val_categorical_accuracy: 0.9839 - val_auc: 0.9974 - val_precision: 0.9839 - val_recall: 0.9839 - 87s/epoch - 430ms/step
# Epoch 16/50
# 202/202 - 87s - loss: 0.0216 - categorical_accuracy: 0.9936 - auc: 0.9997 - precision: 0.9936 - recall: 0.9933 - val_loss: 0.0472 - val_categorical_accuracy: 0.9891 - val_auc: 0.9983 - val_precision: 0.9898 - val_recall: 0.9887 - 87s/epoch - 429ms/step
# Epoch 17/50
# 202/202 - 87s - loss: 0.0139 - categorical_accuracy: 0.9950 - auc: 1.0000 - precision: 0.9953 - recall: 0.9945 - val_loss: 0.0265 - val_categorical_accuracy: 0.9891 - val_auc: 0.9998 - val_precision: 0.9894 - val_recall: 0.9891 - 87s/epoch - 430ms/step
# Epoch 18/50
# 202/202 - 87s - loss: 0.0191 - categorical_accuracy: 0.9934 - auc: 0.9998 - precision: 0.9937 - recall: 0.9932 - val_loss: 0.0299 - val_categorical_accuracy: 0.9909 - val_auc: 0.9995 - val_precision: 0.9920 - val_recall: 0.9909 - 87s/epoch - 430ms/step
# Epoch 19/50
# 202/202 - 87s - loss: 0.0184 - categorical_accuracy: 0.9940 - auc: 0.9997 - precision: 0.9946 - recall: 0.9938 - val_loss: 0.0143 - val_categorical_accuracy: 0.9960 - val_auc: 0.9998 - val_precision: 0.9964 - val_recall: 0.9960 - 87s/epoch - 429ms/step
# Epoch 20/50
# 202/202 - 87s - loss: 0.0142 - categorical_accuracy: 0.9964 - auc: 0.9998 - precision: 0.9964 - recall: 0.9964 - val_loss: 0.0139 - val_categorical_accuracy: 0.9964 - val_auc: 0.9998 - val_precision: 0.9964 - val_recall: 0.9964 - 87s/epoch - 430ms/step
# Epoch 21/50
# 202/202 - 86s - loss: 0.0088 - categorical_accuracy: 0.9975 - auc: 1.0000 - precision: 0.9975 - recall: 0.9974 - val_loss: 0.0111 - val_categorical_accuracy: 0.9953 - val_auc: 1.0000 - val_precision: 0.9953 - val_recall: 0.9953 - 86s/epoch - 428ms/step
# Epoch 22/50
# 202/202 - 87s - loss: 0.0183 - categorical_accuracy: 0.9942 - auc: 0.9997 - precision: 0.9945 - recall: 0.9940 - val_loss: 0.0150 - val_categorical_accuracy: 0.9964 - val_auc: 0.9998 - val_precision: 0.9964 - val_recall: 0.9960 - 87s/epoch - 431ms/step
# Epoch 23/50
# 202/202 - 87s - loss: 0.0096 - categorical_accuracy: 0.9964 - auc: 1.0000 - precision: 0.9965 - recall: 0.9962 - val_loss: 0.0361 - val_categorical_accuracy: 0.9883 - val_auc: 0.9991 - val_precision: 0.9890 - val_recall: 0.9876 - 87s/epoch - 429ms/step
# Epoch 24/50
# 202/202 - 87s - loss: 0.0186 - categorical_accuracy: 0.9933 - auc: 0.9998 - precision: 0.9938 - recall: 0.9932 - val_loss: 0.0242 - val_categorical_accuracy: 0.9920 - val_auc: 0.9994 - val_precision: 0.9923 - val_recall: 0.9916 - 87s/epoch - 431ms/step
# Epoch 25/50
# 202/202 - 87s - loss: 0.0112 - categorical_accuracy: 0.9967 - auc: 0.9998 - precision: 0.9968 - recall: 0.9967 - val_loss: 0.0060 - val_categorical_accuracy: 0.9985 - val_auc: 0.9998 - val_precision: 0.9985 - val_recall: 0.9982 - 87s/epoch - 431ms/step
# Epoch 26/50
# 202/202 - 95s - loss: 0.0117 - categorical_accuracy: 0.9957 - auc: 0.9999 - precision: 0.9958 - recall: 0.9954 - val_loss: 0.0218 - val_categorical_accuracy: 0.9942 - val_auc: 0.9994 - val_precision: 0.9942 - val_recall: 0.9938 - 95s/epoch - 469ms/step
# Epoch 27/50
# 202/202 - 87s - loss: 0.0095 - categorical_accuracy: 0.9966 - auc: 1.0000 - precision: 0.9967 - recall: 0.9964 - val_loss: 0.0085 - val_categorical_accuracy: 0.9967 - val_auc: 1.0000 - val_precision: 0.9967 - val_recall: 0.9967 - 87s/epoch - 428ms/step
# Epoch 28/50
# 202/202 - 86s - loss: 0.0120 - categorical_accuracy: 0.9960 - auc: 0.9999 - precision: 0.9962 - recall: 0.9959 - val_loss: 0.0285 - val_categorical_accuracy: 0.9945 - val_auc: 0.9989 - val_precision: 0.9945 - val_recall: 0.9945 - 86s/epoch - 428ms/step
# Epoch 29/50
# 202/202 - 86s - loss: 0.0046 - categorical_accuracy: 0.9985 - auc: 1.0000 - precision: 0.9986 - recall: 0.9985 - val_loss: 0.0037 - val_categorical_accuracy: 0.9982 - val_auc: 1.0000 - val_precision: 0.9982 - val_recall: 0.9982 - 86s/epoch - 426ms/step
# Epoch 30/50
# 202/202 - 87s - loss: 0.0060 - categorical_accuracy: 0.9981 - auc: 1.0000 - precision: 0.9981 - recall: 0.9980 - val_loss: 0.0990 - val_categorical_accuracy: 0.9763 - val_auc: 0.9974 - val_precision: 0.9766 - val_recall: 0.9763 - 87s/epoch - 430ms/step
# Epoch 31/50
# 202/202 - 87s - loss: 0.0171 - categorical_accuracy: 0.9952 - auc: 0.9997 - precision: 0.9953 - recall: 0.9952 - val_loss: 0.0193 - val_categorical_accuracy: 0.9942 - val_auc: 0.9996 - val_precision: 0.9942 - val_recall: 0.9942 - 87s/epoch - 428ms/step
# Epoch 32/50
# 202/202 - 86s - loss: 0.0156 - categorical_accuracy: 0.9947 - auc: 0.9998 - precision: 0.9949 - recall: 0.9945 - val_loss: 0.0184 - val_categorical_accuracy: 0.9938 - val_auc: 0.9996 - val_precision: 0.9949 - val_recall: 0.9934 - 86s/epoch - 427ms/step
# Epoch 33/50
# 202/202 - 87s - loss: 0.0114 - categorical_accuracy: 0.9967 - auc: 0.9997 - precision: 0.9970 - recall: 0.9966 - val_loss: 0.0180 - val_categorical_accuracy: 0.9938 - val_auc: 0.9995 - val_precision: 0.9938 - val_recall: 0.9938 - 87s/epoch - 428ms/step
# Epoch 34/50
# 202/202 - 87s - loss: 0.0138 - categorical_accuracy: 0.9964 - auc: 0.9997 - precision: 0.9966 - recall: 0.9963 - val_loss: 0.0363 - val_categorical_accuracy: 0.9909 - val_auc: 0.9989 - val_precision: 0.9909 - val_recall: 0.9909 - 87s/epoch - 429ms/step
# Epoch 35/50
# 202/202 - 88s - loss: 0.0071 - categorical_accuracy: 0.9983 - auc: 0.9998 - precision: 0.9984 - recall: 0.9982 - val_loss: 0.0077 - val_categorical_accuracy: 0.9974 - val_auc: 0.9998 - val_precision: 0.9974 - val_recall: 0.9974 - 88s/epoch - 435ms/step
# Epoch 36/50
# 202/202 - 87s - loss: 0.0155 - categorical_accuracy: 0.9955 - auc: 0.9998 - precision: 0.9957 - recall: 0.9952 - val_loss: 0.0665 - val_categorical_accuracy: 0.9843 - val_auc: 0.9979 - val_precision: 0.9850 - val_recall: 0.9843 - 87s/epoch - 431ms/step
# Epoch 37/50
# 202/202 - 88s - loss: 0.0141 - categorical_accuracy: 0.9955 - auc: 0.9998 - precision: 0.9957 - recall: 0.9954 - val_loss: 0.0171 - val_categorical_accuracy: 0.9960 - val_auc: 0.9998 - val_precision: 0.9960 - val_recall: 0.9956 - 88s/epoch - 436ms/step
# Epoch 38/50
# 202/202 - 87s - loss: 0.0035 - categorical_accuracy: 0.9989 - auc: 1.0000 - precision: 0.9990 - recall: 0.9989 - val_loss: 0.0036 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 87s/epoch - 432ms/step
# Epoch 39/50
# 202/202 - 86s - loss: 0.0061 - categorical_accuracy: 0.9983 - auc: 0.9999 - precision: 0.9985 - recall: 0.9981 - val_loss: 0.0060 - val_categorical_accuracy: 0.9989 - val_auc: 0.9998 - val_precision: 0.9989 - val_recall: 0.9989 - 86s/epoch - 427ms/step
# Epoch 40/50
# 202/202 - 87s - loss: 0.0055 - categorical_accuracy: 0.9983 - auc: 1.0000 - precision: 0.9987 - recall: 0.9982 - val_loss: 0.0030 - val_categorical_accuracy: 0.9985 - val_auc: 1.0000 - val_precision: 0.9985 - val_recall: 0.9985 - 87s/epoch - 430ms/step
# Epoch 41/50
# 202/202 - 86s - loss: 0.0057 - categorical_accuracy: 0.9983 - auc: 0.9998 - precision: 0.9986 - recall: 0.9982 - val_loss: 0.0324 - val_categorical_accuracy: 0.9931 - val_auc: 0.9985 - val_precision: 0.9931 - val_recall: 0.9931 - 86s/epoch - 428ms/step
# Epoch 42/50
# 202/202 - 86s - loss: 0.0078 - categorical_accuracy: 0.9974 - auc: 1.0000 - precision: 0.9974 - recall: 0.9974 - val_loss: 0.0067 - val_categorical_accuracy: 0.9985 - val_auc: 0.9998 - val_precision: 0.9985 - val_recall: 0.9982 - 86s/epoch - 427ms/step
# Epoch 43/50
# 202/202 - 87s - loss: 0.0017 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0082 - val_categorical_accuracy: 0.9971 - val_auc: 1.0000 - val_precision: 0.9971 - val_recall: 0.9971 - 87s/epoch - 433ms/step
# Epoch 44/50
# 202/202 - 87s - loss: 0.0144 - categorical_accuracy: 0.9957 - auc: 0.9998 - precision: 0.9959 - recall: 0.9957 - val_loss: 0.0092 - val_categorical_accuracy: 0.9974 - val_auc: 0.9998 - val_precision: 0.9978 - val_recall: 0.9974 - 87s/epoch - 429ms/step
# Epoch 45/50
# 202/202 - 89s - loss: 0.0046 - categorical_accuracy: 0.9989 - auc: 0.9999 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0169 - val_categorical_accuracy: 0.9953 - val_auc: 0.9994 - val_precision: 0.9953 - val_recall: 0.9949 - 89s/epoch - 439ms/step
# Epoch 46/50
# 202/202 - 87s - loss: 0.0049 - categorical_accuracy: 0.9987 - auc: 0.9999 - precision: 0.9987 - recall: 0.9985 - val_loss: 0.0114 - val_categorical_accuracy: 0.9964 - val_auc: 0.9996 - val_precision: 0.9964 - val_recall: 0.9964 - 87s/epoch - 432ms/step
# Epoch 47/50
# 202/202 - 88s - loss: 0.0148 - categorical_accuracy: 0.9956 - auc: 0.9997 - precision: 0.9958 - recall: 0.9955 - val_loss: 0.0436 - val_categorical_accuracy: 0.9865 - val_auc: 0.9989 - val_precision: 0.9865 - val_recall: 0.9861 - 88s/epoch - 435ms/step
# Epoch 48/50
# 202/202 - 86s - loss: 0.0164 - categorical_accuracy: 0.9949 - auc: 0.9998 - precision: 0.9953 - recall: 0.9947 - val_loss: 0.0056 - val_categorical_accuracy: 0.9985 - val_auc: 1.0000 - val_precision: 0.9985 - val_recall: 0.9985 - 86s/epoch - 428ms/step
# Epoch 49/50
# 202/202 - 87s - loss: 0.0034 - categorical_accuracy: 0.9988 - auc: 1.0000 - precision: 0.9988 - recall: 0.9988 - val_loss: 0.0036 - val_categorical_accuracy: 0.9989 - val_auc: 1.0000 - val_precision: 0.9989 - val_recall: 0.9989 - 87s/epoch - 431ms/step
# Epoch 50/50
# 202/202 - 86s - loss: 0.0023 - categorical_accuracy: 0.9991 - auc: 1.0000 - precision: 0.9991 - recall: 0.9991 - val_loss: 0.0144 - val_categorical_accuracy: 0.9964 - val_auc: 0.9996 - val_precision: 0.9964 - val_recall: 0.9964 - 86s/epoch - 427ms/step
# ===================================
# 50 epochs in 89.80137404998143 min

# %%
hist_df = pd.DataFrame(Lmobilenet_v3_hist.history)
hist_json_file = 'LMobileNe_v3_50ep_histori.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = Lmobilenet_v3.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 34s 12ms/step - loss: 0.0064 - categorical_accuracy: 0.9979 - auc: 1.0000 - precision: 0.9979 - recall: 0.9979

# %%
report(Lmobilenet_v3)
# Out:
# 2815/2815 [==============================] - 27s 9ms/step
# [[[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2627    2]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2626    3]
#   [   0  186]]
#
#  [[2629    0]
#   [   6  180]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2754    0]
#   [   0   61]]
#
#  [[2753    0]
#   [   0   62]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       186
#            1       1.00      1.00      1.00       186
#            2       0.99      1.00      1.00       186
#            3       1.00      1.00      1.00       186
#            4       1.00      1.00      1.00       186
#            5       0.99      1.00      0.99       186
#            6       1.00      1.00      1.00       186
#            7       0.98      1.00      0.99       186
#            8       1.00      0.97      0.98       186
#            9       1.00      1.00      1.00       186
#           10       1.00      1.00      1.00       186
#           11       1.00      1.00      1.00       186
#           12       1.00      1.00      1.00       186
#           13       1.00      1.00      1.00        61
#           14       1.00      1.00      1.00        62
#           15       1.00      1.00      1.00       274
#
#     accuracy                           1.00      2815
#    macro avg       1.00      1.00      1.00      2815
# weighted avg       1.00      1.00      1.00      2815

# %%
Smobilenet_v3 = MobileNet_v3(size='Small',input_shape=(256,256,3))
Smobilenet_v3.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
Smobilenet_v3.count_params()
# Out:
# 1697078

# %%
start = time()
Smobilenet_v3_hist = Smobilenet_v3.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/50
# 2023-08-29 11:20:12.529983: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inMobileNetv3_Small/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 202/202 - 181s - loss: 1.4272 - categorical_accuracy: 0.5061 - auc: 0.9207 - precision: 0.8856 - recall: 0.3107 - val_loss: 2.9916 - val_categorical_accuracy: 0.0657 - val_auc: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 181s/epoch - 895ms/step
# Epoch 2/50
# 202/202 - 75s - loss: 0.3291 - categorical_accuracy: 0.8871 - auc: 0.9941 - precision: 0.9201 - recall: 0.8524 - val_loss: 4.0762 - val_categorical_accuracy: 0.0668 - val_auc: 0.5051 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 75s/epoch - 371ms/step
# Epoch 3/50
# 202/202 - 74s - loss: 0.1562 - categorical_accuracy: 0.9482 - auc: 0.9981 - precision: 0.9586 - recall: 0.9395 - val_loss: 5.1023 - val_categorical_accuracy: 0.1142 - val_auc: 0.5843 - val_precision: 0.2085 - val_recall: 0.1040 - 74s/epoch - 367ms/step
# Epoch 4/50
# 202/202 - 74s - loss: 0.1035 - categorical_accuracy: 0.9663 - auc: 0.9990 - precision: 0.9703 - recall: 0.9628 - val_loss: 0.1856 - val_categorical_accuracy: 0.9376 - val_auc: 0.9989 - val_precision: 0.9476 - val_recall: 0.9300 - 74s/epoch - 369ms/step
# Epoch 5/50
# 202/202 - 75s - loss: 0.0811 - categorical_accuracy: 0.9730 - auc: 0.9992 - precision: 0.9760 - recall: 0.9696 - val_loss: 0.0489 - val_categorical_accuracy: 0.9832 - val_auc: 0.9995 - val_precision: 0.9846 - val_recall: 0.9829 - 75s/epoch - 369ms/step
# Epoch 6/50
# 202/202 - 74s - loss: 0.0662 - categorical_accuracy: 0.9778 - auc: 0.9995 - precision: 0.9800 - recall: 0.9754 - val_loss: 0.0440 - val_categorical_accuracy: 0.9865 - val_auc: 0.9993 - val_precision: 0.9872 - val_recall: 0.9858 - 74s/epoch - 368ms/step
# Epoch 7/50
# 202/202 - 75s - loss: 0.0480 - categorical_accuracy: 0.9836 - auc: 0.9995 - precision: 0.9851 - recall: 0.9820 - val_loss: 0.0409 - val_categorical_accuracy: 0.9883 - val_auc: 0.9996 - val_precision: 0.9887 - val_recall: 0.9876 - 75s/epoch - 371ms/step
# Epoch 8/50
# 202/202 - 74s - loss: 0.0336 - categorical_accuracy: 0.9885 - auc: 0.9998 - precision: 0.9900 - recall: 0.9873 - val_loss: 0.0388 - val_categorical_accuracy: 0.9872 - val_auc: 0.9996 - val_precision: 0.9872 - val_recall: 0.9869 - 74s/epoch - 365ms/step
# Epoch 9/50
# 202/202 - 75s - loss: 0.0338 - categorical_accuracy: 0.9892 - auc: 0.9997 - precision: 0.9899 - recall: 0.9888 - val_loss: 0.0282 - val_categorical_accuracy: 0.9920 - val_auc: 0.9994 - val_precision: 0.9920 - val_recall: 0.9920 - 75s/epoch - 369ms/step
# Epoch 10/50
# 202/202 - 74s - loss: 0.0276 - categorical_accuracy: 0.9914 - auc: 0.9998 - precision: 0.9918 - recall: 0.9906 - val_loss: 0.0437 - val_categorical_accuracy: 0.9861 - val_auc: 0.9994 - val_precision: 0.9876 - val_recall: 0.9854 - 74s/epoch - 368ms/step
# Epoch 11/50
# 202/202 - 74s - loss: 0.0374 - categorical_accuracy: 0.9876 - auc: 0.9996 - precision: 0.9886 - recall: 0.9868 - val_loss: 0.0497 - val_categorical_accuracy: 0.9861 - val_auc: 0.9990 - val_precision: 0.9865 - val_recall: 0.9858 - 74s/epoch - 366ms/step
# Epoch 12/50
# 202/202 - 75s - loss: 0.0241 - categorical_accuracy: 0.9923 - auc: 0.9999 - precision: 0.9926 - recall: 0.9916 - val_loss: 0.0538 - val_categorical_accuracy: 0.9832 - val_auc: 0.9990 - val_precision: 0.9843 - val_recall: 0.9825 - 75s/epoch - 373ms/step
# Epoch 13/50
# 202/202 - 75s - loss: 0.0228 - categorical_accuracy: 0.9926 - auc: 0.9998 - precision: 0.9932 - recall: 0.9922 - val_loss: 0.2724 - val_categorical_accuracy: 0.9642 - val_auc: 0.9892 - val_precision: 0.9646 - val_recall: 0.9642 - 75s/epoch - 371ms/step
# Epoch 14/50
# 202/202 - 75s - loss: 0.0302 - categorical_accuracy: 0.9910 - auc: 0.9996 - precision: 0.9915 - recall: 0.9905 - val_loss: 0.1079 - val_categorical_accuracy: 0.9734 - val_auc: 0.9971 - val_precision: 0.9748 - val_recall: 0.9723 - 75s/epoch - 370ms/step
# Epoch 15/50
# 202/202 - 74s - loss: 0.0185 - categorical_accuracy: 0.9942 - auc: 0.9998 - precision: 0.9944 - recall: 0.9941 - val_loss: 0.0371 - val_categorical_accuracy: 0.9883 - val_auc: 0.9992 - val_precision: 0.9890 - val_recall: 0.9880 - 74s/epoch - 367ms/step
# Epoch 16/50
# 202/202 - 74s - loss: 0.0210 - categorical_accuracy: 0.9934 - auc: 0.9998 - precision: 0.9938 - recall: 0.9926 - val_loss: 0.0222 - val_categorical_accuracy: 0.9927 - val_auc: 0.9998 - val_precision: 0.9934 - val_recall: 0.9920 - 74s/epoch - 368ms/step
# Epoch 17/50
# 202/202 - 75s - loss: 0.0148 - categorical_accuracy: 0.9955 - auc: 0.9999 - precision: 0.9957 - recall: 0.9952 - val_loss: 0.0182 - val_categorical_accuracy: 0.9953 - val_auc: 0.9996 - val_precision: 0.9953 - val_recall: 0.9953 - 75s/epoch - 373ms/step
# Epoch 18/50
# 202/202 - 74s - loss: 0.0180 - categorical_accuracy: 0.9943 - auc: 0.9998 - precision: 0.9947 - recall: 0.9940 - val_loss: 0.0202 - val_categorical_accuracy: 0.9923 - val_auc: 1.0000 - val_precision: 0.9923 - val_recall: 0.9916 - 74s/epoch - 368ms/step
# Epoch 19/50
# 202/202 - 74s - loss: 0.0143 - categorical_accuracy: 0.9954 - auc: 0.9999 - precision: 0.9957 - recall: 0.9954 - val_loss: 0.0362 - val_categorical_accuracy: 0.9894 - val_auc: 0.9989 - val_precision: 0.9898 - val_recall: 0.9891 - 74s/epoch - 365ms/step
# Epoch 20/50
# 202/202 - 82s - loss: 0.0091 - categorical_accuracy: 0.9971 - auc: 1.0000 - precision: 0.9973 - recall: 0.9971 - val_loss: 0.0460 - val_categorical_accuracy: 0.9883 - val_auc: 0.9985 - val_precision: 0.9883 - val_recall: 0.9883 - 82s/epoch - 407ms/step
# Epoch 21/50
# 202/202 - 75s - loss: 0.0105 - categorical_accuracy: 0.9971 - auc: 0.9999 - precision: 0.9973 - recall: 0.9970 - val_loss: 0.0199 - val_categorical_accuracy: 0.9931 - val_auc: 0.9996 - val_precision: 0.9934 - val_recall: 0.9931 - 75s/epoch - 369ms/step
# Epoch 22/50
# 202/202 - 73s - loss: 0.0213 - categorical_accuracy: 0.9936 - auc: 0.9997 - precision: 0.9937 - recall: 0.9934 - val_loss: 0.0250 - val_categorical_accuracy: 0.9923 - val_auc: 0.9994 - val_precision: 0.9923 - val_recall: 0.9920 - 73s/epoch - 362ms/step
# Epoch 23/50
# 202/202 - 73s - loss: 0.0182 - categorical_accuracy: 0.9941 - auc: 0.9997 - precision: 0.9946 - recall: 0.9936 - val_loss: 0.0206 - val_categorical_accuracy: 0.9920 - val_auc: 1.0000 - val_precision: 0.9927 - val_recall: 0.9916 - 73s/epoch - 364ms/step
# Epoch 24/50
# 202/202 - 74s - loss: 0.0113 - categorical_accuracy: 0.9968 - auc: 0.9998 - precision: 0.9970 - recall: 0.9967 - val_loss: 0.0175 - val_categorical_accuracy: 0.9949 - val_auc: 0.9998 - val_precision: 0.9949 - val_recall: 0.9949 - 74s/epoch - 364ms/step
# Epoch 25/50
# 202/202 - 74s - loss: 0.0147 - categorical_accuracy: 0.9957 - auc: 0.9998 - precision: 0.9957 - recall: 0.9951 - val_loss: 0.0547 - val_categorical_accuracy: 0.9865 - val_auc: 0.9983 - val_precision: 0.9865 - val_recall: 0.9854 - 74s/epoch - 365ms/step
# Epoch 26/50
# 202/202 - 75s - loss: 0.0122 - categorical_accuracy: 0.9955 - auc: 1.0000 - precision: 0.9957 - recall: 0.9951 - val_loss: 0.0342 - val_categorical_accuracy: 0.9876 - val_auc: 0.9998 - val_precision: 0.9876 - val_recall: 0.9869 - 75s/epoch - 372ms/step
# Epoch 27/50
# 202/202 - 75s - loss: 0.0174 - categorical_accuracy: 0.9954 - auc: 0.9996 - precision: 0.9954 - recall: 0.9953 - val_loss: 0.0125 - val_categorical_accuracy: 0.9960 - val_auc: 0.9998 - val_precision: 0.9963 - val_recall: 0.9956 - 75s/epoch - 370ms/step
# Epoch 28/50
# 202/202 - 73s - loss: 0.0126 - categorical_accuracy: 0.9963 - auc: 0.9998 - precision: 0.9964 - recall: 0.9960 - val_loss: 0.0130 - val_categorical_accuracy: 0.9953 - val_auc: 0.9998 - val_precision: 0.9953 - val_recall: 0.9953 - 73s/epoch - 361ms/step
# Epoch 29/50
# 202/202 - 73s - loss: 0.0185 - categorical_accuracy: 0.9941 - auc: 0.9998 - precision: 0.9943 - recall: 0.9940 - val_loss: 0.0685 - val_categorical_accuracy: 0.9829 - val_auc: 0.9978 - val_precision: 0.9843 - val_recall: 0.9825 - 73s/epoch - 363ms/step
# Epoch 30/50
# 202/202 - 73s - loss: 0.0124 - categorical_accuracy: 0.9963 - auc: 0.9998 - precision: 0.9964 - recall: 0.9961 - val_loss: 0.0123 - val_categorical_accuracy: 0.9949 - val_auc: 1.0000 - val_precision: 0.9949 - val_recall: 0.9945 - 73s/epoch - 361ms/step
# Epoch 31/50
# 202/202 - 74s - loss: 0.0065 - categorical_accuracy: 0.9979 - auc: 0.9999 - precision: 0.9979 - recall: 0.9979 - val_loss: 0.0251 - val_categorical_accuracy: 0.9923 - val_auc: 0.9993 - val_precision: 0.9931 - val_recall: 0.9923 - 74s/epoch - 364ms/step
# Epoch 32/50
# 202/202 - 74s - loss: 0.0091 - categorical_accuracy: 0.9973 - auc: 0.9999 - precision: 0.9973 - recall: 0.9972 - val_loss: 0.0310 - val_categorical_accuracy: 0.9916 - val_auc: 0.9987 - val_precision: 0.9920 - val_recall: 0.9912 - 74s/epoch - 365ms/step
# Epoch 33/50
# 202/202 - 74s - loss: 0.0050 - categorical_accuracy: 0.9986 - auc: 0.9999 - precision: 0.9988 - recall: 0.9986 - val_loss: 0.0217 - val_categorical_accuracy: 0.9938 - val_auc: 0.9994 - val_precision: 0.9938 - val_recall: 0.9938 - 74s/epoch - 364ms/step
# Epoch 34/50
# 202/202 - 74s - loss: 0.0181 - categorical_accuracy: 0.9943 - auc: 0.9996 - precision: 0.9947 - recall: 0.9943 - val_loss: 0.0183 - val_categorical_accuracy: 0.9927 - val_auc: 1.0000 - val_precision: 0.9931 - val_recall: 0.9927 - 74s/epoch - 367ms/step
# Epoch 35/50
# 202/202 - 74s - loss: 0.0155 - categorical_accuracy: 0.9953 - auc: 0.9998 - precision: 0.9954 - recall: 0.9950 - val_loss: 0.0130 - val_categorical_accuracy: 0.9960 - val_auc: 0.9996 - val_precision: 0.9960 - val_recall: 0.9960 - 74s/epoch - 364ms/step
# Epoch 36/50
# 202/202 - 74s - loss: 0.0132 - categorical_accuracy: 0.9960 - auc: 0.9998 - precision: 0.9962 - recall: 0.9958 - val_loss: 0.0170 - val_categorical_accuracy: 0.9953 - val_auc: 0.9996 - val_precision: 0.9953 - val_recall: 0.9953 - 74s/epoch - 367ms/step
# Epoch 37/50
# 202/202 - 74s - loss: 0.0060 - categorical_accuracy: 0.9981 - auc: 1.0000 - precision: 0.9981 - recall: 0.9981 - val_loss: 0.0107 - val_categorical_accuracy: 0.9960 - val_auc: 0.9998 - val_precision: 0.9960 - val_recall: 0.9956 - 74s/epoch - 367ms/step
# Epoch 38/50
# 202/202 - 74s - loss: 0.0047 - categorical_accuracy: 0.9984 - auc: 1.0000 - precision: 0.9984 - recall: 0.9984 - val_loss: 0.0070 - val_categorical_accuracy: 0.9985 - val_auc: 0.9998 - val_precision: 0.9985 - val_recall: 0.9982 - 74s/epoch - 367ms/step
# Epoch 39/50
# 202/202 - 75s - loss: 0.0071 - categorical_accuracy: 0.9980 - auc: 0.9998 - precision: 0.9981 - recall: 0.9978 - val_loss: 0.0295 - val_categorical_accuracy: 0.9909 - val_auc: 0.9996 - val_precision: 0.9912 - val_recall: 0.9909 - 75s/epoch - 371ms/step
# Epoch 40/50
# 202/202 - 75s - loss: 0.0035 - categorical_accuracy: 0.9988 - auc: 1.0000 - precision: 0.9988 - recall: 0.9988 - val_loss: 0.0239 - val_categorical_accuracy: 0.9945 - val_auc: 0.9991 - val_precision: 0.9949 - val_recall: 0.9945 - 75s/epoch - 372ms/step
# Epoch 41/50
# 202/202 - 73s - loss: 0.0093 - categorical_accuracy: 0.9972 - auc: 0.9998 - precision: 0.9974 - recall: 0.9971 - val_loss: 0.0107 - val_categorical_accuracy: 0.9956 - val_auc: 0.9998 - val_precision: 0.9956 - val_recall: 0.9956 - 73s/epoch - 363ms/step
# Epoch 42/50
# 202/202 - 73s - loss: 0.0089 - categorical_accuracy: 0.9970 - auc: 0.9998 - precision: 0.9971 - recall: 0.9968 - val_loss: 0.0140 - val_categorical_accuracy: 0.9953 - val_auc: 0.9998 - val_precision: 0.9956 - val_recall: 0.9953 - 73s/epoch - 362ms/step
# Epoch 43/50
# 202/202 - 72s - loss: 0.0120 - categorical_accuracy: 0.9962 - auc: 0.9997 - precision: 0.9962 - recall: 0.9960 - val_loss: 0.0747 - val_categorical_accuracy: 0.9839 - val_auc: 0.9978 - val_precision: 0.9839 - val_recall: 0.9832 - 72s/epoch - 359ms/step
# Epoch 44/50
# 202/202 - 73s - loss: 0.0096 - categorical_accuracy: 0.9971 - auc: 0.9998 - precision: 0.9973 - recall: 0.9969 - val_loss: 0.0063 - val_categorical_accuracy: 0.9971 - val_auc: 1.0000 - val_precision: 0.9971 - val_recall: 0.9971 - 73s/epoch - 360ms/step
# Epoch 45/50
# 202/202 - 73s - loss: 0.0081 - categorical_accuracy: 0.9981 - auc: 0.9997 - precision: 0.9982 - recall: 0.9981 - val_loss: 0.0099 - val_categorical_accuracy: 0.9960 - val_auc: 1.0000 - val_precision: 0.9964 - val_recall: 0.9960 - 73s/epoch - 363ms/step
# Epoch 46/50
# 202/202 - 83s - loss: 0.0032 - categorical_accuracy: 0.9991 - auc: 1.0000 - precision: 0.9992 - recall: 0.9991 - val_loss: 0.0482 - val_categorical_accuracy: 0.9909 - val_auc: 0.9985 - val_precision: 0.9909 - val_recall: 0.9909 - 83s/epoch - 412ms/step
# Epoch 47/50
# 202/202 - 75s - loss: 0.0073 - categorical_accuracy: 0.9974 - auc: 1.0000 - precision: 0.9974 - recall: 0.9974 - val_loss: 0.0063 - val_categorical_accuracy: 0.9985 - val_auc: 0.9998 - val_precision: 0.9989 - val_recall: 0.9985 - 75s/epoch - 372ms/step
# Epoch 48/50
# 202/202 - 73s - loss: 0.0038 - categorical_accuracy: 0.9991 - auc: 0.9999 - precision: 0.9991 - recall: 0.9991 - val_loss: 0.0087 - val_categorical_accuracy: 0.9964 - val_auc: 1.0000 - val_precision: 0.9964 - val_recall: 0.9964 - 73s/epoch - 362ms/step
# Epoch 49/50
# 202/202 - 73s - loss: 0.0079 - categorical_accuracy: 0.9971 - auc: 1.0000 - precision: 0.9971 - recall: 0.9971 - val_loss: 0.0150 - val_categorical_accuracy: 0.9949 - val_auc: 0.9994 - val_precision: 0.9949 - val_recall: 0.9949 - 73s/epoch - 361ms/step
# Epoch 50/50
# 202/202 - 73s - loss: 0.0092 - categorical_accuracy: 0.9972 - auc: 0.9999 - precision: 0.9975 - recall: 0.9971 - val_loss: 0.0196 - val_categorical_accuracy: 0.9942 - val_auc: 1.0000 - val_precision: 0.9942 - val_recall: 0.9938 - 73s/epoch - 362ms/step
# ===================================
# 50 epochs in 65.80653533538182 min

# %%
hist_df = pd.DataFrame(Smobilenet_v3_hist.history)
hist_json_file = 'SMobileNe_v3_10ep_histori.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = Smobilenet_v3.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 34s 12ms/step - loss: 0.0215 - categorical_accuracy: 0.9929 - auc: 1.0000 - precision: 0.9929 - recall: 0.9929

# %%
report(Smobilenet_v3)
# Out:
# 2815/2815 [==============================] - 22s 8ms/step
# [[[2629    0]
#   [   8  178]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2628    1]
#   [   1  185]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2620    9]
#   [   1  185]]
#
#  [[2625    4]
#   [   1  185]]
#
#  [[2629    0]
#   [   3  183]]
#
#  [[2626    3]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2626    3]
#   [   4  182]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   2  184]]
#
#  [[2754    0]
#   [   0   61]]
#
#  [[2753    0]
#   [   0   62]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       186
#            1       1.00      1.00      1.00       186
#            2       0.99      0.99      0.99       186
#            3       1.00      1.00      1.00       186
#            4       1.00      1.00      1.00       186
#            5       0.95      0.99      0.97       186
#            6       0.98      0.99      0.99       186
#            7       1.00      0.98      0.99       186
#            8       0.98      1.00      0.99       186
#            9       1.00      1.00      1.00       186
#           10       0.98      0.98      0.98       186
#           11       1.00      1.00      1.00       186
#           12       1.00      0.99      0.99       186
#           13       1.00      1.00      1.00        61
#           14       1.00      1.00      1.00        62
#           15       1.00      1.00      1.00       274
#
#     accuracy                           0.99      2815
#    macro avg       0.99      0.99      0.99      2815
# weighted avg       0.99      0.99      0.99      2815

# %% [markdown]
# ## ResNet under 50

# %%
def identity_block(x, filter):
    x_skip = x
    
    act = 'relu'
    
    x = Conv2D(filters=filter, kernel_size=(3,3), padding='same')(x)
    x = BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation(act)(x)
    
    x = Conv2D(filters=filter, kernel_size=(3,3), padding='same')(x)
    x = BatchNormalization(axis=3)(x)
    
    x = tf.keras.layers.Add()([x, x_skip])
    x = tf.keras.layers.Activation(act)(x)
    
    return x

def convolutional_block(x, filter):
    x_skip = x
    
    act = 'relu'
    
    x = Conv2D(filters=filter, kernel_size=(3,3), padding='same', strides=2)(x)
    x = BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation(act)(x)
    
    x = Conv2D(filters=filter, kernel_size=(3,3), padding='same')(x)
    x = BatchNormalization(axis=3)(x)
    
    x_skip = Conv2D(filters=filter, kernel_size=1, strides=2)(x_skip)
    
    x = tf.keras.layers.Add()([x, x_skip])
    x = tf.keras.layers.Activation(act)(x)
    return x

# %%
def ResNet(layers=18, input_shape=(256,256,3)):
    
    filters = 64
    act = 'relu'
    
    input = Input(shape=input_shape)
    #x = tf.keras.layers.ZeroPadding2D((3,3))(x_input)
    
    x = Conv2D(filters=filters, kernel_size=(7,7), strides=2)(input)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation(act)(x)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    
    if layers == 18:
        block_layers = [2,2,2,2]
    if layers == 34:
        block_layers = [3,4,6,3]
    for i in range(4):
        if i == 0:
            for j in range(block_layers[i]):
                x = identity_block(x, filters)
        else:
            filters = filters*2
            x = convolutional_block(x, filters)
            for j in range(block_layers[i] - 1):
                x = identity_block(x, filters)
    
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = Flatten()(x)
    x = Dropout(0.5)(x)
    output = Dense(units=16, activation='softmax')(x)
    
    model = Model(inputs=input, outputs=output, name='ResNet18')
    
    return model

# %%
resnet18 = ResNet(input_shape=(256,256,3))
resnet18.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
resnet18.count_params()
# Out:
# 11195536

# %%
start = time()
resnet18_hist = resnet18.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/50
# 2023-08-29 14:54:44.671959: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResNet18/dropout_3/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 202/202 - 206s - loss: 0.5763 - categorical_accuracy: 0.8168 - auc: 0.9843 - precision: 0.9010 - recall: 0.7639 - val_loss: 3.1902 - val_categorical_accuracy: 0.0657 - val_auc: 0.5657 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 -
# Epoch 12/50
# 202/202 - 79s - loss: 0.0187 - categorical_accuracy: 0.9940 - auc: 0.9997 - precision: 0.9946 - recall: 0.9936 - val_loss: 0.1321 - val_categorical_accuracy: 0.9555 - val_auc: 0.9984 - val_precision: 0.9638 - val_recall: 0.9522 - 79s/epoch - 389ms/step
# Epoch 13/50
# 202/202 - 78s - loss: 0.0197 - categorical_accuracy: 0.9945 - auc: 0.9997 - precision: 0.9950 - recall: 0.9943 - val_loss: 0.0347 - val_categorical_accuracy: 0.9894 - val_auc: 1.0000 - val_precision: 0.9905 - val_recall: 0.9872 - 78s/epoch - 384ms/step
# Epoch 14/50
# 202/202 - 78s - loss: 0.0122 - categorical_accuracy: 0.9965 - auc: 0.9999 - precision: 0.9969 - recall: 0.9962 - val_loss: 0.0396 - val_categorical_accuracy: 0.9876 - val_auc: 1.0000 - val_precision: 0.9905 - val_recall: 0.9854 - 78s/epoch - 387ms/step
# Epoch 15/50
# 202/202 - 77s - loss: 0.0117 - categorical_accuracy: 0.9965 - auc: 0.9999 - precision: 0.9966 - recall: 0.9964 - val_loss: 0.9586 - val_categorical_accuracy: 0.8034 - val_auc: 0.9634 - val_precision: 0.8141 - val_recall: 0.7939 - 77s/epoch - 383ms/step
# Epoch 16/50
# 202/202 - 79s - loss: 0.0213 - categorical_accuracy: 0.9942 - auc: 0.9999 - precision: 0.9944 - recall: 0.9938 - val_loss: 0.1117 - val_categorical_accuracy: 0.9679 - val_auc: 0.9975 - val_precision: 0.9693 - val_recall: 0.9661 - 79s/epoch - 389ms/step
# Epoch 17/50
# 202/202 - 77s - loss: 0.0099 - categorical_accuracy: 0.9965 - auc: 1.0000 - precision: 0.9969 - recall: 0.9963 - val_loss: 0.0409 - val_categorical_accuracy: 0.9880 - val_auc: 0.9994 - val_precision: 0.9883 - val_recall: 0.9876 - 77s/epoch - 383ms/step
# Epoch 18/50
# 202/202 - 77s - loss: 0.0142 - categorical_accuracy: 0.9956 - auc: 0.9998 - precision: 0.9957 - recall: 0.9951 - val_loss: 0.0607 - val_categorical_accuracy: 0.9763 - val_auc: 0.9996 - val_precision: 0.9780 - val_recall: 0.9752 - 77s/epoch - 384ms/step
# Epoch 19/50
# 202/202 - 77s - loss: 0.0266 - categorical_accuracy: 0.9921 - auc: 0.9996 - precision: 0.9926 - recall: 0.9916 - val_loss: 0.3996 - val_categorical_accuracy: 0.8843 - val_auc: 0.9890 - val_precision: 0.8915 - val_recall: 0.8785 - 77s/epoch - 380ms/step
# Epoch 20/50
# 202/202 - 76s - loss: 0.0094 - categorical_accuracy: 0.9974 - auc: 0.9999 - precision: 0.9976 - recall: 0.9972 - val_loss: 0.0272 - val_categorical_accuracy: 0.9923 - val_auc: 0.9998 - val_precision: 0.9938 - val_recall: 0.9916 - 76s/epoch - 379ms/step
# Epoch 21/50
# 202/202 - 77s - loss: 0.0044 - categorical_accuracy: 0.9988 - auc: 1.0000 - precision: 0.9990 - recall: 0.9988 - val_loss: 0.0400 - val_categorical_accuracy: 0.9850 - val_auc: 0.9996 - val_precision: 0.9854 - val_recall: 0.9847 - 77s/epoch - 380ms/step
# Epoch 22/50
# 202/202 - 77s - loss: 0.0063 - categorical_accuracy: 0.9987 - auc: 0.9998 - precision: 0.9988 - recall: 0.9987 - val_loss: 0.0122 - val_categorical_accuracy: 0.9971 - val_auc: 0.9998 - val_precision: 0.9974 - val_recall: 0.9971 - 77s/epoch - 380ms/step
# Epoch 23/50
# 202/202 - 76s - loss: 0.0039 - categorical_accuracy: 0.9988 - auc: 1.0000 - precision: 0.9989 - recall: 0.9988 - val_loss: 0.0346 - val_categorical_accuracy: 0.9898 - val_auc: 0.9996 - val_precision: 0.9898 - val_recall: 0.9876 - 76s/epoch - 378ms/step
# Epoch 24/50
# 202/202 - 77s - loss: 0.0147 - categorical_accuracy: 0.9960 - auc: 0.9998 - precision: 0.9962 - recall: 0.9957 - val_loss: 0.0483 - val_categorical_accuracy: 0.9865 - val_auc: 0.9996 - val_precision: 0.9879 - val_recall: 0.9858 - 77s/epoch - 380ms/step
# Epoch 25/50
# 202/202 - 76s - loss: 0.0126 - categorical_accuracy: 0.9964 - auc: 0.9998 - precision: 0.9967 - recall: 0.9961 - val_loss: 0.0441 - val_categorical_accuracy: 0.9880 - val_auc: 0.9992 - val_precision: 0.9883 - val_recall: 0.9869 - 76s/epoch - 375ms/step
# Epoch 26/50
# 202/202 - 77s - loss: 0.0062 - categorical_accuracy: 0.9982 - auc: 0.9999 - precision: 0.9982 - recall: 0.9982 - val_loss: 0.0266 - val_categorical_accuracy: 0.9920 - val_auc: 0.9998 - val_precision: 0.9923 - val_recall: 0.9920 - 77s/epoch - 380ms/step
# Epoch 27/50
# 202/202 - 76s - loss: 0.0241 - categorical_accuracy: 0.9932 - auc: 0.9996 - precision: 0.9936 - recall: 0.9925 - val_loss: 0.3018 - val_categorical_accuracy: 0.9201 - val_auc: 0.9926 - val_precision: 0.9296 - val_recall: 0.9154 - 76s/epoch - 378ms/step
# Epoch 28/50
# 202/202 - 76s - loss: 0.0108 - categorical_accuracy: 0.9973 - auc: 0.9998 - precision: 0.9975 - recall: 0.9971 - val_loss: 0.2084 - val_categorical_accuracy: 0.9427 - val_auc: 0.9944 - val_precision: 0.9473 - val_recall: 0.9376 - 76s/epoch - 376ms/step
# Epoch 29/50
# 202/202 - 77s - loss: 8.3189e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0265 - val_categorical_accuracy: 0.9909 - val_auc: 0.9996 - val_precision: 0.9916 - val_recall: 0.9909 - 77s/epoch - 381ms/step
# Epoch 30/50
# 202/202 - 76s - loss: 0.0033 - categorical_accuracy: 0.9993 - auc: 0.9999 - precision: 0.9993 - recall: 0.9993 - val_loss: 0.0642 - val_categorical_accuracy: 0.9777 - val_auc: 0.9991 - val_precision: 0.9827 - val_recall: 0.9745 - 76s/epoch - 379ms/step
# Epoch 31/50
# 202/202 - 76s - loss: 0.0070 - categorical_accuracy: 0.9980 - auc: 1.0000 - precision: 0.9981 - recall: 0.9979 - val_loss: 0.0158 - val_categorical_accuracy: 0.9953 - val_auc: 1.0000 - val_precision: 0.9967 - val_recall: 0.9938 - 76s/epoch - 377ms/step
# Epoch 32/50
# 202/202 - 76s - loss: 0.0124 - categorical_accuracy: 0.9969 - auc: 0.9998 - precision: 0.9971 - recall: 0.9967 - val_loss: 0.0376 - val_categorical_accuracy: 0.9858 - val_auc: 1.0000 - val_precision: 0.9886 - val_recall: 0.9850 - 76s/epoch - 375ms/step
# Epoch 33/50
# 202/202 - 76s - loss: 0.0209 - categorical_accuracy: 0.9942 - auc: 0.9996 - precision: 0.9946 - recall: 0.9936 - val_loss: 0.0346 - val_categorical_accuracy: 0.9887 - val_auc: 0.9996 - val_precision: 0.9898 - val_recall: 0.9869 - 76s/epoch - 378ms/step
# Epoch 34/50
# 202/202 - 76s - loss: 0.0016 - categorical_accuracy: 0.9996 - auc: 1.0000 - precision: 0.9996 - recall: 0.9996 - val_loss: 0.0162 - val_categorical_accuracy: 0.9953 - val_auc: 0.9998 - val_precision: 0.9960 - val_recall: 0.9942 - 76s/epoch - 377ms/step
# Epoch 35/50
# 202/202 - 76s - loss: 0.0042 - categorical_accuracy: 0.9988 - auc: 0.9999 - precision: 0.9988 - recall: 0.9988 - val_loss: 0.0273 - val_categorical_accuracy: 0.9909 - val_auc: 0.9998 - val_precision: 0.9923 - val_recall: 0.9909 - 76s/epoch - 378ms/step
# Epoch 36/50
# 202/202 - 76s - loss: 0.0026 - categorical_accuracy: 0.9992 - auc: 1.0000 - precision: 0.9993 - recall: 0.9992 - val_loss: 0.0280 - val_categorical_accuracy: 0.9916 - val_auc: 0.9996 - val_precision: 0.9927 - val_recall: 0.9905 - 76s/epoch - 377ms/step
# Epoch 37/50
# 202/202 - 76s - loss: 6.8303e-04 - categorical_accuracy: 0.9999 - auc: 1.0000 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0119 - val_categorical_accuracy: 0.9960 - val_auc: 1.0000 - val_precision: 0.9960 - val_recall: 0.9960 - 76s/epoch - 378ms/step
# Epoch 38/50
# 202/202 - 76s - loss: 0.0019 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.1264 - val_categorical_accuracy: 0.9646 - val_auc: 0.9972 - val_precision: 0.9702 - val_recall: 0.9617 - 76s/epoch - 375ms/step
# Epoch 39/50
# 202/202 - 76s - loss: 0.0258 - categorical_accuracy: 0.9933 - auc: 0.9997 - precision: 0.9934 - recall: 0.9926 - val_loss: 0.0481 - val_categorical_accuracy: 0.9861 - val_auc: 0.9996 - val_precision: 0.9875 - val_recall: 0.9836 - 76s/epoch - 375ms/step
# Epoch 40/50
# 202/202 - 76s - loss: 0.0312 - categorical_accuracy: 0.9914 - auc: 0.9993 - precision: 0.9919 - recall: 0.9909 - val_loss: 0.0654 - val_categorical_accuracy: 0.9763 - val_auc: 0.9998 - val_precision: 0.9798 - val_recall: 0.9726 - 76s/epoch - 376ms/step
# Epoch 41/50
# 202/202 - 76s - loss: 0.0061 - categorical_accuracy: 0.9981 - auc: 1.0000 - precision: 0.9981 - recall: 0.9977 - val_loss: 0.0157 - val_categorical_accuracy: 0.9949 - val_auc: 1.0000 - val_precision: 0.9956 - val_recall: 0.9942 - 76s/epoch - 375ms/step
# Epoch 42/50
# 202/202 - 76s - loss: 0.0011 - categorical_accuracy: 0.9996 - auc: 1.0000 - precision: 0.9996 - recall: 0.9996 - val_loss: 0.0150 - val_categorical_accuracy: 0.9934 - val_auc: 1.0000 - val_precision: 0.9942 - val_recall: 0.9931 - 76s/epoch - 377ms/step
# Epoch 43/50
# 202/202 - 76s - loss: 0.0014 - categorical_accuracy: 0.9994 - auc: 1.0000 - precision: 0.9994 - recall: 0.9994 - val_loss: 0.0244 - val_categorical_accuracy: 0.9916 - val_auc: 1.0000 - val_precision: 0.9923 - val_recall: 0.9894 - 76s/epoch - 378ms/step
# Epoch 44/50
# 202/202 - 77s - loss: 0.0040 - categorical_accuracy: 0.9990 - auc: 0.9999 - precision: 0.9991 - recall: 0.9988 - val_loss: 0.0161 - val_categorical_accuracy: 0.9953 - val_auc: 1.0000 - val_precision: 0.9953 - val_recall: 0.9945 - 77s/epoch - 379ms/step
# Epoch 45/50
# 202/202 - 76s - loss: 2.4428e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0123 - val_categorical_accuracy: 0.9949 - val_auc: 1.0000 - val_precision: 0.9956 - val_recall: 0.9945 - 76s/epoch - 375ms/step
# Epoch 46/50
# 202/202 - 77s - loss: 0.0017 - categorical_accuracy: 0.9996 - auc: 1.0000 - precision: 0.9997 - recall: 0.9996 - val_loss: 0.0326 - val_categorical_accuracy: 0.9891 - val_auc: 0.9998 - val_precision: 0.9898 - val_recall: 0.9883 - 77s/epoch - 383ms/step
# Epoch 47/50
# 202/202 - 76s - loss: 0.0234 - categorical_accuracy: 0.9929 - auc: 0.9997 - precision: 0.9933 - recall: 0.9926 - val_loss: 0.0209 - val_categorical_accuracy: 0.9938 - val_auc: 0.9998 - val_precision: 0.9945 - val_recall: 0.9931 - 76s/epoch - 375ms/step
# Epoch 48/50
# 202/202 - 76s - loss: 0.0043 - categorical_accuracy: 0.9988 - auc: 1.0000 - precision: 0.9989 - recall: 0.9987 - val_loss: 0.0192 - val_categorical_accuracy: 0.9923 - val_auc: 0.9998 - val_precision: 0.9931 - val_recall: 0.9920 - 76s/epoch - 374ms/step
# Epoch 49/50
# 202/202 - 76s - loss: 0.0082 - categorical_accuracy: 0.9974 - auc: 0.9999 - precision: 0.9978 - recall: 0.9974 - val_loss: 0.0147 - val_categorical_accuracy: 0.9949 - val_auc: 1.0000 - val_precision: 0.9960 - val_recall: 0.9942 - 76s/epoch - 378ms/step
# Epoch 50/50
# 202/202 - 77s - loss: 0.0041 - categorical_accuracy: 0.9987 - auc: 1.0000 - precision: 0.9987 - recall: 0.9984 - val_loss: 0.0213 - val_categorical_accuracy: 0.9934 - val_auc: 0.9998 - val_precision: 0.9938 - val_recall: 0.9931 - 77s/epoch - 380ms/step
# ===================================
# 50 epochs in 67.88028220335643 min

# %%
hist_df = pd.DataFrame(resnet18_hist.history)
hist_json_file = 'ResNet18_10ep_histori.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = resnet18.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 33s 12ms/step - loss: 0.0176 - categorical_accuracy: 0.9950 - auc: 0.9997 - precision: 0.9950 - recall: 0.9950

# %%
report(resnet18)
# Out:
# 2815/2815 [==============================] - 15s 5ms/step
# [[[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2623    6]
#   [   0  186]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2629    0]
#   [   6  180]]
#
#  [[2628    1]
#   [   4  182]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2625    4]
#   [   0  186]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2754    0]
#   [   0   61]]
#
#  [[2753    0]
#   [   0   62]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       186
#            1       1.00      0.99      1.00       186
#            2       1.00      0.99      1.00       186
#            3       1.00      1.00      1.00       186
#            4       1.00      1.00      1.00       186
#            5       0.97      1.00      0.98       186
#            6       1.00      0.99      1.00       186
#            7       1.00      0.99      1.00       186
#            8       1.00      0.97      0.98       186
#            9       0.99      0.98      0.99       186
#           10       0.99      1.00      1.00       186
#           11       0.98      1.00      0.99       186
#           12       0.99      1.00      1.00       186
#           13       1.00      1.00      1.00        61
#           14       1.00      1.00      1.00        62
#           15       1.00      1.00      1.00       274
#
#     accuracy                           1.00      2815
#    macro avg       1.00      1.00      1.00      2815
# weighted avg       1.00      1.00      1.00      2815

# %%
resnet34 = ResNet(layers=34,input_shape=(256,256,3))
resnet34.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
resnet34.count_params()
# Out:
# 21314832

# %%
start = time()
resnet34_hist = resnet34.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/50
# 2023-08-29 16:28:38.258383: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResNet18/dropout_5/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 202/202 - 117s - loss: 0.7384 - categorical_accuracy: 0.8053 - auc: 0.9815 - precision: 0.8839 - recall: 0.7611 - val_loss: 3.7026 - val_categorical_accuracy: 0.0668 - val_auc: 0.5124 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 117s/epoch - 581ms/step
# Epoch 2/50
# 202/202 - 80s - loss: 0.1338 - categorical_accuracy: 0.9564 - auc: 0.9978 - precision: 0.9618 - recall: 0.9531 - val_loss: 4.2773 - val_categorical_accuracy: 0.0668 - val_auc: 0.5604 - val_precision: 0.0684 - val_recall: 0.0668 - 80s/epoch - 398ms/step
# Epoch 3/50
# 202/202 - 80s - loss: 0.0737 - categorical_accuracy: 0.9764 - auc: 0.9989 - precision: 0.9788 - recall: 0.9743 - val_loss: 3.4140 - val_categorical_accuracy: 0.2149 - val_auc: 0.8326 - val_precision: 0.2164 - val_recall: 0.1795 - 80s/epoch - 397ms/step
# Epoch 4/50
# 202/202 - 81s - loss: 0.0572 - categorical_accuracy: 0.9819 - auc: 0.9994 - precision: 0.9832 - recall: 0.9810 - val_loss: 0.2173 - val_categorical_accuracy: 0.9252 - val_auc: 0.9978 - val_precision: 0.9355 - val_recall: 0.9157 - 81s/epoch - 402ms/step
# Epoch 5/50
# 202/202 - 81s - loss: 0.0604 - categorical_accuracy: 0.9818 - auc: 0.9990 - precision: 0.9833 - recall: 0.9811 - val_loss: 0.3724 - val_categorical_accuracy: 0.8661 - val_auc: 0.9946 - val_precision: 0.8833 - val_recall: 0.8530 - 81s/epoch - 402ms/step
# Epoch 6/50
# 202/202 - 81s - loss: 0.0545 - categorical_accuracy: 0.9833 - auc: 0.9991 - precision: 0.9839 - recall: 0.9826 - val_loss: 0.8095 - val_categorical_accuracy: 0.7953 - val_auc: 0.9785 - val_precision: 0.8183 - val_recall: 0.7753 - 81s/epoch - 400ms/step
# Epoch 7/50
# 202/202 - 81s - loss: 0.0323 - categorical_accuracy: 0.9901 - auc: 0.9996 - precision: 0.9908 - recall: 0.9895 - val_loss: 0.0857 - val_categorical_accuracy: 0.9712 - val_auc: 0.9997 - val_precision: 0.9742 - val_recall: 0.9661 - 81s/epoch - 399ms/step
# Epoch 8/50
# 202/202 - 82s - loss: 0.0242 - categorical_accuracy: 0.9924 - auc: 0.9997 - precision: 0.9926 - recall: 0.9920 - val_loss: 0.2506 - val_categorical_accuracy: 0.9238 - val_auc: 0.9946 - val_precision: 0.9284 - val_recall: 0.9179 - 82s/epoch - 405ms/step
# Epoch 9/50
# 202/202 - 81s - loss: 0.0390 - categorical_accuracy: 0.9879 - auc: 0.9993 - precision: 0.9891 - recall: 0.9870 - val_loss: 0.1635 - val_categorical_accuracy: 0.9500 - val_auc: 0.9972 - val_precision: 0.9533 - val_recall: 0.9460 - 81s/epoch - 400ms/step
# Epoch 10/50
# 202/202 - 81s - loss: 0.0284 - categorical_accuracy: 0.9916 - auc: 0.9996 - precision: 0.9924 - recall: 0.9909 - val_loss: 0.2203 - val_categorical_accuracy: 0.9278 - val_auc: 0.9967 - val_precision: 0.9356 - val_recall: 0.9223 - 81s/epoch - 401ms/step
# Epoch 11/50
# 202/202 - 81s - loss: 0.0264 - categorical_accuracy: 0.9918 - auc: 0.9995 - precision: 0.9920 - recall: 0.9914 - val_loss: 0.1150 - val_categorical_accuracy: 0.9624 - val_auc: 0.9980 - val_precision: 0.9672 - val_recall: 0.9577 - 81s/epoch - 402ms/step
# Epoch 12/50
# 202/202 - 80s - loss: 0.0142 - categorical_accuracy: 0.9954 - auc: 0.9998 - precision: 0.9957 - recall: 0.9954 - val_loss: 0.1523 - val_categorical_accuracy: 0.9486 - val_auc: 0.9991 - val_precision: 0.9540 - val_recall: 0.9372 - 80s/epoch - 398ms/step
# Epoch 13/50
# 202/202 - 81s - loss: 0.0253 - categorical_accuracy: 0.9923 - auc: 0.9996 - precision: 0.9929 - recall: 0.9919 - val_loss: 0.0207 - val_categorical_accuracy: 0.9956 - val_auc: 0.9996 - val_precision: 0.9960 - val_recall: 0.9953 - 81s/epoch - 401ms/step
# Epoch 14/50
# 202/202 - 80s - loss: 0.0287 - categorical_accuracy: 0.9923 - auc: 0.9994 - precision: 0.9930 - recall: 0.9917 - val_loss: 0.4942 - val_categorical_accuracy: 0.8417 - val_auc: 0.9925 - val_precision: 0.8540 - val_recall: 0.8278 - 80s/epoch - 397ms/step
# Epoch 15/50
# 202/202 - 81s - loss: 0.0254 - categorical_accuracy: 0.9921 - auc: 0.9995 - precision: 0.9926 - recall: 0.9917 - val_loss: 0.2565 - val_categorical_accuracy: 0.9113 - val_auc: 0.9978 - val_precision: 0.9284 - val_recall: 0.8982 - 81s/epoch - 402ms/step
# Epoch 16/50
# 202/202 - 81s - loss: 0.0256 - categorical_accuracy: 0.9930 - auc: 0.9996 - precision: 0.9933 - recall: 0.9923 - val_loss: 0.0489 - val_categorical_accuracy: 0.9839 - val_auc: 0.9996 - val_precision: 0.9850 - val_recall: 0.9825 - 81s/epoch - 401ms/step
# Epoch 17/50
# 202/202 - 81s - loss: 0.0066 - categorical_accuracy: 0.9980 - auc: 0.9999 - precision: 0.9981 - recall: 0.9978 - val_loss: 0.0710 - val_categorical_accuracy: 0.9774 - val_auc: 0.9992 - val_precision: 0.9805 - val_recall: 0.9741 - 81s/epoch - 400ms/step
# Epoch 18/50
# 202/202 - 81s - loss: 0.0229 - categorical_accuracy: 0.9924 - auc: 0.9996 - precision: 0.9927 - recall: 0.9924 - val_loss: 0.1105 - val_categorical_accuracy: 0.9661 - val_auc: 0.9993 - val_precision: 0.9719 - val_recall: 0.9595 - 81s/epoch - 399ms/step
# Epoch 19/50
# 202/202 - 81s - loss: 0.0174 - categorical_accuracy: 0.9955 - auc: 0.9996 - precision: 0.9959 - recall: 0.9952 - val_loss: 0.0869 - val_categorical_accuracy: 0.9701 - val_auc: 0.9994 - val_precision: 0.9725 - val_recall: 0.9683 - 81s/epoch - 400ms/step
# Epoch 20/50
# 202/202 - 81s - loss: 0.0162 - categorical_accuracy: 0.9956 - auc: 0.9998 - precision: 0.9960 - recall: 0.9954 - val_loss: 0.3817 - val_categorical_accuracy: 0.8822 - val_auc: 0.9949 - val_precision: 0.8912 - val_recall: 0.8752 - 81s/epoch - 400ms/step
# Epoch 21/50
# 202/202 - 82s - loss: 0.0342 - categorical_accuracy: 0.9892 - auc: 0.9995 - precision: 0.9899 - recall: 0.9888 - val_loss: 0.2041 - val_categorical_accuracy: 0.9329 - val_auc: 0.9970 - val_precision: 0.9408 - val_recall: 0.9281 - 82s/epoch - 406ms/step
# Epoch 22/50
# 202/202 - 82s - loss: 0.0268 - categorical_accuracy: 0.9924 - auc: 0.9994 - precision: 0.9929 - recall: 0.9919 - val_loss: 0.0542 - val_categorical_accuracy: 0.9854 - val_auc: 0.9992 - val_precision: 0.9857 - val_recall: 0.9836 - 82s/epoch - 405ms/step
# Epoch 23/50
# 202/202 - 81s - loss: 0.0050 - categorical_accuracy: 0.9989 - auc: 0.9999 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0245 - val_categorical_accuracy: 0.9949 - val_auc: 0.9996 - val_precision: 0.9953 - val_recall: 0.9942 - 81s/epoch - 400ms/step
# Epoch 24/50
# 202/202 - 81s - loss: 0.0118 - categorical_accuracy: 0.9967 - auc: 0.9998 - precision: 0.9968 - recall: 0.9966 - val_loss: 0.0532 - val_categorical_accuracy: 0.9810 - val_auc: 0.9994 - val_precision: 0.9821 - val_recall: 0.9807 - 81s/epoch - 399ms/step
# Epoch 25/50
# 202/202 - 80s - loss: 0.0102 - categorical_accuracy: 0.9974 - auc: 0.9998 - precision: 0.9977 - recall: 0.9973 - val_loss: 0.0487 - val_categorical_accuracy: 0.9854 - val_auc: 0.9997 - val_precision: 0.9876 - val_recall: 0.9843 - 80s/epoch - 398ms/step
# Epoch 26/50
# 202/202 - 80s - loss: 0.0208 - categorical_accuracy: 0.9946 - auc: 0.9996 - precision: 0.9950 - recall: 0.9944 - val_loss: 0.0872 - val_categorical_accuracy: 0.9686 - val_auc: 0.9993 - val_precision: 0.9703 - val_recall: 0.9668 - 80s/epoch - 397ms/step
# Epoch 27/50
# 202/202 - 82s - loss: 0.0072 - categorical_accuracy: 0.9981 - auc: 0.9998 - precision: 0.9983 - recall: 0.9980 - val_loss: 0.1747 - val_categorical_accuracy: 0.9354 - val_auc: 0.9982 - val_precision: 0.9429 - val_recall: 0.9270 - 82s/epoch - 407ms/step
# Epoch 28/50
# 202/202 - 88s - loss: 0.0029 - categorical_accuracy: 0.9991 - auc: 1.0000 - precision: 0.9993 - recall: 0.9991 - val_loss: 0.0770 - val_categorical_accuracy: 0.9741 - val_auc: 0.9997 - val_precision: 0.9765 - val_recall: 0.9701 - 88s/epoch - 436ms/step
# Epoch 29/50
# 202/202 - 81s - loss: 0.0282 - categorical_accuracy: 0.9916 - auc: 0.9995 - precision: 0.9920 - recall: 0.9912 - val_loss: 0.0955 - val_categorical_accuracy: 0.9653 - val_auc: 0.9996 - val_precision: 0.9705 - val_recall: 0.9602 - 81s/epoch - 399ms/step
# Epoch 30/50
# 202/202 - 81s - loss: 0.0296 - categorical_accuracy: 0.9917 - auc: 0.9992 - precision: 0.9926 - recall: 0.9914 - val_loss: 0.0207 - val_categorical_accuracy: 0.9942 - val_auc: 1.0000 - val_precision: 0.9949 - val_recall: 0.9942 - 81s/epoch - 399ms/step
# Epoch 31/50
# 202/202 - 81s - loss: 0.0070 - categorical_accuracy: 0.9974 - auc: 1.0000 - precision: 0.9975 - recall: 0.9974 - val_loss: 0.0411 - val_categorical_accuracy: 0.9869 - val_auc: 0.9994 - val_precision: 0.9869 - val_recall: 0.9865 - 81s/epoch - 401ms/step
# Epoch 32/50
# 202/202 - 83s - loss: 0.0169 - categorical_accuracy: 0.9950 - auc: 0.9997 - precision: 0.9954 - recall: 0.9947 - val_loss: 0.0776 - val_categorical_accuracy: 0.9767 - val_auc: 0.9988 - val_precision: 0.9784 - val_recall: 0.9734 - 83s/epoch - 412ms/step
# Epoch 33/50
# 202/202 - 81s - loss: 0.0038 - categorical_accuracy: 0.9988 - auc: 1.0000 - precision: 0.9989 - recall: 0.9988 - val_loss: 0.0447 - val_categorical_accuracy: 0.9850 - val_auc: 0.9996 - val_precision: 0.9854 - val_recall: 0.9836 - 81s/epoch - 400ms/step
# Epoch 34/50
# 202/202 - 81s - loss: 0.0152 - categorical_accuracy: 0.9959 - auc: 0.9997 - precision: 0.9962 - recall: 0.9954 - val_loss: 0.1853 - val_categorical_accuracy: 0.9387 - val_auc: 0.9981 - val_precision: 0.9457 - val_recall: 0.9285 - 81s/epoch - 400ms/step
# Epoch 35/50
# 202/202 - 82s - loss: 0.0018 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0237 - val_categorical_accuracy: 0.9912 - val_auc: 0.9998 - val_precision: 0.9920 - val_recall: 0.9909 - 82s/epoch - 407ms/step
# Epoch 36/50
# 202/202 - 82s - loss: 0.0090 - categorical_accuracy: 0.9968 - auc: 0.9998 - precision: 0.9969 - recall: 0.9967 - val_loss: 0.4816 - val_categorical_accuracy: 0.8880 - val_auc: 0.9851 - val_precision: 0.8984 - val_recall: 0.8811 - 82s/epoch - 403ms/step
# Epoch 37/50
# 202/202 - 81s - loss: 0.0362 - categorical_accuracy: 0.9903 - auc: 0.9993 - precision: 0.9915 - recall: 0.9894 - val_loss: 0.0724 - val_categorical_accuracy: 0.9807 - val_auc: 0.9985 - val_precision: 0.9839 - val_recall: 0.9792 - 81s/epoch - 400ms/step
# Epoch 38/50
# 202/202 - 84s - loss: 0.0096 - categorical_accuracy: 0.9966 - auc: 0.9999 - precision: 0.9969 - recall: 0.9964 - val_loss: 0.0295 - val_categorical_accuracy: 0.9920 - val_auc: 0.9994 - val_precision: 0.9923 - val_recall: 0.9912 - 84s/epoch - 418ms/step
# Epoch 39/50
# 202/202 - 81s - loss: 0.0076 - categorical_accuracy: 0.9975 - auc: 0.9999 - precision: 0.9975 - recall: 0.9975 - val_loss: 0.0636 - val_categorical_accuracy: 0.9777 - val_auc: 0.9996 - val_precision: 0.9809 - val_recall: 0.9756 - 81s/epoch - 399ms/step
# Epoch 40/50
# 202/202 - 81s - loss: 0.0060 - categorical_accuracy: 0.9982 - auc: 0.9999 - precision: 0.9983 - recall: 0.9981 - val_loss: 0.0310 - val_categorical_accuracy: 0.9909 - val_auc: 0.9998 - val_precision: 0.9920 - val_recall: 0.9901 - 81s/epoch - 400ms/step
# Epoch 41/50
# 202/202 - 81s - loss: 0.0090 - categorical_accuracy: 0.9972 - auc: 0.9998 - precision: 0.9974 - recall: 0.9971 - val_loss: 0.2064 - val_categorical_accuracy: 0.9387 - val_auc: 0.9959 - val_precision: 0.9453 - val_recall: 0.9325 - 81s/epoch - 401ms/step
# Epoch 42/50
# 202/202 - 84s - loss: 0.0166 - categorical_accuracy: 0.9958 - auc: 0.9997 - precision: 0.9961 - recall: 0.9953 - val_loss: 0.0684 - val_categorical_accuracy: 0.9759 - val_auc: 0.9992 - val_precision: 0.9808 - val_recall: 0.9715 - 84s/epoch - 415ms/step
# Epoch 43/50
# 202/202 - 82s - loss: 0.0043 - categorical_accuracy: 0.9988 - auc: 1.0000 - precision: 0.9989 - recall: 0.9987 - val_loss: 0.0593 - val_categorical_accuracy: 0.9810 - val_auc: 0.9991 - val_precision: 0.9817 - val_recall: 0.9803 - 82s/epoch - 408ms/step
# Epoch 44/50
# 202/202 - 81s - loss: 0.0026 - categorical_accuracy: 0.9990 - auc: 1.0000 - precision: 0.9990 - recall: 0.9989 - val_loss: 0.0277 - val_categorical_accuracy: 0.9927 - val_auc: 0.9994 - val_precision: 0.9931 - val_recall: 0.9916 - 81s/epoch - 402ms/step
# Epoch 45/50
# 202/202 - 81s - loss: 0.0063 - categorical_accuracy: 0.9982 - auc: 0.9999 - precision: 0.9983 - recall: 0.9982 - val_loss: 0.0170 - val_categorical_accuracy: 0.9953 - val_auc: 0.9998 - val_precision: 0.9956 - val_recall: 0.9945 - 81s/epoch - 403ms/step
# Epoch 46/50
# 202/202 - 81s - loss: 0.0126 - categorical_accuracy: 0.9971 - auc: 0.9997 - precision: 0.9974 - recall: 0.9968 - val_loss: 0.0447 - val_categorical_accuracy: 0.9843 - val_auc: 0.9998 - val_precision: 0.9875 - val_recall: 0.9825 - 81s/epoch - 402ms/step
# Epoch 47/50
# 202/202 - 81s - loss: 0.0010 - categorical_accuracy: 0.9997 - auc: 1.0000 - precision: 0.9997 - recall: 0.9997 - val_loss: 0.0172 - val_categorical_accuracy: 0.9953 - val_auc: 0.9998 - val_precision: 0.9956 - val_recall: 0.9953 - 81s/epoch - 403ms/step
# Epoch 48/50
# 202/202 - 81s - loss: 1.9514e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0243 - val_categorical_accuracy: 0.9916 - val_auc: 0.9998 - val_precision: 0.9920 - val_recall: 0.9916 - 81s/epoch - 399ms/step
# Epoch 49/50
# 202/202 - 81s - loss: 1.0399e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0144 - val_categorical_accuracy: 0.9967 - val_auc: 0.9998 - val_precision: 0.9967 - val_recall: 0.9967 - 81s/epoch - 402ms/step
# Epoch 50/50
# 202/202 - 80s - loss: 0.0283 - categorical_accuracy: 0.9926 - auc: 0.9996 - precision: 0.9928 - recall: 0.9916 - val_loss: 0.0525 - val_categorical_accuracy: 0.9818 - val_auc: 0.9994 - val_precision: 0.9846 - val_recall: 0.9807 - 80s/epoch - 398ms/step
# ===================================
# 50 epochs in 71.19745131333669 min

# %%
hist_df = pd.DataFrame(resnet34_hist.history)
hist_json_file = 'ResNet34_50ep_histori.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = resnet34.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 32s 11ms/step - loss: 0.0616 - categorical_accuracy: 0.9805 - auc: 0.9996 - precision: 0.9815 - recall: 0.9776

# %%
report(resnet34)
# Out:
# 2815/2815 [==============================] - 21s 7ms/step
# [[[2629    0]
#   [   1  185]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2626    3]
#   [   1  185]]
#
#  [[2629    0]
#   [   4  182]]
#
#  [[2629    0]
#   [   6  180]]
#
#  [[2619   10]
#   [   1  185]]
#
#  [[2628    1]
#   [  24  162]]
#
#  [[2629    0]
#   [  10  176]]
#
#  [[2618   11]
#   [   5  181]]
#
#  [[2629    0]
#   [   2  184]]
#
#  [[2608   21]
#   [   1  185]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2626    3]
#   [   0  186]]
#
#  [[2748    6]
#   [   0   61]]
#
#  [[2753    0]
#   [   0   62]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       186
#            1       1.00      1.00      1.00       186
#            2       0.98      0.99      0.99       186
#            3       1.00      0.98      0.99       186
#            4       1.00      0.97      0.98       186
#            5       0.95      0.99      0.97       186
#            6       0.99      0.87      0.93       186
#            7       1.00      0.95      0.97       186
#            8       0.94      0.97      0.96       186
#            9       1.00      0.99      0.99       186
#           10       0.90      0.99      0.94       186
#           11       1.00      1.00      1.00       186
#           12       0.98      1.00      0.99       186
#           13       0.91      1.00      0.95        61
#           14       1.00      1.00      1.00        62
#           15       1.00      1.00      1.00       274
#
#     accuracy                           0.98      2815
#    macro avg       0.98      0.98      0.98      2815
# weighted avg       0.98      0.98      0.98      2815

# %% [markdown]
# ## ResNet above 50

# %%
def BN_identity_block(x, filter):
    x_skip = x
    
    act = 'relu'
    
    x = Conv2D(filters=filter, kernel_size=(1,1), padding='valid')(x)
    x = BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation(act)(x)
    
    x = Conv2D(filters=filter, kernel_size=(3,3), padding='same')(x)
    x = BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation(act)(x)
    
    x = Conv2D(filters=filter*4, kernel_size=(1,1), padding='valid')(x)
    x = BatchNormalization(axis=3)(x)
    
    x = tf.keras.layers.Add()([x, x_skip])
    x = tf.keras.layers.Activation(act)(x)
    
    return x

def BN_convolutional_block(x, filter, s):
    x_skip = x
    
    act = 'relu'
    
    x = Conv2D(filters=filter, kernel_size=(1,1), padding='valid', strides=s)(x)
    x = BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation(act)(x)
    
    x = Conv2D(filters=filter, kernel_size=(3,3), padding='same')(x)
    x = BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation(act)(x)
    
    x = Conv2D(filters=filter*4, kernel_size=(1,1), padding='valid')(x)
    x = BatchNormalization(axis=3)(x)
    
    x_skip = Conv2D(filters=filter*4, kernel_size=1, strides=s, padding='valid')(x_skip)
    
    x = tf.keras.layers.Add()([x, x_skip])
    x = tf.keras.layers.Activation(act)(x)
    return x

# %%
def BN_ResNet(input_shape=(256,256,3)):
    
    filters = 64
    act = 'relu'
    
    x_input = Input(shape=input_shape)
    
    x = Conv2D(filters=filters, kernel_size=(7,7), strides=2)(x_input)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation(act)(x)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    
    block_layers = [3,4,6,3]
    for i in range(4):
        if i == 0:
            x = BN_convolutional_block(x=x, filter=filters, s=1)
            for j in range(block_layers[i]-1):
                x = BN_identity_block(x, filters)
        else:
            filters = filters*2
            x = BN_convolutional_block(x, filters, s=2)
            for j in range(block_layers[i] - 1):
                x = BN_identity_block(x, filters)
    
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = Flatten()(x)
    x = Dropout(0.4)(x)
    output = Dense(units=16, activation='softmax')(x)
    
    model = Model(inputs=x_input, outputs=output, name='ResNet50')
    
    return model

# %%
resnet50 = BN_ResNet(input_shape=(256,256,3))
resnet50.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
resnet50.count_params()
# Out:
# 23605136

# %%
start = time()
resnet50_hist = resnet50.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/50
# 2023-08-29 17:47:47.369825: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResNet50/dropout_7/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 202/202 - 153s - loss: 1.1826 - categorical_accuracy: 0.6797 - auc: 0.9591 - precision: 0.8141 - recall: 0.6167 - val_loss: 5.4174 - val_categorical_accuracy: 0.0657 - val_auc: 0.5560 - val_precision: 0.0657 - val_recall: 0.0657 - 153s/epoch - 757ms/step
# Epoch 2/50
# 202/202 - 110s - loss: 0.3020 - categorical_accuracy: 0.8943 - auc: 0.9935 - precision: 0.9090 - recall: 0.8840 - val_loss: 6.6139 - val_categorical_accuracy: 0.0660 - val_auc: 0.5029 - val_precision: 0.0811 - val_recall: 0.0551 - 110s/epoch - 543ms/step
# Epoch 3/50
# 202/202 - 109s - loss: 0.1555 - categorical_accuracy: 0.9480 - auc: 0.9971 - precision: 0.9541 - recall: 0.9442 - val_loss: 7.3525 - val_categorical_accuracy: 0.0890 - val_auc: 0.5694 - val_precision: 0.0982 - val_recall: 0.0719 - 109s/epoch - 541ms/step
# Epoch 4/50
# 202/202 - 110s - loss: 0.1171 - categorical_accuracy: 0.9634 - auc: 0.9977 - precision: 0.9660 - recall: 0.9608 - val_loss: 3.0098 - val_categorical_accuracy: 0.4199 - val_auc: 0.8291 - val_precision: 0.4302 - val_recall: 0.3980 - 110s/epoch - 544ms/step
# Epoch 5/50
# 202/202 - 110s - loss: 0.0701 - categorical_accuracy: 0.9766 - auc: 0.9991 - precision: 0.9785 - recall: 0.9753 - val_loss: 2.6204 - val_categorical_accuracy: 0.4371 - val_auc: 0.8516 - val_precision: 0.4730 - val_recall: 0.4090 - 110s/epoch - 542ms/step
# Epoch 6/50
# 202/202 - 109s - loss: 0.0514 - categorical_accuracy: 0.9845 - auc: 0.9991 - precision: 0.9855 - recall: 0.9838 - val_loss: 2.5262 - val_categorical_accuracy: 0.4378 - val_auc: 0.8798 - val_precision: 0.4951 - val_recall: 0.4239 - 109s/epoch - 541ms/step
# Epoch 7/50
# 202/202 - 109s - loss: 0.0535 - categorical_accuracy: 0.9829 - auc: 0.9989 - precision: 0.9840 - recall: 0.9820 - val_loss: 2.7094 - val_categorical_accuracy: 0.4878 - val_auc: 0.8817 - val_precision: 0.5087 - val_recall: 0.4568 - 109s/epoch - 542ms/step
# Epoch 8/50
# 202/202 - 110s - loss: 0.0323 - categorical_accuracy: 0.9889 - auc: 0.9996 - precision: 0.9895 - recall: 0.9885 - val_loss: 1.8227 - val_categorical_accuracy: 0.6596 - val_auc: 0.9029 - val_precision: 0.6785 - val_recall: 0.6392 - 110s/epoch - 543ms/step
# Epoch 9/50
# 202/202 - 109s - loss: 0.0417 - categorical_accuracy: 0.9875 - auc: 0.9992 - precision: 0.9884 - recall: 0.9871 - val_loss: 1.1509 - val_categorical_accuracy: 0.7067 - val_auc: 0.9533 - val_precision: 0.7221 - val_recall: 0.6957 - 109s/epoch - 541ms/step
# Epoch 10/50
# 202/202 - 110s - loss: 0.0362 - categorical_accuracy: 0.9886 - auc: 0.9994 - precision: 0.9891 - recall: 0.9882 - val_loss: 0.8084 - val_categorical_accuracy: 0.7866 - val_auc: 0.9667 - val_precision: 0.7976 - val_recall: 0.7778 - 110s/epoch - 545ms/step
# Epoch 11/50
# 202/202 - 110s - loss: 0.0278 - categorical_accuracy: 0.9918 - auc: 0.9993 - precision: 0.9922 - recall: 0.9916 - val_loss: 1.0612 - val_categorical_accuracy: 0.7132 - val_auc: 0.9388 - val_precision: 0.7276 - val_recall: 0.6987 - 110s/epoch - 543ms/step
# Epoch 12/50
# 202/202 - 110s - loss: 0.0387 - categorical_accuracy: 0.9881 - auc: 0.9994 - precision: 0.9890 - recall: 0.9871 - val_loss: 0.5212 - val_categorical_accuracy: 0.8763 - val_auc: 0.9632 - val_precision: 0.8862 - val_recall: 0.8668 - 110s/epoch - 542ms/step
# Epoch 13/50
# 202/202 - 109s - loss: 0.0282 - categorical_accuracy: 0.9909 - auc: 0.9997 - precision: 0.9913 - recall: 0.9907 - val_loss: 0.3488 - val_categorical_accuracy: 0.8909 - val_auc: 0.9940 - val_precision: 0.8999 - val_recall: 0.8854 - 109s/epoch - 540ms/step
# Epoch 14/50
# 202/202 - 110s - loss: 0.0171 - categorical_accuracy: 0.9948 - auc: 0.9998 - precision: 0.9949 - recall: 0.9943 - val_loss: 0.3033 - val_categorical_accuracy: 0.8924 - val_auc: 0.9965 - val_precision: 0.9052 - val_recall: 0.8843 - 110s/epoch - 543ms/step
# Epoch 15/50
# 202/202 - 110s - loss: 0.0248 - categorical_accuracy: 0.9937 - auc: 0.9993 - precision: 0.9940 - recall: 0.9935 - val_loss: 0.1902 - val_categorical_accuracy: 0.9245 - val_auc: 0.9983 - val_precision: 0.9356 - val_recall: 0.9165 - 110s/epoch - 543ms/step
# Epoch 16/50
# 202/202 - 110s - loss: 0.0171 - categorical_accuracy: 0.9947 - auc: 0.9998 - precision: 0.9950 - recall: 0.9943 - val_loss: 0.3066 - val_categorical_accuracy: 0.8931 - val_auc: 0.9945 - val_precision: 0.9050 - val_recall: 0.8865 - 110s/epoch - 546ms/step
# Epoch 17/50
# 202/202 - 109s - loss: 0.0467 - categorical_accuracy: 0.9859 - auc: 0.9991 - precision: 0.9867 - recall: 0.9854 - val_loss: 1.7649 - val_categorical_accuracy: 0.6140 - val_auc: 0.9155 - val_precision: 0.6311 - val_recall: 0.6005 - 109s/epoch - 541ms/step
# Epoch 18/50
# 202/202 - 110s - loss: 0.0266 - categorical_accuracy: 0.9912 - auc: 0.9998 - precision: 0.9919 - recall: 0.9908 - val_loss: 0.4008 - val_categorical_accuracy: 0.8957 - val_auc: 0.9890 - val_precision: 0.9115 - val_recall: 0.8865 - 110s/epoch - 544ms/step
# Epoch 19/50
# 202/202 - 109s - loss: 0.0187 - categorical_accuracy: 0.9945 - auc: 0.9995 - precision: 0.9950 - recall: 0.9941 - val_loss: 0.1399 - val_categorical_accuracy: 0.9482 - val_auc: 0.9983 - val_precision: 0.9557 - val_recall: 0.9453 - 109s/epoch - 542ms/step
# Epoch 20/50
# 202/202 - 110s - loss: 0.0249 - categorical_accuracy: 0.9924 - auc: 0.9995 - precision: 0.9930 - recall: 0.9921 - val_loss: 0.2400 - val_categorical_accuracy: 0.9310 - val_auc: 0.9953 - val_precision: 0.9347 - val_recall: 0.9300 - 110s/epoch - 544ms/step
# Epoch 21/50
# 202/202 - 109s - loss: 0.0145 - categorical_accuracy: 0.9950 - auc: 0.9998 - precision: 0.9952 - recall: 0.9948 - val_loss: 0.2113 - val_categorical_accuracy: 0.9278 - val_auc: 0.9962 - val_precision: 0.9367 - val_recall: 0.9238 - 109s/epoch - 542ms/step
# Epoch 22/50
# 202/202 - 110s - loss: 0.0055 - categorical_accuracy: 0.9981 - auc: 1.0000 - precision: 0.9982 - recall: 0.9980 - val_loss: 0.2955 - val_categorical_accuracy: 0.9030 - val_auc: 0.9916 - val_precision: 0.9163 - val_recall: 0.8982 - 110s/epoch - 543ms/step
# Epoch 23/50
# 202/202 - 110s - loss: 0.0087 - categorical_accuracy: 0.9973 - auc: 0.9999 - precision: 0.9974 - recall: 0.9971 - val_loss: 0.0769 - val_categorical_accuracy: 0.9737 - val_auc: 0.9994 - val_precision: 0.9779 - val_recall: 0.9697 - 110s/epoch - 543ms/step
# Epoch 24/50
# 202/202 - 109s - loss: 0.0432 - categorical_accuracy: 0.9886 - auc: 0.9989 - precision: 0.9891 - recall: 0.9882 - val_loss: 0.8430 - val_categorical_accuracy: 0.8004 - val_auc: 0.9757 - val_precision: 0.8082 - val_recall: 0.7931 - 109s/epoch - 541ms/step
# Epoch 25/50
# 202/202 - 109s - loss: 0.0199 - categorical_accuracy: 0.9941 - auc: 0.9997 - precision: 0.9944 - recall: 0.9937 - val_loss: 0.1437 - val_categorical_accuracy: 0.9445 - val_auc: 0.9994 - val_precision: 0.9513 - val_recall: 0.9405 - 109s/epoch - 542ms/step
# Epoch 26/50
# 202/202 - 110s - loss: 0.0099 - categorical_accuracy: 0.9967 - auc: 0.9999 - precision: 0.9970 - recall: 0.9967 - val_loss: 0.1076 - val_categorical_accuracy: 0.9650 - val_auc: 0.9991 - val_precision: 0.9697 - val_recall: 0.9588 - 110s/epoch - 542ms/step
# Epoch 27/50
# 202/202 - 110s - loss: 0.0132 - categorical_accuracy: 0.9957 - auc: 0.9998 - precision: 0.9960 - recall: 0.9956 - val_loss: 0.2859 - val_categorical_accuracy: 0.9234 - val_auc: 0.9932 - val_precision: 0.9316 - val_recall: 0.9197 - 110s/epoch - 544ms/step
# Epoch 28/50
# 202/202 - 109s - loss: 0.0223 - categorical_accuracy: 0.9933 - auc: 0.9997 - precision: 0.9936 - recall: 0.9929 - val_loss: 0.2561 - val_categorical_accuracy: 0.9175 - val_auc: 0.9951 - val_precision: 0.9296 - val_recall: 0.9099 - 109s/epoch - 541ms/step
# Epoch 29/50
# 202/202 - 110s - loss: 0.0126 - categorical_accuracy: 0.9962 - auc: 0.9998 - precision: 0.9964 - recall: 0.9960 - val_loss: 0.3905 - val_categorical_accuracy: 0.8960 - val_auc: 0.9697 - val_precision: 0.9061 - val_recall: 0.8873 - 110s/epoch - 544ms/step
# Epoch 30/50
# 202/202 - 110s - loss: 0.0098 - categorical_accuracy: 0.9971 - auc: 0.9998 - precision: 0.9972 - recall: 0.9968 - val_loss: 0.0729 - val_categorical_accuracy: 0.9734 - val_auc: 0.9996 - val_precision: 0.9776 - val_recall: 0.9697 - 110s/epoch - 547ms/step
# Epoch 31/50
# 202/202 - 110s - loss: 0.0071 - categorical_accuracy: 0.9981 - auc: 1.0000 - precision: 0.9981 - recall: 0.9981 - val_loss: 0.0896 - val_categorical_accuracy: 0.9723 - val_auc: 0.9986 - val_precision: 0.9740 - val_recall: 0.9686 - 110s/epoch - 544ms/step
# Epoch 32/50
# 202/202 - 110s - loss: 0.0133 - categorical_accuracy: 0.9963 - auc: 0.9996 - precision: 0.9964 - recall: 0.9960 - val_loss: 0.2520 - val_categorical_accuracy: 0.9278 - val_auc: 0.9949 - val_precision: 0.9337 - val_recall: 0.9245 - 110s/epoch - 543ms/step
# Epoch 33/50
# 202/202 - 110s - loss: 0.0601 - categorical_accuracy: 0.9837 - auc: 0.9988 - precision: 0.9849 - recall: 0.9824 - val_loss: 0.1875 - val_categorical_accuracy: 0.9318 - val_auc: 0.9983 - val_precision: 0.9422 - val_recall: 0.9270 - 110s/epoch - 543ms/step
# Epoch 34/50
# 202/202 - 109s - loss: 0.0186 - categorical_accuracy: 0.9952 - auc: 0.9996 - precision: 0.9959 - recall: 0.9950 - val_loss: 0.1258 - val_categorical_accuracy: 0.9657 - val_auc: 0.9973 - val_precision: 0.9685 - val_recall: 0.9642 - 109s/epoch - 541ms/step
# Epoch 35/50
# 202/202 - 110s - loss: 0.0113 - categorical_accuracy: 0.9970 - auc: 0.9997 - precision: 0.9971 - recall: 0.9967 - val_loss: 0.1221 - val_categorical_accuracy: 0.9591 - val_auc: 0.9988 - val_precision: 0.9681 - val_recall: 0.9537 - 110s/epoch - 546ms/step
# Epoch 36/50
# 202/202 - 110s - loss: 0.0109 - categorical_accuracy: 0.9974 - auc: 0.9998 - precision: 0.9974 - recall: 0.9972 - val_loss: 0.1856 - val_categorical_accuracy: 0.9362 - val_auc: 0.9966 - val_precision: 0.9407 - val_recall: 0.9318 - 110s/epoch - 546ms/step
# Epoch 37/50
# 202/202 - 110s - loss: 0.0104 - categorical_accuracy: 0.9972 - auc: 0.9998 - precision: 0.9974 - recall: 0.9970 - val_loss: 0.1161 - val_categorical_accuracy: 0.9664 - val_auc: 0.9982 - val_precision: 0.9717 - val_recall: 0.9639 - 110s/epoch - 543ms/step
# Epoch 38/50
# 202/202 - 110s - loss: 0.0107 - categorical_accuracy: 0.9972 - auc: 0.9998 - precision: 0.9974 - recall: 0.9972 - val_loss: 0.1086 - val_categorical_accuracy: 0.9657 - val_auc: 0.9981 - val_precision: 0.9720 - val_recall: 0.9621 - 110s/epoch - 543ms/step
# Epoch 39/50
# 202/202 - 110s - loss: 0.0018 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0559 - val_categorical_accuracy: 0.9836 - val_auc: 0.9992 - val_precision: 0.9861 - val_recall: 0.9814 - 110s/epoch - 546ms/step
# Epoch 40/50
# 202/202 - 110s - loss: 0.0217 - categorical_accuracy: 0.9942 - auc: 0.9995 - precision: 0.9947 - recall: 0.9941 - val_loss: 0.0789 - val_categorical_accuracy: 0.9748 - val_auc: 0.9992 - val_precision: 0.9787 - val_recall: 0.9730 - 110s/epoch - 542ms/step
# Epoch 41/50
# 202/202 - 110s - loss: 0.0144 - categorical_accuracy: 0.9957 - auc: 0.9996 - precision: 0.9959 - recall: 0.9954 - val_loss: 0.1863 - val_categorical_accuracy: 0.9551 - val_auc: 0.9941 - val_precision: 0.9571 - val_recall: 0.9526 - 110s/epoch - 543ms/step
# Epoch 42/50
# 202/202 - 109s - loss: 0.0267 - categorical_accuracy: 0.9926 - auc: 0.9994 - precision: 0.9929 - recall: 0.9922 - val_loss: 0.1063 - val_categorical_accuracy: 0.9624 - val_auc: 0.9997 - val_precision: 0.9668 - val_recall: 0.9573 - 109s/epoch - 542ms/step
# Epoch 43/50
# 202/202 - 109s - loss: 0.0099 - categorical_accuracy: 0.9969 - auc: 0.9998 - precision: 0.9971 - recall: 0.9968 - val_loss: 0.0825 - val_categorical_accuracy: 0.9683 - val_auc: 0.9998 - val_precision: 0.9728 - val_recall: 0.9657 - 109s/epoch - 542ms/step
# Epoch 44/50
# 202/202 - 109s - loss: 0.0088 - categorical_accuracy: 0.9974 - auc: 0.9998 - precision: 0.9976 - recall: 0.9971 - val_loss: 0.2150 - val_categorical_accuracy: 0.9307 - val_auc: 0.9962 - val_precision: 0.9358 - val_recall: 0.9252 - 109s/epoch - 541ms/step
# Epoch 45/50
# 202/202 - 117s - loss: 0.0126 - categorical_accuracy: 0.9962 - auc: 0.9999 - precision: 0.9967 - recall: 0.9960 - val_loss: 0.0398 - val_categorical_accuracy: 0.9880 - val_auc: 0.9998 - val_precision: 0.9898 - val_recall: 0.9869 - 117s/epoch - 578ms/step
# Epoch 46/50
# 202/202 - 109s - loss: 0.0043 - categorical_accuracy: 0.9987 - auc: 0.9999 - precision: 0.9988 - recall: 0.9985 - val_loss: 0.0403 - val_categorical_accuracy: 0.9861 - val_auc: 0.9998 - val_precision: 0.9883 - val_recall: 0.9843 - 109s/epoch - 542ms/step
# Epoch 47/50
# 202/202 - 109s - loss: 0.0064 - categorical_accuracy: 0.9978 - auc: 1.0000 - precision: 0.9978 - recall: 0.9977 - val_loss: 0.0537 - val_categorical_accuracy: 0.9821 - val_auc: 0.9992 - val_precision: 0.9832 - val_recall: 0.9803 - 109s/epoch - 540ms/step
# Epoch 48/50
# 202/202 - 109s - loss: 0.0033 - categorical_accuracy: 0.9990 - auc: 1.0000 - precision: 0.9990 - recall: 0.9989 - val_loss: 0.1141 - val_categorical_accuracy: 0.9807 - val_auc: 0.9962 - val_precision: 0.9817 - val_recall: 0.9803 - 109s/epoch - 541ms/step
# Epoch 49/50
# 202/202 - 109s - loss: 0.0244 - categorical_accuracy: 0.9930 - auc: 0.9995 - precision: 0.9935 - recall: 0.9926 - val_loss: 0.0775 - val_categorical_accuracy: 0.9741 - val_auc: 0.9990 - val_precision: 0.9759 - val_recall: 0.9734 - 109s/epoch - 540ms/step
# Epoch 50/50
# 202/202 - 109s - loss: 0.0222 - categorical_accuracy: 0.9928 - auc: 0.9997 - precision: 0.9933 - recall: 0.9926 - val_loss: 0.0375 - val_categorical_accuracy: 0.9850 - val_auc: 0.9999 - val_precision: 0.9876 - val_recall: 0.9843 - 109s/epoch - 542ms/step
# ===================================
# 50 epochs in 101.8121096889178 min

# %%
hist_df = pd.DataFrame(resnet50_hist.history)
hist_json_file = 'ResNet50_10ep_histori.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = resnet50.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 37s 13ms/step - loss: 0.0317 - categorical_accuracy: 0.9897 - auc: 1.0000 - precision: 0.9915 - recall: 0.9890

# %%
report(resnet50)
# Out:
# 2815/2815 [==============================] - 26s 9ms/step
# [[[2628    1]
#   [   5  181]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2628    1]
#   [   2  184]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2614   15]
#   [   0  186]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2628    1]
#   [  19  167]]
#
#  [[2620    9]
#   [   0  186]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   2  184]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2754    0]
#   [   0   61]]
#
#  [[2753    0]
#   [   0   62]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       186
#            1       1.00      1.00      1.00       186
#            2       0.99      0.99      0.99       186
#            3       1.00      1.00      1.00       186
#            4       1.00      1.00      1.00       186
#            5       0.93      1.00      0.96       186
#            6       0.99      1.00      1.00       186
#            7       0.99      0.90      0.94       186
#            8       0.95      1.00      0.98       186
#            9       0.99      1.00      1.00       186
#           10       1.00      0.99      0.99       186
#           11       1.00      0.99      1.00       186
#           12       1.00      1.00      1.00       186
#           13       1.00      1.00      1.00        61
#           14       1.00      1.00      1.00        62
#           15       1.00      1.00      1.00       274
#
#     accuracy                           0.99      2815
#    macro avg       0.99      0.99      0.99      2815
# weighted avg       0.99      0.99      0.99      2815

# %% [markdown]
# ## DenseNet

# %%
def convolutional_layer(x, filters, kernel=1, strides=1):
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = Conv2D(filters, kernel_size=kernel, strides=strides, padding='same')(x)
    return x

def dense_block(x, layers, filters):
    for _ in range(layers):
        x_d = convolutional_layer(x, 4*filters)
        x_d = convolutional_layer(x_d, filters, kernel=3)
        x = tf.keras.layers.Concatenate()([x_d,x])
    return x

def transition_layer(x):
    x = convolutional_layer(x, filters=x.shape[-1]//2)
    x = tf.keras.layers.AveragePooling2D(2, strides=2, padding='same')(x)
    return x

# %%
def denseNet121(input_shape):
    input = Input(shape=input_shape)
    
    x = Conv2D(filters=64, kernel_size=7, strides=2, padding='same')(input)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    for l in [6,12,24,16]:
        d = dense_block(x, layers=l, filters=32)
        x = Dropout(0.2)(x)
        x = transition_layer(d)
    x = Dropout(0.5)(x)
        
    x = tf.keras.layers.GlobalAveragePooling2D()(d)
    x = Flatten()(x)
    output = Dense(units=16, activation='softmax')(x)
    
    model = Model(inputs=input, outputs=output, name='DenseNet')
    
    return model

# %%
densenet = denseNet121(input_shape=(256,256,3))
densenet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
densenet.count_params()
# Out:
# 7060048

# %%
start = time()
densenet_hist = densenet.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/50
# 202/202 - 211s - loss: 0.5773 - categorical_accuracy: 0.8573 - auc: 0.9921 - precision: 0.9621 - recall: 0.7610 - val_loss: 3.7687 - val_categorical_accuracy: 0.0657 - val_auc: 0.4978 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 211s/epoch - 1s/step
# Epoch 2/50
# 202/202 - 104s - loss: 0.0781 - categorical_accuracy: 0.9778 - auc: 0.9994 - precision: 0.9821 - recall: 0.9736 - val_loss: 4.3804 - val_categorical_accuracy: 0.0657 - val_auc: 0.5243 - val_precision: 0.0657 - val_recall: 0.0657 - 104s/epoch - 515ms/step
# Epoch 3/50
# 202/202 - 104s - loss: 0.0519 - categorical_accuracy: 0.9849 - auc: 0.9994 - precision: 0.9865 - recall: 0.9831 - val_loss: 0.7099 - val_categorical_accuracy: 0.7468 - val_auc: 0.9954 - val_precision: 0.7920 - val_recall: 0.6833 - 104s/epoch - 515ms/step
# Epoch 4/50
# 202/202 - 112s - loss: 0.0257 - categorical_accuracy: 0.9915 - auc: 0.9999 - precision: 0.9925 - recall: 0.9905 - val_loss: 0.0392 - val_categorical_accuracy: 0.9869 - val_auc: 0.9998 - val_precision: 0.9883 - val_recall: 0.9858 - 112s/epoch - 553ms/step
# Epoch 5/50
# 202/202 - 104s - loss: 0.0390 - categorical_accuracy: 0.9885 - auc: 0.9996 - precision: 0.9893 - recall: 0.9875 - val_loss: 0.0327 - val_categorical_accuracy: 0.9909 - val_auc: 0.9996 - val_precision: 0.9920 - val_recall: 0.9901 - 104s/epoch - 515ms/step
# Epoch 6/50
# 202/202 - 104s - loss: 0.0162 - categorical_accuracy: 0.9956 - auc: 0.9999 - precision: 0.9962 - recall: 0.9949 - val_loss: 0.1962 - val_categorical_accuracy: 0.9537 - val_auc: 0.9949 - val_precision: 0.9563 - val_recall: 0.9489 - 104s/epoch - 516ms/step
# Epoch 7/50
# 202/202 - 105s - loss: 0.0157 - categorical_accuracy: 0.9944 - auc: 0.9999 - precision: 0.9950 - recall: 0.9941 - val_loss: 0.1396 - val_categorical_accuracy: 0.9621 - val_auc: 0.9972 - val_precision: 0.9623 - val_recall: 0.9595 - 105s/epoch - 520ms/step
# Epoch 8/50
# 202/202 - 104s - loss: 0.0156 - categorical_accuracy: 0.9952 - auc: 0.9999 - precision: 0.9955 - recall: 0.9950 - val_loss: 0.1520 - val_categorical_accuracy: 0.9562 - val_auc: 0.9959 - val_precision: 0.9569 - val_recall: 0.9555 - 104s/epoch - 517ms/step
# Epoch 9/50
# 202/202 - 104s - loss: 0.0149 - categorical_accuracy: 0.9957 - auc: 0.9999 - precision: 0.9959 - recall: 0.9954 - val_loss: 0.0191 - val_categorical_accuracy: 0.9927 - val_auc: 1.0000 - val_precision: 0.9931 - val_recall: 0.9927 - 104s/epoch - 516ms/step
# Epoch 10/50
# 202/202 - 112s - loss: 0.0299 - categorical_accuracy: 0.9925 - auc: 0.9995 - precision: 0.9936 - recall: 0.9921 - val_loss: 0.0792 - val_categorical_accuracy: 0.9788 - val_auc: 0.9994 - val_precision: 0.9795 - val_recall: 0.9759 - 112s/epoch - 554ms/step
# Epoch 11/50
# 202/202 - 105s - loss: 0.0240 - categorical_accuracy: 0.9922 - auc: 0.9995 - precision: 0.9926 - recall: 0.9919 - val_loss: 0.0113 - val_categorical_accuracy: 0.9967 - val_auc: 0.9998 - val_precision: 0.9971 - val_recall: 0.9960 - 105s/epoch - 517ms/step
# Epoch 12/50
# 202/202 - 105s - loss: 0.0052 - categorical_accuracy: 0.9987 - auc: 0.9999 - precision: 0.9989 - recall: 0.9986 - val_loss: 0.0435 - val_categorical_accuracy: 0.9839 - val_auc: 0.9996 - val_precision: 0.9865 - val_recall: 0.9832 - 105s/epoch - 518ms/step
# Epoch 13/50
# 202/202 - 105s - loss: 0.0111 - categorical_accuracy: 0.9970 - auc: 0.9998 - precision: 0.9971 - recall: 0.9966 - val_loss: 0.0942 - val_categorical_accuracy: 0.9810 - val_auc: 0.9965 - val_precision: 0.9828 - val_recall: 0.9803 - 105s/epoch - 518ms/step
# Epoch 14/50
# 202/202 - 104s - loss: 0.0239 - categorical_accuracy: 0.9936 - auc: 0.9996 - precision: 0.9942 - recall: 0.9933 - val_loss: 0.0445 - val_categorical_accuracy: 0.9865 - val_auc: 0.9991 - val_precision: 0.9865 - val_recall: 0.9858 - 104s/epoch - 517ms/step
# Epoch 15/50
# 202/202 - 104s - loss: 0.0084 - categorical_accuracy: 0.9971 - auc: 1.0000 - precision: 0.9974 - recall: 0.9970 - val_loss: 0.0171 - val_categorical_accuracy: 0.9931 - val_auc: 1.0000 - val_precision: 0.9938 - val_recall: 0.9927 - 104s/epoch - 516ms/step
# Epoch 16/50
# 202/202 - 105s - loss: 0.0070 - categorical_accuracy: 0.9975 - auc: 1.0000 - precision: 0.9975 - recall: 0.9974 - val_loss: 0.0839 - val_categorical_accuracy: 0.9737 - val_auc: 0.9987 - val_precision: 0.9783 - val_recall: 0.9719 - 105s/epoch - 518ms/step
# Epoch 17/50
# 202/202 - 104s - loss: 0.0125 - categorical_accuracy: 0.9964 - auc: 0.9998 - precision: 0.9966 - recall: 0.9964 - val_loss: 0.0151 - val_categorical_accuracy: 0.9953 - val_auc: 1.0000 - val_precision: 0.9953 - val_recall: 0.9945 - 104s/epoch - 517ms/step
# Epoch 18/50
# 202/202 - 105s - loss: 0.0070 - categorical_accuracy: 0.9974 - auc: 1.0000 - precision: 0.9976 - recall: 0.9974 - val_loss: 0.0177 - val_categorical_accuracy: 0.9949 - val_auc: 0.9998 - val_precision: 0.9956 - val_recall: 0.9945 - 105s/epoch - 518ms/step
# Epoch 19/50
# 202/202 - 105s - loss: 0.0109 - categorical_accuracy: 0.9976 - auc: 0.9998 - precision: 0.9978 - recall: 0.9976 - val_loss: 0.1002 - val_categorical_accuracy: 0.9613 - val_auc: 0.9998 - val_precision: 0.9637 - val_recall: 0.9599 - 105s/epoch - 518ms/step
# Epoch 20/50
# 202/202 - 104s - loss: 0.0284 - categorical_accuracy: 0.9919 - auc: 0.9995 - precision: 0.9919 - recall: 0.9917 - val_loss: 0.0351 - val_categorical_accuracy: 0.9876 - val_auc: 0.9996 - val_precision: 0.9880 - val_recall: 0.9876 - 104s/epoch - 517ms/step
# Epoch 21/50
# 202/202 - 105s - loss: 0.0033 - categorical_accuracy: 0.9991 - auc: 1.0000 - precision: 0.9992 - recall: 0.9989 - val_loss: 0.0074 - val_categorical_accuracy: 0.9956 - val_auc: 1.0000 - val_precision: 0.9956 - val_recall: 0.9956 - 105s/epoch - 518ms/step
# Epoch 22/50
# 202/202 - 104s - loss: 0.0116 - categorical_accuracy: 0.9968 - auc: 0.9997 - precision: 0.9968 - recall: 0.9966 - val_loss: 0.0314 - val_categorical_accuracy: 0.9920 - val_auc: 0.9994 - val_precision: 0.9927 - val_recall: 0.9912 - 104s/epoch - 516ms/step
# Epoch 23/50
# 202/202 - 104s - loss: 0.0164 - categorical_accuracy: 0.9947 - auc: 0.9998 - precision: 0.9952 - recall: 0.9945 - val_loss: 0.0101 - val_categorical_accuracy: 0.9956 - val_auc: 1.0000 - val_precision: 0.9956 - val_recall: 0.9953 - 104s/epoch - 515ms/step
# Epoch 24/50
# 202/202 - 104s - loss: 0.0081 - categorical_accuracy: 0.9974 - auc: 0.9999 - precision: 0.9976 - recall: 0.9974 - val_loss: 0.1997 - val_categorical_accuracy: 0.9456 - val_auc: 0.9943 - val_precision: 0.9476 - val_recall: 0.9431 - 104s/epoch - 517ms/step
# Epoch 25/50
# 202/202 - 104s - loss: 0.0052 - categorical_accuracy: 0.9988 - auc: 0.9999 - precision: 0.9989 - recall: 0.9988 - val_loss: 0.0367 - val_categorical_accuracy: 0.9898 - val_auc: 0.9994 - val_precision: 0.9909 - val_recall: 0.9883 - 104s/epoch - 517ms/step
# Epoch 26/50
# 202/202 - 105s - loss: 0.0112 - categorical_accuracy: 0.9964 - auc: 0.9999 - precision: 0.9964 - recall: 0.9964 - val_loss: 0.0433 - val_categorical_accuracy: 0.9861 - val_auc: 0.9991 - val_precision: 0.9861 - val_recall: 0.9861 - 105s/epoch - 519ms/step
# Epoch 27/50
# 202/202 - 104s - loss: 0.0130 - categorical_accuracy: 0.9969 - auc: 0.9998 - precision: 0.9969 - recall: 0.9967 - val_loss: 0.0333 - val_categorical_accuracy: 0.9880 - val_auc: 0.9996 - val_precision: 0.9905 - val_recall: 0.9876 - 104s/epoch - 516ms/step
# Epoch 28/50
# 202/202 - 104s - loss: 0.0095 - categorical_accuracy: 0.9973 - auc: 0.9999 - precision: 0.9974 - recall: 0.9973 - val_loss: 0.0163 - val_categorical_accuracy: 0.9953 - val_auc: 0.9996 - val_precision: 0.9960 - val_recall: 0.9953 - 104s/epoch - 515ms/step
# Epoch 29/50
# 202/202 - 105s - loss: 0.0031 - categorical_accuracy: 0.9994 - auc: 1.0000 - precision: 0.9994 - recall: 0.9993 - val_loss: 0.0029 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 105s/epoch - 518ms/step
# Epoch 30/50
# 202/202 - 104s - loss: 0.0011 - categorical_accuracy: 0.9997 - auc: 1.0000 - precision: 0.9998 - recall: 0.9997 - val_loss: 0.0038 - val_categorical_accuracy: 0.9993 - val_auc: 0.9998 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 515ms/step
# Epoch 31/50
# 202/202 - 105s - loss: 1.6049e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0025 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 105s/epoch - 518ms/step
# Epoch 32/50
# 202/202 - 104s - loss: 0.0053 - categorical_accuracy: 0.9981 - auc: 0.9999 - precision: 0.9981 - recall: 0.9981 - val_loss: 0.6929 - val_categorical_accuracy: 0.9168 - val_auc: 0.9760 - val_precision: 0.9199 - val_recall: 0.9135 - 104s/epoch - 516ms/step
# Epoch 33/50
# 202/202 - 104s - loss: 0.0222 - categorical_accuracy: 0.9936 - auc: 0.9996 - precision: 0.9940 - recall: 0.9933 - val_loss: 0.0178 - val_categorical_accuracy: 0.9934 - val_auc: 1.0000 - val_precision: 0.9934 - val_recall: 0.9934 - 104s/epoch - 517ms/step
# Epoch 34/50
# 202/202 - 105s - loss: 0.0151 - categorical_accuracy: 0.9958 - auc: 0.9998 - precision: 0.9959 - recall: 0.9957 - val_loss: 0.4753 - val_categorical_accuracy: 0.8679 - val_auc: 0.9902 - val_precision: 0.8693 - val_recall: 0.8665 - 105s/epoch - 519ms/step
# Epoch 35/50
# 202/202 - 104s - loss: 0.0150 - categorical_accuracy: 0.9949 - auc: 0.9999 - precision: 0.9951 - recall: 0.9947 - val_loss: 0.0112 - val_categorical_accuracy: 0.9974 - val_auc: 1.0000 - val_precision: 0.9974 - val_recall: 0.9971 - 104s/epoch - 515ms/step
# Epoch 36/50
# 202/202 - 104s - loss: 0.0018 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0036 - val_categorical_accuracy: 0.9985 - val_auc: 1.0000 - val_precision: 0.9989 - val_recall: 0.9985 - 104s/epoch - 515ms/step
# Epoch 37/50
# 202/202 - 105s - loss: 0.0037 - categorical_accuracy: 0.9986 - auc: 1.0000 - precision: 0.9986 - recall: 0.9986 - val_loss: 0.0072 - val_categorical_accuracy: 0.9989 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9985 - 105s/epoch - 519ms/step
# Epoch 38/50
# 202/202 - 104s - loss: 9.3879e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0019 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 515ms/step
# Epoch 39/50
# 202/202 - 104s - loss: 1.8093e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0012 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 517ms/step
# Epoch 40/50
# 202/202 - 105s - loss: 1.1289e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.4634e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 105s/epoch - 517ms/step
# Epoch 41/50
# 202/202 - 104s - loss: 1.6569e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0012 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 517ms/step
# Epoch 42/50
# 202/202 - 105s - loss: 5.8913e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.7324e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 105s/epoch - 521ms/step
# Epoch 43/50
# 202/202 - 104s - loss: 1.2223e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 6.5751e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 104s/epoch - 517ms/step
# Epoch 44/50
# 202/202 - 105s - loss: 0.0515 - categorical_accuracy: 0.9872 - auc: 0.9987 - precision: 0.9881 - recall: 0.9866 - val_loss: 0.0520 - val_categorical_accuracy: 0.9847 - val_auc: 0.9989 - val_precision: 0.9850 - val_recall: 0.9843 - 105s/epoch - 517ms/step
# Epoch 45/50
# 202/202 - 104s - loss: 0.0099 - categorical_accuracy: 0.9971 - auc: 0.9998 - precision: 0.9971 - recall: 0.9970 - val_loss: 0.0210 - val_categorical_accuracy: 0.9931 - val_auc: 0.9998 - val_precision: 0.9934 - val_recall: 0.9923 - 104s/epoch - 517ms/step
# Epoch 46/50
# 202/202 - 105s - loss: 0.0070 - categorical_accuracy: 0.9971 - auc: 1.0000 - precision: 0.9971 - recall: 0.9971 - val_loss: 0.0183 - val_categorical_accuracy: 0.9945 - val_auc: 0.9996 - val_precision: 0.9949 - val_recall: 0.9945 - 105s/epoch - 518ms/step
# Epoch 47/50
# 202/202 - 105s - loss: 0.0025 - categorical_accuracy: 0.9990 - auc: 1.0000 - precision: 0.9990 - recall: 0.9989 - val_loss: 0.0033 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 105s/epoch - 518ms/step
# Epoch 48/50
# 202/202 - 104s - loss: 1.9880e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.1783e-04 - val_categorical_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.9996 - 104s/epoch - 517ms/step
# Epoch 49/50
# 202/202 - 104s - loss: 2.4045e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 8.3616e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 104s/epoch - 516ms/step
# Epoch 50/50
# 202/202 - 105s - loss: 1.2698e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 8.1804e-04 - val_categorical_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.9996 - 105s/epoch - 518ms/step
# ===================================
# 50 epochs in 98.77834994395575 min

# %%
hist_df = pd.DataFrame(densenet_hist.history)
hist_json_file = 'densenet_50ep_histori.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = densenet.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 53s 18ms/step - loss: 0.0039 - categorical_accuracy: 0.9989 - auc: 0.9998 - precision: 0.9989 - recall: 0.9989

# %%
report(densenet)
# Out:
# 2815/2815 [==============================] - 45s 15ms/step
# [[[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   3  183]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2627    2]
#   [   0  186]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2754    0]
#   [   0   61]]
#
#  [[2753    0]
#   [   0   62]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       186
#            1       1.00      1.00      1.00       186
#            2       1.00      1.00      1.00       186
#            3       1.00      1.00      1.00       186
#            4       1.00      1.00      1.00       186
#            5       1.00      0.98      0.99       186
#            6       1.00      1.00      1.00       186
#            7       0.99      1.00      0.99       186
#            8       0.99      1.00      1.00       186
#            9       1.00      1.00      1.00       186
#           10       1.00      1.00      1.00       186
#           11       1.00      1.00      1.00       186
#           12       1.00      1.00      1.00       186
#           13       1.00      1.00      1.00        61
#           14       1.00      1.00      1.00        62
#           15       1.00      1.00      1.00       274
#
#     accuracy                           1.00      2815
#    macro avg       1.00      1.00      1.00      2815
# weighted avg       1.00      1.00      1.00      2815

# %% [markdown]
# ## Inception v1

# %%
def inception_module(x,filters_1x1,filters_3x3_reduce,filters_3x3,
    filters_5x5_reduce,filters_5x5,filters_pool_proj,name=None):

    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)

    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(conv_3x3)
    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(conv_5x5)
    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu')(pool_proj)
    output = tf.keras.layers.Concatenate(axis=3, name=name)([conv_1x1, conv_3x3, conv_5x5, pool_proj])

    return output

# %%
def inception_v1(input_shape=(256,256,3)):
    
    input = Input(shape=input_shape)
    
    x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2')(input)
    x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
    x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
    x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
    x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)
    
    x = inception_module(x,filters_1x1=64,filters_3x3_reduce=96,
     filters_3x3=128,filters_5x5_reduce=16,filters_5x5=32,filters_pool_proj=32,name='inception_3a')
    x = Dropout(0.2)(x)
    
    x = inception_module(x,filters_1x1=128,filters_3x3_reduce=128,
     filters_3x3=192,filters_5x5_reduce=32,filters_5x5=96,filters_pool_proj=64,name='inception_3b')
    x = Dropout(0.2)(x)
    
    x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)
    x = inception_module(x,filters_1x1=192,filters_3x3_reduce=96,
    filters_3x3=208,filters_5x5_reduce=16,filters_5x5=48,filters_pool_proj=64, name='inception_4a')
    x = Dropout(0.2)(x)
    
    x1 = tf.keras.layers.AveragePooling2D((5, 5), strides=3)(x)
    x1 = Conv2D(128, (1, 1), padding='same', activation='relu')(x1)
    x1 = Flatten()(x1)
    x1 = Dense(1024, activation='relu')(x1)
    x1 = Dropout(0.7)(x1)
    x1 = Dense(16, activation='softmax', name='auxilliary_output_1')(x1)
    
    x = inception_module(x,filters_1x1=160,filters_3x3_reduce=112,
    filters_3x3=224,filters_5x5_reduce=24,filters_5x5=64,filters_pool_proj=64,name='inception_4b')
    x = Dropout(0.2)(x)
    
    x = inception_module(x,filters_1x1=128,filters_3x3_reduce=128,
     filters_3x3=256,filters_5x5_reduce=24,filters_5x5=64,filters_pool_proj=64,name='inception_4c')
    x = Dropout(0.2)(x)
    
    x = inception_module(x,filters_1x1=112,filters_3x3_reduce=144,
     filters_3x3=288,filters_5x5_reduce=32,filters_5x5=64,filters_pool_proj=64,name='inception_4d')
    x = Dropout(0.2)(x)
    
    x2 = tf.keras.layers.AveragePooling2D((5, 5), strides=3)(x)
    x2 = Conv2D(128, (1, 1), padding='same', activation='relu')(x2)
    x2 = Flatten()(x2)
    x2 = Dense(1024, activation='relu')(x2)
    x2 = Dropout(0.7)(x2)
    x2 = Dense(16, activation='softmax', name='auxilliary_output_2')(x2)
    
    x = inception_module(x,filters_1x1=256,filters_3x3_reduce=160,
     filters_3x3=320,filters_5x5_reduce=32,filters_5x5=128,filters_pool_proj=128,name='inception_4e')
    
    x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)
    x = inception_module(x,filters_1x1=256,filters_3x3_reduce=160,
     filters_3x3=320,filters_5x5_reduce=32,filters_5x5=128,filters_pool_proj=128,name='inception_5a')
    
    x = inception_module(x, filters_1x1=384,filters_3x3_reduce=192,
     filters_3x3=384,filters_5x5_reduce=48,filters_5x5=128,filters_pool_proj=128,name='inception_5b')
    
    x = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)
    x = Dropout(0.4)(x)
    x = Dense(16, activation='softmax', name='output')(x)
    
    model = Model(inputs=input, outputs=[x, x1, x2], name='inception_v1')
    
    return model

# %%
inception1 = inception_v1(input_shape=(256,256,3))
inception1.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=['categorical_crossentropy','categorical_crossentropy', 'categorical_crossentropy'], loss_weights=[1.0,0.3,0.3], metrics=[cat_acc,auc_roc,prec,recall])

# %%
start = time()
inception1_hist = inception1.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=2)
end = time()
print("===================================")
print(f'50 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/50
# 2023-08-29 21:28:58.238672: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape ininception_v1/dropout_32/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 202/202 - 110s - loss: 3.6889 - output_loss: 2.2788 - auxilliary_output_1_loss: 2.3809 - auxilliary_output_2_loss: 2.3196 - output_categorical_accuracy: 0.1965 - output_auc: 0.7378 - output_precision: 0.8817 - output_recall: 0.0820 - auxilliary_output_1_categorical_accuracy: 0.1879 - auxilliary_output_1_auc: 0.7139 - auxilliary_output_1_precision: 0.9602 - auxilliary_output_1_recall: 0.0635 - auxilliary_output_2_categorical_accuracy: 0.1987 - auxilliary_output_2_auc: 0.7274 - auxilliary_output_2_precision: 0.8916 - auxilliary_output_2_recall: 0.0784 - val_loss: 3.0792 - val_output_loss: 1.9235 - val_auxilliary_output_1_loss: 1.9773 - val_auxilliary_output_2_loss: 1.8751 - val_output_categorical_accuracy: 0.3539 - val_output_auc: 0.8935 - val_output_precision: 0.9444 - val_output_recall: 0.0992 - val_auxilliary_output_1_categorical_accuracy: 0.3057 - val_auxilliary_output_1_auc: 0.8674 - val_auxilliary_output_1_precision: 1.0000 - val_auxilliary_output_1_recall: 0.0992 - val_auxilliary_output_2_categorical_accuracy: 0.4079 - val_auxilliary_output_2_auc: 0.9007 - val_auxilliary_output_2_precision: 1.0000 - val_auxilliary_output_2_recall: 0.1000 - 110s/epoch - 546ms/step
# Epoch 2/50
# 202/202 - 78s - loss: 2.4707 - output_loss: 1.5036 - auxilliary_output_1_loss: 1.7039 - auxilliary_output_2_loss: 1.5196 - output_categorical_accuracy: 0.4140 - output_auc: 0.9054 - output_precision: 0.7233 - output_recall: 0.1991 - auxilliary_output_1_categorical_accuracy: 0.3650 - auxilliary_output_1_auc: 0.8805 - auxilliary_output_1_precision: 0.7730 - auxilliary_output_1_recall: 0.1387 - auxilliary_output_2_categorical_accuracy: 0.4140 - auxilliary_output_2_auc: 0.9055 - auxilliary_output_2_precision: 0.7316 - auxilliary_output_2_recall: 0.2059 - val_loss: 2.1626 - val_output_loss: 1.3370 - val_auxilliary_output_1_loss: 1.4667 - val_auxilliary_output_2_loss: 1.2851 - val_output_categorical_accuracy: 0.5494 - val_output_auc: 0.9460 - val_output_precision: 0.9393 - val_output_recall: 0.2090 - val_au
auxilliary_output_2_recall: 0.9945 - val_loss: 0.0823 - val_output_loss: 0.0356 - val_auxilliary_output_1_loss: 0.0889 - val_auxilliary_output_2_loss: 0.0668 - val_output_categorical_accuracy: 0.9901 - val_output_auc: 0.9996 - val_output_precision: 0.9912 - val_output_recall: 0.9887 - val_auxilliary_output_1_categorical_accuracy: 0.9672 - val_auxilliary_output_1_auc: 0.9988 - val_auxilliary_output_1_precision: 0.9714 - val_auxilliary_output_1_recall: 0.9661 - val_auxilliary_output_2_categorical_accuracy: 0.9891 - val_auxilliary_output_2_auc: 0.9984 - val_auxilliary_output_2_precision: 0.9901 - val_auxilliary_output_2_recall: 0.9887 - 79s/epoch - 389ms/step
# ===================================
# 50 epochs in 67.41121159791946 min

# %%
hist_df = pd.DataFrame(inception1_hist.history)
hist_json_file = 'inception1_50ep_history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %%
pred = inception1.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 45s 16ms/step - loss: 4.0962 - output_loss: 3.3179 - auxilliary_output_1_loss: 0.2102 - auxilliary_output_2_loss: 2.3842 - output_categorical_accuracy: 0.7854 - output_auc: 0.9136 - output_precision: 0.7865 - output_recall: 0.7851 - auxilliary_output_1_categorical_accuracy: 0.9155 - auxilliary_output_1_auc: 0.9977 - auxilliary_output_1_precision: 0.9245 - auxilliary_output_1_recall: 0.9087 - auxilliary_output_2_categorical_accuracy: 0.8270 - auxilliary_output_2_auc: 0.9330 - auxilliary_output_2_precision: 0.8272 - auxilliary_output_2_recall: 0.8263

# %%
report(inception1)
# Out:
# 2815/2815 [==============================] - 22s 8ms/step
# incept
# [[[2543   86]
#   [  32  154]]
#
#  [[2621    8]
#   [   0  186]]
#
#  [[2629    0]
#   [  42  144]]
#
#  [[2593   36]
#   [   0  186]]
#
#  [[2629    0]
#   [ 100   86]]
#
#  [[2621    8]
#   [ 144   42]]
#
#  [[2497  132]
#   [   1  185]]
#
#  [[2534   95]
#   [  15  171]]
#
#  [[2571   58]
#   [  52  134]]
#
#  [[2627    2]
#   [   4  182]]
#
#  [[2629    0]
#   [  89   97]]
#
#  [[2629    0]
#   [   6  180]]
#
#  [[2613   16]
#   [  63  123]]
#
#  [[2591  163]
#   [   0   61]]
#
#  [[2753    0]
#   [  56    6]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.83      0.72       186
#            1       0.96      1.00      0.98       186
#            2       1.00      0.77      0.87       186
#            3       0.84      1.00      0.91       186
#            4       1.00      0.46      0.63       186
#            5       0.84      0.23      0.36       186
#            6       0.58      0.99      0.74       186
#            7       0.64      0.92      0.76       186
#            8       0.70      0.72      0.71       186
#            9       0.99      0.98      0.98       186
#           10       1.00      0.52      0.69       186
#           11       1.00      0.97      0.98       186
#           12       0.88      0.66      0.76       186
#           13       0.27      1.00      0.43        61
#           14       1.00      0.10      0.18        62
#           15       1.00      1.00      1.00       274
#
#     accuracy                           0.79      2815
#    macro avg       0.83      0.76      0.73      2815
# weighted avg       0.86      0.79      0.78      2815

# %% [markdown]
# # Best model

# %%
def convolutional_layer(x, filters, kernel=1, strides=1):
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = Conv2D(filters, kernel_size=kernel, strides=strides, padding='same')(x)
    return x

def dense_block(x, layers, filters):
    for _ in range(layers):
        x_d = convolutional_layer(x, 4*filters)
        x_d = convolutional_layer(x_d, filters, kernel=3)
        x = tf.keras.layers.Concatenate()([x_d,x])
    return x

def transition_layer(x):
    x = convolutional_layer(x, filters=x.shape[-1]//2)
    x = tf.keras.layers.AveragePooling2D(2, strides=2, padding='same')(x)
    return x

def denseNet121(input_shape):
    input = Input(shape=input_shape)
    
    x = Conv2D(filters=64, kernel_size=7, strides=2, padding='same')(input)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = MaxPool2D(3, strides=2, padding='same')(x)
    
    for l in [6,12,24,16]:
        d = dense_block(x, layers=l, filters=32)
        x = Dropout(0.2)(x)
        x = transition_layer(d)
    x = Dropout(0.2)(x)
        
    x = tf.keras.layers.GlobalAveragePooling2D()(d)
    x = Flatten()(x)
    output = Dense(units=16, activation='softmax')(x)
    
    model = Model(inputs=input, outputs=output, name='DenseNet')
    
    return model

densenet = denseNet121(input_shape=(256,256,3))
densenet.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=[cat_acc,auc_roc,prec,recall])

# %%
def scheduler(epoch, lr):
    if epoch < 40:
        return lr
    elif epoch < 60:
        lr = 1e-4 * tf.math.exp(-0.8)
        return lr
    else:
        lr = 7e-5 * tf.math.exp(-0.9)
        return lr

call = tf.keras.callbacks.LearningRateScheduler(
    scheduler, verbose=0
)

start = time()
densenet_hist = densenet.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=70, verbose=2, callbacks=[call])
end = time()
print("===================================")
print(f'70 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/70
# 202/202 - 196s - loss: 0.5431 - categorical_accuracy: 0.9155 - auc: 0.9970 - precision: 0.9815 - recall: 0.8583 - val_loss: 3.3377 - val_categorical_accuracy: 0.0657 - val_auc: 0.5137 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - lr: 1.0000e-04 - 196s/epoch - 968ms/step
# Epoch 2/70
# 202/202 - 104s - loss: 0.0732 - categorical_accuracy: 0.9791 - auc: 0.9995 - precision: 0.9824 - recall: 0.9753 - val_loss: 3.8419 - val_categorical_accuracy: 0.1452 - val_auc: 0.5447 - val_precision: 0.2661 - val_recall: 0.0106 - lr: 1.0000e-04 - 104s/epoch - 516ms/step
# Epoch 3/70
# 202/202 - 106s - loss: 0.0474 - categorical_accuracy: 0.9858 - auc: 0.9997 - precision: 0.9876 - recall: 0.9842 - val_loss: 1.0739 - val_categorical_accuracy: 0.6151 - val_auc: 0.9795 - val_precision: 0.6646 - val_recall: 0.5465 - lr: 1.0000e-04 - 106s/epoch - 526ms/step
# Epoch 4/70
# 202/202 - 104s - loss: 0.0362 - categorical_accuracy: 0.9888 - auc: 0.9996 - precision: 0.9898 - recall: 0.9872 - val_loss: 0.0406 - val_categorical_accuracy: 0.9880 - val_auc: 0.9998 - val_precision: 0.9898 - val_recall: 0.9869 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 5/70
# 202/202 - 104s - loss: 0.0340 - categorical_accuracy: 0.9900 - auc: 0.9998 - precision: 0.9905 - recall: 0.9885 - val_loss: 0.0733 - val_categorical_accuracy: 0.9799 - val_auc: 0.9998 - val_precision: 0.9835 - val_recall: 0.9767 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 6/70
# 202/202 - 104s - loss: 0.0223 - categorical_accuracy: 0.9935 - auc: 0.9998 - precision: 0.9942 - recall: 0.9929 - val_loss: 0.0807 - val_categorical_accuracy: 0.9686 - val_auc: 0.9994 - val_precision: 0.9690 - val_recall: 0.9679 - lr: 1.0000e-04 - 104s/epoch - 517ms/step
# Epoch 7/70
# 202/202 - 104s - loss: 0.0176 - categorical_accuracy: 0.9944 - auc: 0.9999 - precision: 0.9950 - recall: 0.9941 - val_loss: 0.0135 - val_categorical_accuracy: 0.9974 - val_auc: 0.9996 - val_precision: 0.9978 - val_recall: 0.9974 - lr: 1.0000e-04 - 104s/epoch - 513ms/step
# Epoch 8/70
# 202/202 - 111s - loss: 0.0216 - categorical_accuracy: 0.9935 - auc: 0.9997 - precision: 0.9938 - recall: 0.9931 - val_loss: 0.1045 - val_categorical_accuracy: 0.9675 - val_auc: 0.9984 - val_precision: 0.9717 - val_recall: 0.9639 - lr: 1.0000e-04 - 111s/epoch - 551ms/step
# Epoch 9/70
# 202/202 - 104s - loss: 0.0146 - categorical_accuracy: 0.9960 - auc: 0.9999 - precision: 0.9960 - recall: 0.9958 - val_loss: 0.0245 - val_categorical_accuracy: 0.9927 - val_auc: 0.9996 - val_precision: 0.9927 - val_recall: 0.9923 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 10/70
# 202/202 - 104s - loss: 0.0064 - categorical_accuracy: 0.9983 - auc: 1.0000 - precision: 0.9984 - recall: 0.9982 - val_loss: 0.0308 - val_categorical_accuracy: 0.9934 - val_auc: 0.9987 - val_precision: 0.9934 - val_recall: 0.9934 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 11/70
# 202/202 - 104s - loss: 0.0284 - categorical_accuracy: 0.9917 - auc: 0.9995 - precision: 0.9923 - recall: 0.9915 - val_loss: 0.3449 - val_categorical_accuracy: 0.8843 - val_auc: 0.9952 - val_precision: 0.9013 - val_recall: 0.8657 - lr: 1.0000e-04 - 104s/epoch - 516ms/step
# Epoch 12/70
# 202/202 - 104s - loss: 0.0151 - categorical_accuracy: 0.9956 - auc: 0.9999 - precision: 0.9957 - recall: 0.9954 - val_loss: 0.0612 - val_categorical_accuracy: 0.9887 - val_auc: 0.9976 - val_precision: 0.9887 - val_recall: 0.9883 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 13/70
# 202/202 - 104s - loss: 0.0127 - categorical_accuracy: 0.9962 - auc: 0.9999 - precision: 0.9965 - recall: 0.9960 - val_loss: 0.0086 - val_categorical_accuracy: 0.9982 - val_auc: 0.9998 - val_precision: 0.9982 - val_recall: 0.9978 - lr: 1.0000e-04 - 104s/epoch - 517ms/step
# Epoch 14/70
# 202/202 - 104s - loss: 0.0222 - categorical_accuracy: 0.9943 - auc: 0.9996 - precision: 0.9950 - recall: 0.9940 - val_loss: 0.1127 - val_categorical_accuracy: 0.9621 - val_auc: 0.9992 - val_precision: 0.9659 - val_recall: 0.9599 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 15/70
# 202/202 - 104s - loss: 0.0135 - categorical_accuracy: 0.9962 - auc: 0.9998 - precision: 0.9962 - recall: 0.9961 - val_loss: 0.0405 - val_categorical_accuracy: 0.9869 - val_auc: 0.9992 - val_precision: 0.9876 - val_recall: 0.9865 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 16/70
# 202/202 - 104s - loss: 0.0084 - categorical_accuracy: 0.9970 - auc: 0.9999 - precision: 0.9972 - recall: 0.9969 - val_loss: 0.0229 - val_categorical_accuracy: 0.9916 - val_auc: 0.9998 - val_precision: 0.9927 - val_recall: 0.9909 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 17/70
# 202/202 - 104s - loss: 0.0134 - categorical_accuracy: 0.9963 - auc: 0.9997 - precision: 0.9967 - recall: 0.9963 - val_loss: 0.0722 - val_categorical_accuracy: 0.9741 - val_auc: 0.9988 - val_precision: 0.9748 - val_recall: 0.9737 - lr: 1.0000e-04 - 104s/epoch - 516ms/step
# Epoch 18/70
# 202/202 - 104s - loss: 0.0162 - categorical_accuracy: 0.9943 - auc: 0.9998 - precision: 0.9948 - recall: 0.9941 - val_loss: 0.1213 - val_categorical_accuracy: 0.9752 - val_auc: 0.9961 - val_precision: 0.9787 - val_recall: 0.9734 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 19/70
# 202/202 - 104s - loss: 0.0154 - categorical_accuracy: 0.9960 - auc: 0.9998 - precision: 0.9964 - recall: 0.9959 - val_loss: 0.1473 - val_categorical_accuracy: 0.9529 - val_auc: 0.9975 - val_precision: 0.9601 - val_recall: 0.9475 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 20/70
# 202/202 - 111s - loss: 0.0214 - categorical_accuracy: 0.9941 - auc: 0.9998 - precision: 0.9942 - recall: 0.9937 - val_loss: 0.0382 - val_categorical_accuracy: 0.9905 - val_auc: 0.9989 - val_precision: 0.9905 - val_recall: 0.9898 - lr: 1.0000e-04 - 111s/epoch - 551ms/step
# Epoch 21/70
# 202/202 - 104s - loss: 0.0047 - categorical_accuracy: 0.9986 - auc: 1.0000 - precision: 0.9987 - recall: 0.9986 - val_loss: 0.0141 - val_categorical_accuracy: 0.9964 - val_auc: 0.9996 - val_precision: 0.9964 - val_recall: 0.9960 - lr: 1.0000e-04 - 104s/epoch - 513ms/step
# Epoch 22/70
# 202/202 - 104s - loss: 0.0027 - categorical_accuracy: 0.9995 - auc: 0.9999 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0707 - val_categorical_accuracy: 0.9883 - val_auc: 0.9976 - val_precision: 0.9887 - val_recall: 0.9883 - lr: 1.0000e-04 - 104s/epoch - 516ms/step
# Epoch 23/70
# 202/202 - 104s - loss: 0.0095 - categorical_accuracy: 0.9967 - auc: 0.9999 - precision: 0.9967 - recall: 0.9967 - val_loss: 0.0096 - val_categorical_accuracy: 0.9964 - val_auc: 0.9998 - val_precision: 0.9964 - val_recall: 0.9964 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 24/70
# 202/202 - 104s - loss: 9.0590e-04 - categorical_accuracy: 0.9999 - auc: 1.0000 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0075 - val_categorical_accuracy: 0.9978 - val_auc: 0.9998 - val_precision: 0.9985 - val_recall: 0.9978 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 25/70
# 202/202 - 104s - loss: 5.8780e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0031 - val_categorical_accuracy: 0.9978 - val_auc: 1.0000 - val_precision: 0.9985 - val_recall: 0.9974 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 26/70
# 202/202 - 104s - loss: 0.0282 - categorical_accuracy: 0.9921 - auc: 0.9996 - precision: 0.9925 - recall: 0.9916 - val_loss: 0.0791 - val_categorical_accuracy: 0.9712 - val_auc: 0.9996 - val_precision: 0.9733 - val_recall: 0.9697 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 27/70
# 202/202 - 104s - loss: 0.0030 - categorical_accuracy: 0.9992 - auc: 1.0000 - precision: 0.9993 - recall: 0.9992 - val_loss: 0.0094 - val_categorical_accuracy: 0.9971 - val_auc: 1.0000 - val_precision: 0.9971 - val_recall: 0.9971 - lr: 1.0000e-04 - 104s/epoch - 516ms/step
# Epoch 28/70
# 202/202 - 104s - loss: 3.3752e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0029 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 29/70
# 202/202 - 104s - loss: 9.7618e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0032 - val_categorical_accuracy: 0.9989 - val_auc: 1.0000 - val_precision: 0.9989 - val_recall: 0.9989 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 30/70
# 202/202 - 104s - loss: 0.0063 - categorical_accuracy: 0.9981 - auc: 0.9998 - precision: 0.9982 - recall: 0.9981 - val_loss: 0.5344 - val_categorical_accuracy: 0.8909 - val_auc: 0.9827 - val_precision: 0.8944 - val_recall: 0.8895 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 31/70
# 202/202 - 104s - loss: 0.0302 - categorical_accuracy: 0.9916 - auc: 0.9994 - precision: 0.9919 - recall: 0.9910 - val_loss: 0.0554 - val_categorical_accuracy: 0.9836 - val_auc: 0.9987 - val_precision: 0.9839 - val_recall: 0.9832 - lr: 1.0000e-04 - 104s/epoch - 517ms/step
# Epoch 32/70
# 202/202 - 112s - loss: 0.0012 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0047 - val_categorical_accuracy: 0.9989 - val_auc: 0.9998 - val_precision: 0.9989 - val_recall: 0.9989 - lr: 1.0000e-04 - 112s/epoch - 552ms/step
# Epoch 33/70
# 202/202 - 104s - loss: 9.9038e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0025 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - lr: 1.0000e-04 - 104s/epoch - 517ms/step
# Epoch 34/70
# 202/202 - 104s - loss: 9.4591e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0262 - val_categorical_accuracy: 0.9927 - val_auc: 0.9994 - val_precision: 0.9927 - val_recall: 0.9927 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 35/70
# 202/202 - 104s - loss: 0.0268 - categorical_accuracy: 0.9923 - auc: 0.9994 - precision: 0.9926 - recall: 0.9921 - val_loss: 0.0485 - val_categorical_accuracy: 0.9847 - val_auc: 0.9994 - val_precision: 0.9854 - val_recall: 0.9836 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 36/70
# 202/202 - 104s - loss: 0.0038 - categorical_accuracy: 0.9986 - auc: 1.0000 - precision: 0.9988 - recall: 0.9985 - val_loss: 0.0037 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - lr: 1.0000e-04 - 104s/epoch - 516ms/step
# Epoch 37/70
# 202/202 - 104s - loss: 7.6055e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0045 - val_categorical_accuracy: 0.9974 - val_auc: 1.0000 - val_precision: 0.9974 - val_recall: 0.9974 - lr: 1.0000e-04 - 104s/epoch - 516ms/step
# Epoch 38/70
# 202/202 - 104s - loss: 0.0153 - categorical_accuracy: 0.9957 - auc: 0.9998 - precision: 0.9960 - recall: 0.9957 - val_loss: 0.0542 - val_categorical_accuracy: 0.9869 - val_auc: 0.9984 - val_precision: 0.9894 - val_recall: 0.9869 - lr: 1.0000e-04 - 104s/epoch - 515ms/step
# Epoch 39/70
# 202/202 - 105s - loss: 0.0145 - categorical_accuracy: 0.9964 - auc: 0.9997 - precision: 0.9966 - recall: 0.9962 - val_loss: 0.0793 - val_categorical_accuracy: 0.9752 - val_auc: 0.9987 - val_precision: 0.9766 - val_recall: 0.9741 - lr: 1.0000e-04 - 105s/epoch - 517ms/step
# Epoch 40/70
# 202/202 - 104s - loss: 0.0124 - categorical_accuracy: 0.9964 - auc: 0.9998 - precision: 0.9965 - recall: 0.9964 - val_loss: 0.0100 - val_categorical_accuracy: 0.9960 - val_auc: 1.0000 - val_precision: 0.9960 - val_recall: 0.9960 - lr: 1.0000e-04 - 104s/epoch - 514ms/step
# Epoch 41/70
# 202/202 - 104s - loss: 7.2787e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0016 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - lr: 4.4933e-05 - 104s/epoch - 516ms/step
# Epoch 42/70
# 202/202 - 104s - loss: 3.7428e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0013 - val_categorical_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.9996 - lr: 4.4933e-05 - 104s/epoch - 516ms/step
# Epoch 43/70
# 202/202 - 104s - loss: 2.2004e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0014 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - lr: 4.4933e-05 - 104s/epoch - 514ms/step
# Epoch 44/70
# 202/202 - 104s - loss: 1.3351e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.0587e-04 - val_categorical_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - lr: 4.4933e-05 - 104s/epoch - 515ms/step
# Epoch 45/70
# 202/202 - 104s - loss: 2.1210e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0017 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - lr: 4.4933e-05 - 104s/epoch - 515ms/step
# Epoch 46/70
# 202/202 - 104s - loss: 1.6062e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0011 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - lr: 4.4933e-05 - 104s/epoch - 514ms/step
# Epoch 47/70
# 202/202 - 104s - loss: 1.0951e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0010 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - lr: 4.4933e-05 - 104s/epoch - 517ms/step
# Epoch 48/70
# 202/202 - 104s - loss: 1.2199e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 8.4150e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 0.9996 - lr: 4.4933e-05 - 104s/epoch - 515ms/step
# Epoch 49/70
# 202/202 - 104s - loss: 1.1041e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0013 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - lr: 4.4933e-05 - 104s/epoch - 514ms/step
# Epoch 50/70
# 202/202 - 104s - loss: 1.1636e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0012 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9989 - lr: 4.4933e-05 - 104s/epoch - 516ms/step
# Epoch 51/70
# 202/202 - 104s - loss: 7.0001e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.1554e-04 - val_categorical_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - lr: 4.4933e-05 - 104s/epoch - 517ms/step
# Epoch 52/70
# 202/202 - 104s - loss: 6.0960e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 8.4183e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - lr: 4.4933e-05 - 104s/epoch - 514ms/step
# Epoch 53/70
# 202/202 - 104s - loss: 7.7993e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.7600e-04 - val_categorical_accuracy: 1.0000 - val_auc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - lr: 4.4933e-05 - 104s/epoch - 517ms/step
# Epoch 54/70
# 202/202 - 104s - loss: 0.0045 - categorical_accuracy: 0.9988 - auc: 0.9998 - precision: 0.9988 - recall: 0.9988 - val_loss: 0.0112 - val_categorical_accuracy: 0.9956 - val_auc: 1.0000 - val_precision: 0.9956 - val_recall: 0.9956 - lr: 4.4933e-05 - 104s/epoch - 514ms/step
# Epoch 55/70
# 202/202 - 105s - loss: 0.0067 - categorical_accuracy: 0.9978 - auc: 0.9999 - precision: 0.9979 - recall: 0.9978 - val_loss: 0.0033 - val_categorical_accuracy: 0.9985 - val_auc: 1.0000 - val_precision: 0.9985 - val_recall: 0.9985 - lr: 4.4933e-05 - 105s/epoch - 520ms/step
# Epoch 56/70
# 202/202 - 104s - loss: 0.0020 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0022 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - lr: 4.4933e-05 - 104s/epoch - 516ms/step
# Epoch 57/70
# 202/202 - 112s - loss: 1.3748e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 9.6311e-04 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - lr: 4.4933e-05 - 112s/epoch - 554ms/step
# Epoch 58/70
# 202/202 - 104s - loss: 1.9167e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.0056 - val_categorical_accuracy: 0.9982 - val_auc: 0.9998 - val_precision: 0.9982 - val_recall: 0.9982 - lr: 4.4933e-05 - 104s/epoch - 516ms/step
# Epoch 59/70
# 202/202 - 112s - loss: 0.0059 - categorical_accuracy: 0.9985 - auc: 0.9998 - precision: 0.9985 - recall: 0.9985 - val_loss: 0.0036 - val_categorical_accuracy: 0.9985 - val_auc: 1.0000 - val_precision: 0.9985 - val_recall: 0.9985 - lr: 4.4933e-05 - 112s/epoch - 552ms/step
# Epoch 60/70
# 202/202 - 104s - loss: 0.0013 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0050 - val_categorical_accuracy: 0.9989 - val_auc: 0.9998 - val_precision: 0.9989 - val_recall: 0.9989 - lr: 4.4933e-05 - 104s/epoch - 517ms/step
# Epoch 61/70
# 202/202 - 104s - loss: 2.7122e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0019 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - lr: 2.8460e-05 - 104s/epoch - 515ms/step
# Epoch 62/70
# 202/202 - 104s - loss: 1.2444e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0014 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - lr: 2.8460e-05 - 104s/epoch - 516ms/step
# Epoch 63/70
# 202/202 - 104s - loss: 1.4798e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0017 - val_categorical_accuracy: 0.9989 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9989 - lr: 2.8460e-05 - 104s/epoch - 517ms/step
# Epoch 64/70
# 202/202 - 104s - loss: 5.0459e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0013 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - lr: 2.8460e-05 - 104s/epoch - 516ms/step
# Epoch 65/70
# 202/202 - 104s - loss: 5.9023e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0013 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - lr: 2.8460e-05 - 104s/epoch - 517ms/step
# Epoch 66/70
# 202/202 - 104s - loss: 6.1179e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0011 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - lr: 2.8460e-05 - 104s/epoch - 517ms/step
# Epoch 67/70
# 202/202 - 104s - loss: 5.3037e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0011 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - lr: 2.8460e-05 - 104s/epoch - 517ms/step
# Epoch 68/70
# 202/202 - 104s - loss: 5.1707e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0012 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - lr: 2.8460e-05 - 104s/epoch - 514ms/step
# Epoch 69/70
# 202/202 - 104s - loss: 4.6299e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0013 - val_categorical_accuracy: 0.9989 - val_auc: 1.0000 - val_precision: 0.9989 - val_recall: 0.9989 - lr: 2.8460e-05 - 104s/epoch - 516ms/step
# Epoch 70/70
# 202/202 - 103s - loss: 4.7751e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 7.8789e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - lr: 2.8460e-05 - 103s/epoch - 512ms/step
# ===================================
# 70 epochs in 141.79092177549998 min

# %%
densenet.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 53s 19ms/step - loss: 4.5614e-04 - categorical_accuracy: 0.9996 - auc: 1.0000 - precision: 0.9996 - recall: 0.9996
# [0.000456141191534698,
#  0.9996447563171387,
#  1.0,
#  0.9996447563171387,
#  0.9996447563171387]

# %%
report(densenet)
# Out:
# 2815/2815 [==============================] - 41s 15ms/step
# [[[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2754    0]
#   [   0   61]]
#
#  [[2753    0]
#   [   0   62]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0    1.00000   1.00000   1.00000       186
#            1    1.00000   1.00000   1.00000       186
#            2    1.00000   1.00000   1.00000       186
#            3    1.00000   1.00000   1.00000       186
#            4    1.00000   1.00000   1.00000       186
#            5    1.00000   1.00000   1.00000       186
#            6    1.00000   1.00000   1.00000       186
#            7    1.00000   0.99462   0.99730       186
#            8    0.99465   1.00000   0.99732       186
#            9    1.00000   1.00000   1.00000       186
#           10    1.00000   1.00000   1.00000       186
#           11    1.00000   1.00000   1.00000       186
#           12    1.00000   1.00000   1.00000       186
#           13    1.00000   1.00000   1.00000        61
#           14    1.00000   1.00000   1.00000        62
#           15    1.00000   1.00000   1.00000       274
#
#     accuracy                        0.99964      2815
#    macro avg    0.99967   0.99966   0.99966      2815
# weighted avg    0.99965   0.99964   0.99964      2815

# %%
densenet.save_weights("DenseNet121_weights.hdf5")

# %%
start = time()
densenet_hist = densenet.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=80, verbose=2)
end = time()
print("===================================")
print(f'80 epochs in {(end-start)/60} min')
# Out:
# Epoch 1/80
# 202/202 - 195s - loss: 0.5807 - categorical_accuracy: 0.8572 - auc: 0.9918 - precision: 0.9694 - recall: 0.7628 - val_loss: 3.6599 - val_categorical_accuracy: 0.0657 - val_auc: 0.5256 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - 195s/epoch - 967ms/step
# Epoch 2/80
# 202/202 - 104s - loss: 0.0887 - categorical_accuracy: 0.9736 - auc: 0.9993 - precision: 0.9774 - recall: 0.9699 - val_loss: 4.2092 - val_categorical_accuracy: 0.0657 - val_auc: 0.5320 - val_precision: 0.0820 - val_recall: 0.0657 - 104s/epoch - 515ms/step
# Epoch 3/80
# 202/202 - 104s - loss: 0.0390 - categorical_accuracy: 0.9890 - auc: 0.9997 - precision: 0.9905 - recall: 0.9875 - val_loss: 1.9356 - val_categorical_accuracy: 0.4075 - val_auc: 0.9488 - val_precision: 0.4841 - val_recall: 0.3386 - 104s/epoch - 516ms/step
# Epoch 4/80
# 202/202 - 104s - loss: 0.0353 - categorical_accuracy: 0.9892 - auc: 0.9998 - precision: 0.9901 - recall: 0.9880 - val_loss: 0.0298 - val_categorical_accuracy: 0.9920 - val_auc: 0.9998 - val_precision: 0.9927 - val_recall: 0.9912 - 104s/epoch - 516ms/step
# Epoch 5/80
# 202/202 - 104s - loss: 0.0333 - categorical_accuracy: 0.9905 - auc: 0.9996 - precision: 0.9912 - recall: 0.9895 - val_loss: 0.0617 - val_categorical_accuracy: 0.9818 - val_auc: 0.9994 - val_precision: 0.9835 - val_recall: 0.9807 - 104s/epoch - 515ms/step
# Epoch 6/80
# 202/202 - 105s - loss: 0.0233 - categorical_accuracy: 0.9930 - auc: 0.9998 - precision: 0.9936 - recall: 0.9926 - val_loss: 0.1540 - val_categorical_accuracy: 0.9449 - val_auc: 0.9984 - val_precision: 0.9502 - val_recall: 0.9402 - 105s/epoch - 519ms/step
# Epoch 7/80
# 202/202 - 104s - loss: 0.0194 - categorical_accuracy: 0.9940 - auc: 0.9999 - precision: 0.9944 - recall: 0.9937 - val_loss: 0.0670 - val_categorical_accuracy: 0.9836 - val_auc: 0.9977 - val_precision: 0.9846 - val_recall: 0.9825 - 104s/epoch - 515ms/step
# Epoch 8/80
# 202/202 - 105s - loss: 0.0129 - categorical_accuracy: 0.9962 - auc: 0.9999 - precision: 0.9964 - recall: 0.9960 - val_loss: 0.0217 - val_categorical_accuracy: 0.9953 - val_auc: 0.9994 - val_precision: 0.9960 - val_recall: 0.9953 - 105s/epoch - 518ms/step
# Epoch 9/80
# 202/202 - 104s - loss: 0.0210 - categorical_accuracy: 0.9937 - auc: 0.9997 - precision: 0.9940 - recall: 0.9933 - val_loss: 0.0833 - val_categorical_accuracy: 0.9818 - val_auc: 0.9976 - val_precision: 0.9828 - val_recall: 0.9810 - 104s/epoch - 515ms/step
# Epoch 10/80
# 202/202 - 104s - loss: 0.0124 - categorical_accuracy: 0.9961 - auc: 0.9999 - precision: 0.9964 - recall: 0.9959 - val_loss: 0.0085 - val_categorical_accuracy: 0.9974 - val_auc: 1.0000 - val_precision: 0.9978 - val_recall: 0.9971 - 104s/epoch - 517ms/step
# Epoch 11/80
# 202/202 - 104s - loss: 0.0062 - categorical_accuracy: 0.9981 - auc: 0.9999 - precision: 0.9983 - recall: 0.9981 - val_loss: 0.0210 - val_categorical_accuracy: 0.9934 - val_auc: 0.9998 - val_precision: 0.9934 - val_recall: 0.9934 - 104s/epoch - 517ms/step
# Epoch 12/80
# 202/202 - 105s - loss: 0.0389 - categorical_accuracy: 0.9897 - auc: 0.9993 - precision: 0.9902 - recall: 0.9892 - val_loss: 0.0281 - val_categorical_accuracy: 0.9905 - val_auc: 1.0000 - val_precision: 0.9923 - val_recall: 0.9901 - 105s/epoch - 519ms/step
# Epoch 13/80
# 202/202 - 104s - loss: 0.0096 - categorical_accuracy: 0.9975 - auc: 0.9998 - precision: 0.9977 - recall: 0.9974 - val_loss: 0.0265 - val_categorical_accuracy: 0.9923 - val_auc: 0.9995 - val_precision: 0.9927 - val_recall: 0.9923 - 104s/epoch - 516ms/step
# Epoch 14/80
# 202/202 - 104s - loss: 0.0100 - categorical_accuracy: 0.9965 - auc: 1.0000 - precision: 0.9968 - recall: 0.9962 - val_loss: 0.0101 - val_categorical_accuracy: 0.9967 - val_auc: 1.0000 - val_precision: 0.9974 - val_recall: 0.9967 - 104s/epoch - 515ms/step
# Epoch 15/80
# 202/202 - 104s - loss: 0.0111 - categorical_accuracy: 0.9969 - auc: 0.9998 - precision: 0.9971 - recall: 0.9968 - val_loss: 0.0850 - val_categorical_accuracy: 0.9686 - val_auc: 0.9992 - val_precision: 0.9714 - val_recall: 0.9672 - 104s/epoch - 517ms/step
# Epoch 16/80
# 202/202 - 104s - loss: 0.0263 - categorical_accuracy: 0.9923 - auc: 0.9996 - precision: 0.9929 - recall: 0.9921 - val_loss: 0.2048 - val_categorical_accuracy: 0.9602 - val_auc: 0.9930 - val_precision: 0.9616 - val_recall: 0.9602 - 104s/epoch - 515ms/step
# Epoch 17/80
# 202/202 - 104s - loss: 0.0125 - categorical_accuracy: 0.9962 - auc: 0.9998 - precision: 0.9964 - recall: 0.9960 - val_loss: 0.0174 - val_categorical_accuracy: 0.9956 - val_auc: 0.9994 - val_precision: 0.9956 - val_recall: 0.9956 - 104s/epoch - 515ms/step
# Epoch 18/80
# 202/202 - 104s - loss: 0.0078 - categorical_accuracy: 0.9978 - auc: 0.9998 - precision: 0.9979 - recall: 0.9978 - val_loss: 0.0475 - val_categorical_accuracy: 0.9909 - val_auc: 0.9982 - val_precision: 0.9909 - val_recall: 0.9905 - 104s/epoch - 517ms/step
# Epoch 19/80
# 202/202 - 104s - loss: 0.0039 - categorical_accuracy: 0.9988 - auc: 1.0000 - precision: 0.9988 - recall: 0.9988 - val_loss: 0.0071 - val_categorical_accuracy: 0.9982 - val_auc: 1.0000 - val_precision: 0.9982 - val_recall: 0.9982 - 104s/epoch - 516ms/step
# Epoch 20/80
# 202/202 - 104s - loss: 0.0031 - categorical_accuracy: 0.9992 - auc: 0.9999 - precision: 0.9992 - recall: 0.9992 - val_loss: 0.0053 - val_categorical_accuracy: 0.9985 - val_auc: 1.0000 - val_precision: 0.9985 - val_recall: 0.9985 - 104s/epoch - 516ms/step
# Epoch 21/80
# 202/202 - 105s - loss: 0.0314 - categorical_accuracy: 0.9898 - auc: 0.9995 - precision: 0.9904 - recall: 0.9895 - val_loss: 0.0780 - val_categorical_accuracy: 0.9759 - val_auc: 0.9984 - val_precision: 0.9766 - val_recall: 0.9748 - 105s/epoch - 519ms/step
# Epoch 22/80
# 202/202 - 104s - loss: 0.0144 - categorical_accuracy: 0.9954 - auc: 0.9998 - precision: 0.9957 - recall: 0.9950 - val_loss: 0.0544 - val_categorical_accuracy: 0.9850 - val_auc: 0.9990 - val_precision: 0.9850 - val_recall: 0.9850 - 104s/epoch - 517ms/step
# Epoch 23/80
# 202/202 - 104s - loss: 0.0043 - categorical_accuracy: 0.9985 - auc: 1.0000 - precision: 0.9985 - recall: 0.9983 - val_loss: 0.0168 - val_categorical_accuracy: 0.9953 - val_auc: 0.9998 - val_precision: 0.9953 - val_recall: 0.9953 - 104s/epoch - 515ms/step
# Epoch 24/80
# 202/202 - 104s - loss: 0.0017 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0025 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - 104s/epoch - 516ms/step
# Epoch 25/80
# 202/202 - 104s - loss: 4.0111e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0022 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 517ms/step
# Epoch 26/80
# 202/202 - 104s - loss: 1.6436e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0014 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - 104s/epoch - 516ms/step
# Epoch 27/80
# 202/202 - 105s - loss: 1.4969e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 5.4582e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 105s/epoch - 518ms/step
# Epoch 28/80
# 202/202 - 105s - loss: 0.0233 - categorical_accuracy: 0.9933 - auc: 0.9994 - precision: 0.9939 - recall: 0.9932 - val_loss: 0.5786 - val_categorical_accuracy: 0.8252 - val_auc: 0.9874 - val_precision: 0.8278 - val_recall: 0.8242 - 105s/epoch - 518ms/step
# Epoch 29/80
# 202/202 - 105s - loss: 0.0364 - categorical_accuracy: 0.9890 - auc: 0.9994 - precision: 0.9895 - recall: 0.9888 - val_loss: 0.2014 - val_categorical_accuracy: 0.9515 - val_auc: 0.9927 - val_precision: 0.9514 - val_recall: 0.9507 - 105s/epoch - 518ms/step
# Epoch 30/80
# 202/202 - 105s - loss: 0.0203 - categorical_accuracy: 0.9940 - auc: 0.9997 - precision: 0.9943 - recall: 0.9938 - val_loss: 0.0281 - val_categorical_accuracy: 0.9901 - val_auc: 0.9998 - val_precision: 0.9901 - val_recall: 0.9901 - 105s/epoch - 518ms/step
# Epoch 31/80
# 202/202 - 104s - loss: 0.0039 - categorical_accuracy: 0.9989 - auc: 1.0000 - precision: 0.9989 - recall: 0.9988 - val_loss: 0.0061 - val_categorical_accuracy: 0.9985 - val_auc: 1.0000 - val_precision: 0.9985 - val_recall: 0.9985 - 104s/epoch - 516ms/step
# Epoch 32/80
# 202/202 - 105s - loss: 5.7895e-04 - categorical_accuracy: 0.9999 - auc: 1.0000 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.0029 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 105s/epoch - 518ms/step
# Epoch 33/80
# 202/202 - 104s - loss: 3.0302e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0014 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - 104s/epoch - 516ms/step
# Epoch 34/80
# 202/202 - 104s - loss: 4.1812e-04 - categorical_accuracy: 0.9999 - auc: 1.0000 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0023 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 104s/epoch - 517ms/step
# Epoch 35/80
# 202/202 - 105s - loss: 0.0069 - categorical_accuracy: 0.9978 - auc: 1.0000 - precision: 0.9978 - recall: 0.9977 - val_loss: 0.0264 - val_categorical_accuracy: 0.9931 - val_auc: 0.9996 - val_precision: 0.9931 - val_recall: 0.9931 - 105s/epoch - 518ms/step
# Epoch 36/80
# 202/202 - 104s - loss: 0.0169 - categorical_accuracy: 0.9948 - auc: 0.9998 - precision: 0.9950 - recall: 0.9947 - val_loss: 0.1061 - val_categorical_accuracy: 0.9694 - val_auc: 0.9981 - val_precision: 0.9711 - val_recall: 0.9675 - 104s/epoch - 516ms/step
# Epoch 37/80
# 202/202 - 105s - loss: 0.0074 - categorical_accuracy: 0.9972 - auc: 0.9999 - precision: 0.9974 - recall: 0.9971 - val_loss: 0.0278 - val_categorical_accuracy: 0.9909 - val_auc: 0.9996 - val_precision: 0.9909 - val_recall: 0.9905 - 105s/epoch - 519ms/step
# Epoch 38/80
# 202/202 - 104s - loss: 0.0091 - categorical_accuracy: 0.9968 - auc: 0.9999 - precision: 0.9969 - recall: 0.9968 - val_loss: 0.4316 - val_categorical_accuracy: 0.9216 - val_auc: 0.9853 - val_precision: 0.9225 - val_recall: 0.9205 - 104s/epoch - 516ms/step
# Epoch 39/80
# 202/202 - 104s - loss: 0.0078 - categorical_accuracy: 0.9976 - auc: 0.9999 - precision: 0.9976 - recall: 0.9975 - val_loss: 0.0106 - val_categorical_accuracy: 0.9953 - val_auc: 1.0000 - val_precision: 0.9956 - val_recall: 0.9949 - 104s/epoch - 515ms/step
# Epoch 40/80
# 202/202 - 105s - loss: 4.2628e-04 - categorical_accuracy: 0.9999 - auc: 1.0000 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0018 - val_categorical_accuracy: 0.9985 - val_auc: 1.0000 - val_precision: 0.9989 - val_recall: 0.9985 - 105s/epoch - 519ms/step
# Epoch 41/80
# 202/202 - 104s - loss: 0.0039 - categorical_accuracy: 0.9989 - auc: 0.9999 - precision: 0.9991 - recall: 0.9988 - val_loss: 0.0558 - val_categorical_accuracy: 0.9839 - val_auc: 0.9989 - val_precision: 0.9843 - val_recall: 0.9836 - 104s/epoch - 515ms/step
# Epoch 42/80
# 202/202 - 104s - loss: 0.0178 - categorical_accuracy: 0.9955 - auc: 0.9996 - precision: 0.9955 - recall: 0.9953 - val_loss: 0.0523 - val_categorical_accuracy: 0.9872 - val_auc: 0.9991 - val_precision: 0.9876 - val_recall: 0.9861 - 104s/epoch - 517ms/step
# Epoch 43/80
# 202/202 - 104s - loss: 0.0024 - categorical_accuracy: 0.9994 - auc: 1.0000 - precision: 0.9994 - recall: 0.9994 - val_loss: 0.0047 - val_categorical_accuracy: 0.9989 - val_auc: 0.9998 - val_precision: 0.9989 - val_recall: 0.9989 - 104s/epoch - 517ms/step
# Epoch 44/80
# 202/202 - 104s - loss: 0.0060 - categorical_accuracy: 0.9979 - auc: 1.0000 - precision: 0.9979 - recall: 0.9979 - val_loss: 0.1392 - val_categorical_accuracy: 0.9759 - val_auc: 0.9952 - val_precision: 0.9773 - val_recall: 0.9752 - 104s/epoch - 516ms/step
# Epoch 45/80
# 202/202 - 105s - loss: 0.0078 - categorical_accuracy: 0.9976 - auc: 0.9999 - precision: 0.9977 - recall: 0.9976 - val_loss: 0.0059 - val_categorical_accuracy: 0.9978 - val_auc: 0.9998 - val_precision: 0.9978 - val_recall: 0.9978 - 105s/epoch - 518ms/step
# Epoch 46/80
# 202/202 - 104s - loss: 0.0023 - categorical_accuracy: 0.9993 - auc: 1.0000 - precision: 0.9993 - recall: 0.9993 - val_loss: 0.1976 - val_categorical_accuracy: 0.9522 - val_auc: 0.9935 - val_precision: 0.9549 - val_recall: 0.9500 - 104s/epoch - 515ms/step
# Epoch 47/80
# 202/202 - 105s - loss: 0.0133 - categorical_accuracy: 0.9963 - auc: 0.9997 - precision: 0.9964 - recall: 0.9961 - val_loss: 0.0111 - val_categorical_accuracy: 0.9978 - val_auc: 0.9996 - val_precision: 0.9978 - val_recall: 0.9978 - 105s/epoch - 518ms/step
# Epoch 48/80
# 202/202 - 104s - loss: 0.0042 - categorical_accuracy: 0.9985 - auc: 1.0000 - precision: 0.9985 - recall: 0.9985 - val_loss: 0.0192 - val_categorical_accuracy: 0.9953 - val_auc: 0.9993 - val_precision: 0.9953 - val_recall: 0.9949 - 104s/epoch - 515ms/step
# Epoch 49/80
# 202/202 - 104s - loss: 0.0050 - categorical_accuracy: 0.9989 - auc: 0.9998 - precision: 0.9989 - recall: 0.9989 - val_loss: 0.0117 - val_categorical_accuracy: 0.9964 - val_auc: 0.9996 - val_precision: 0.9964 - val_recall: 0.9960 - 104s/epoch - 517ms/step
# Epoch 50/80
# 202/202 - 104s - loss: 0.0162 - categorical_accuracy: 0.9958 - auc: 0.9997 - precision: 0.9959 - recall: 0.9958 - val_loss: 0.0585 - val_categorical_accuracy: 0.9825 - val_auc: 0.9991 - val_precision: 0.9828 - val_recall: 0.9821 - 104s/epoch - 517ms/step
# Epoch 51/80
# 202/202 - 111s - loss: 0.0028 - categorical_accuracy: 0.9988 - auc: 1.0000 - precision: 0.9988 - recall: 0.9988 - val_loss: 0.0155 - val_categorical_accuracy: 0.9960 - val_auc: 0.9998 - val_precision: 0.9964 - val_recall: 0.9960 - 111s/epoch - 549ms/step
# Epoch 52/80
# 202/202 - 105s - loss: 0.0019 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.0022 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - 105s/epoch - 518ms/step
# Epoch 53/80
# 202/202 - 104s - loss: 2.3617e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0024 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 515ms/step
# Epoch 54/80
# 202/202 - 104s - loss: 0.0257 - categorical_accuracy: 0.9938 - auc: 0.9992 - precision: 0.9940 - recall: 0.9935 - val_loss: 1.1842 - val_categorical_accuracy: 0.7891 - val_auc: 0.9574 - val_precision: 0.8019 - val_recall: 0.7844 - 104s/epoch - 516ms/step
# Epoch 55/80
# 202/202 - 105s - loss: 0.0125 - categorical_accuracy: 0.9968 - auc: 0.9998 - precision: 0.9968 - recall: 0.9967 - val_loss: 0.0042 - val_categorical_accuracy: 0.9982 - val_auc: 1.0000 - val_precision: 0.9982 - val_recall: 0.9982 - 105s/epoch - 520ms/step
# Epoch 56/80
# 202/202 - 104s - loss: 0.0057 - categorical_accuracy: 0.9983 - auc: 0.9999 - precision: 0.9983 - recall: 0.9981 - val_loss: 0.0026 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - 104s/epoch - 517ms/step
# Epoch 57/80
# 202/202 - 104s - loss: 6.1016e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0019 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 104s/epoch - 517ms/step
# Epoch 58/80
# 202/202 - 104s - loss: 1.3439e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 6.5951e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 104s/epoch - 515ms/step
# Epoch 59/80
# 202/202 - 104s - loss: 9.7152e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 9.9237e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 104s/epoch - 517ms/step
# Epoch 60/80
# 202/202 - 105s - loss: 4.3179e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 9.1198e-04 - val_categorical_accuracy: 0.9996 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9996 - 105s/epoch - 518ms/step
# Epoch 61/80
# 202/202 - 105s - loss: 0.0101 - categorical_accuracy: 0.9972 - auc: 0.9998 - precision: 0.9973 - recall: 0.9970 - val_loss: 0.0120 - val_categorical_accuracy: 0.9971 - val_auc: 0.9996 - val_precision: 0.9971 - val_recall: 0.9971 - 105s/epoch - 518ms/step
# Epoch 62/80
# 202/202 - 104s - loss: 0.0332 - categorical_accuracy: 0.9922 - auc: 0.9990 - precision: 0.9925 - recall: 0.9920 - val_loss: 0.5558 - val_categorical_accuracy: 0.8661 - val_auc: 0.9825 - val_precision: 0.8721 - val_recall: 0.8628 - 104s/epoch - 516ms/step
# Epoch 63/80
# 202/202 - 105s - loss: 0.0058 - categorical_accuracy: 0.9983 - auc: 1.0000 - precision: 0.9984 - recall: 0.9983 - val_loss: 0.0066 - val_categorical_accuracy: 0.9989 - val_auc: 0.9998 - val_precision: 0.9993 - val_recall: 0.9985 - 105s/epoch - 518ms/step
# Epoch 64/80
# 202/202 - 104s - loss: 9.5061e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0029 - val_categorical_accuracy: 0.9989 - val_auc: 1.0000 - val_precision: 0.9989 - val_recall: 0.9989 - 104s/epoch - 516ms/step
# Epoch 65/80
# 202/202 - 105s - loss: 1.6704e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0013 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 105s/epoch - 519ms/step
# Epoch 66/80
# 202/202 - 104s - loss: 1.5554e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0033 - val_categorical_accuracy: 0.9985 - val_auc: 1.0000 - val_precision: 0.9985 - val_recall: 0.9985 - 104s/epoch - 515ms/step
# Epoch 67/80
# 202/202 - 104s - loss: 5.9687e-04 - categorical_accuracy: 0.9999 - auc: 1.0000 - precision: 0.9999 - recall: 0.9999 - val_loss: 0.0020 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 515ms/step
# Epoch 68/80
# 202/202 - 104s - loss: 9.5455e-04 - categorical_accuracy: 0.9998 - auc: 1.0000 - precision: 0.9998 - recall: 0.9998 - val_loss: 0.0036 - val_categorical_accuracy: 0.9993 - val_auc: 0.9998 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 516ms/step
# Epoch 69/80
# 202/202 - 104s - loss: 0.0021 - categorical_accuracy: 0.9995 - auc: 1.0000 - precision: 0.9995 - recall: 0.9995 - val_loss: 0.2504 - val_categorical_accuracy: 0.9351 - val_auc: 0.9935 - val_precision: 0.9354 - val_recall: 0.9343 - 104s/epoch - 515ms/step
# Epoch 70/80
# 202/202 - 104s - loss: 0.0226 - categorical_accuracy: 0.9935 - auc: 0.9997 - precision: 0.9936 - recall: 0.9932 - val_loss: 0.1554 - val_categorical_accuracy: 0.9628 - val_auc: 0.9920 - val_precision: 0.9638 - val_recall: 0.9624 - 104s/epoch - 517ms/step
# Epoch 71/80
# 202/202 - 104s - loss: 0.0039 - categorical_accuracy: 0.9990 - auc: 0.9999 - precision: 0.9990 - recall: 0.9990 - val_loss: 0.0025 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9989 - 104s/epoch - 515ms/step
# Epoch 72/80
# 202/202 - 104s - loss: 1.5086e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0016 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9989 - 104s/epoch - 515ms/step
# Epoch 73/80
# 202/202 - 104s - loss: 9.8487e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0016 - val_categorical_accuracy: 0.9989 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9989 - 104s/epoch - 515ms/step
# Epoch 74/80
# 202/202 - 104s - loss: 1.1367e-04 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0017 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - 104s/epoch - 514ms/step
# Epoch 75/80
# 202/202 - 104s - loss: 7.1368e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0019 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9996 - val_recall: 0.9993 - 104s/epoch - 516ms/step
# Epoch 76/80
# 202/202 - 104s - loss: 7.5956e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0028 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 516ms/step
# Epoch 77/80
# 202/202 - 105s - loss: 4.5345e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0020 - val_categorical_accuracy: 0.9989 - val_auc: 1.0000 - val_precision: 0.9989 - val_recall: 0.9989 - 105s/epoch - 518ms/step
# Epoch 78/80
# 202/202 - 105s - loss: 4.1401e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0019 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 105s/epoch - 518ms/step
# Epoch 79/80
# 202/202 - 104s - loss: 2.7071e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0020 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 516ms/step
# Epoch 80/80
# 202/202 - 104s - loss: 3.4445e-05 - categorical_accuracy: 1.0000 - auc: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.0028 - val_categorical_accuracy: 0.9993 - val_auc: 1.0000 - val_precision: 0.9993 - val_recall: 0.9993 - 104s/epoch - 516ms/step
# ===================================
# 80 epochs in 162.07180610100428 min

# %%
densenet.evaluate(test_gen)
# Out:
# 2815/2815 [==============================] - 52s 18ms/step - loss: 5.9628e-04 - categorical_accuracy: 0.9996 - auc: 1.0000 - precision: 0.9996 - recall: 0.9996
# [0.0005962767172604799,
#  0.9996447563171387,
#  1.0,
#  0.9996447563171387,
#  0.9996447563171387]

# %%
report(densenet)
# Out:
# 2815/2815 [==============================] - 43s 15ms/step
# [[[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   1  185]]
#
#  [[2628    1]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2629    0]
#   [   0  186]]
#
#  [[2754    0]
#   [   0   61]]
#
#  [[2753    0]
#   [   0   62]]
#
#  [[2541    0]
#   [   0  274]]]
#               precision    recall  f1-score   support
#
#            0    1.00000   1.00000   1.00000       186
#            1    1.00000   1.00000   1.00000       186
#            2    1.00000   1.00000   1.00000       186
#            3    1.00000   1.00000   1.00000       186
#            4    1.00000   1.00000   1.00000       186
#            5    1.00000   1.00000   1.00000       186
#            6    1.00000   1.00000   1.00000       186
#            7    1.00000   0.99462   0.99730       186
#            8    0.99465   1.00000   0.99732       186
#            9    1.00000   1.00000   1.00000       186
#           10    1.00000   1.00000   1.00000       186
#           11    1.00000   1.00000   1.00000       186
#           12    1.00000   1.00000   1.00000       186
#           13    1.00000   1.00000   1.00000        61
#           14    1.00000   1.00000   1.00000        62
#           15    1.00000   1.00000   1.00000       274
#
#     accuracy                        0.99964      2815
#    macro avg    0.99967   0.99966   0.99966      2815
# weighted avg    0.99965   0.99964   0.99964      2815
